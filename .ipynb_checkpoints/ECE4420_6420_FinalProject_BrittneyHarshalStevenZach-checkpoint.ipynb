# %% [markdown]
# # ECE 4420/6420 Final Project
# ## Tabular Playground Series: State Classification
# ### Brittney McKeone, Harshal Varpe, Steven Platt, Zach Fugate

# %% [markdown]
# For the final project, we chose a Kaggle competition named Tabular Playground Series. The final project aimed at the implementation various EDA and data preprocessing methods, classifiers, and their respective hypertuning to a classification problem.
#
# The problem we chose concerned with binary state classification using biological sensor data collected from nearly a thousand different paticipant.

# %% [markdown]
# Project checkpoint 1 (15%): For this milestone, you will need to have downloaded the data, and
# also run some initial pre-processing on it. You should also make at least one dummy submission
# (all-positive, all-negative, most-frequency) on Kaggle and submit the Jupyter Notebook including
# the code and a screenshot of the score on Canvas.

# %%
# Importing all the required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.dummy import DummyClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV
import graphviz
import IPython
import mglearn
from IPython.display import HTML, display

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\hvarp\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# We use this function provided during class/assignment to get the cross validation score and see if the model is overfitting.
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" % (mean_scores[i], std_scores[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %% [markdown]
# Let us take a look at the data provided.
#
# The dataset had three different data sets.
# The "train.csv" file contains the sequence and corresponding sensor data. Each sequence has 60 data points or sensor readings. There are total 12 different sensors. Moreover, each sequence number is associated with a unique subject. The variable "step" is simply a counter that runs from 0 to 59 for each sequence or each subject. Important thing about this datafile is that there are no labels included. The image below shows a snippet of the .csv file.
#
# ![train_csv.png](attachment:train_csv.png)

# %%
X_train = pd.read_csv("train.csv")
X_train_og = X_train # we will need this for heatmap and pairplot
X_train.shape
# Out:
# (1558080, 16)

# %%
X_train.head()
# Out:
#    sequence  subject  step  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0       47     0  -0.196291   0.112395        1.0   0.329204
# 1         0       47     1  -0.447450   0.134454        1.0  -0.658407
# 2         0       47     2   0.326893  -0.694328        1.0   0.330088
# 3         0       47     3   0.523184   0.751050        1.0   0.976991
# 4         0       47     4   0.272025   1.074580        1.0  -0.136283
#
#    sensor_04  sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# 0  -1.004660  -0.131638  -0.127505   0.368702       -0.1  -0.963873
# 1   0.162495   0.340314  -0.209472  -0.867176        0.2  -0.301301
# 2   0.473678   1.280479  -0.094718   0.535878        1.4   1.002168
# 3  -0.563287  -0.720269   0.793260   0.951145       -0.3  -0.995665
# 4   0.398579   0.044877   0.560109  -0.541985       -0.9   1.055636
#
#    sensor_10  sensor_11  sensor_12
# 0  -0.985069   0.531893   4.751492
# 1   0.082733  -0.231481   0.454390
# 2   0.449221  -0.586420  -4.736147
# 3  -0.434290   1.344650   0.429241
# 4   0.812631   0.123457  -0.223359

# %% [markdown]
# The "train_lables.csv" file contains the labels for the all the datapoints in "train.csv". It has only two columns: sequence and state.

# %% [markdown]
# ![train_labels_csv.png](attachment:train_labels_csv.png)

# %%
y_train = pd.read_csv("train_labels.csv")
y_train.head()
# Out:
#    sequence  state
# 0         0      0
# 1         1      1
# 2         2      1
# 3         3      1
# 4         4      1

# %%
y_train.shape
# Out:
# (25968, 2)

# %%
X_train.describe()
# Out:
#            sequence       subject          step     sensor_00     sensor_01  \
# count  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06
# mean   1.298350e+04  3.316331e+02  2.950000e+01  4.365526e-04 -1.034982e-03
# std    7.496318e+03  1.958257e+02  1.731811e+01  2.658684e+00  4.404200e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00 -3.750634e+02 -4.345977e+02
# 25%    6.491750e+03  1.617500e+02  1.475000e+01 -5.000000e-01 -4.831933e-01
# 50%    1.298350e+04  3.350000e+02  2.950000e+01 -3.091190e-03  3.151261e-03
# 75%    1.947525e+04  5.010000e+02  4.425000e+01  4.845440e-01  4.926471e-01
# max    2.596700e+04  6.710000e+02  5.900000e+01  3.358246e+02  4.495914e+02
#
#           sensor_02     sensor_03     sensor_04     sensor_05     sensor_06  \
# count  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06
# mean  -2.178045e-01 -2.156555e-03 -1.828903e-03 -1.651785e-03 -4.122917e-04
# std    2.298002e+00  3.934184e+00  1.683685e+00  1.590818e+00  3.345143e+00
# min   -3.165948e+01 -4.083761e+02 -2.362601e+01 -7.498280e+01 -4.705046e+02
# 25%   -6.461531e-01 -4.929204e-01 -4.729928e-01 -4.786836e-01 -4.927140e-01
# 50%    0.000000e+00  0.000000e+00 -1.589577e-03  2.991773e-03  9.107468e-04
# 75%    3.338469e-01  4.893805e-01  4.701565e-01  5.056096e-01  4.927140e-01
# max    1.666667e+00  4.366504e+02  2.487286e+01  7.791548e+01  4.425009e+02
#
#           sensor_07     sensor_08     sensor_09     sensor_10     sensor_11  \
# count  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06  1.558080e+06
# mean  -2.620665e-05 -1.298393e-04  1.365584e-03  3.315801e-04 -3.733291e-03
# std    3.243428e+00  4.501534e+00  2.592913e+00  1.917333e+00  4.532568e+00
# min   -4.070115e+02 -5.361000e+02 -2.703468e+02 -4.341271e+01 -4.270586e+02
# 25%   -5.022901e-01 -5.000000e-01 -5.151734e-01 -4.787939e-01 -4.835391e-01
# 50%   -2.290076e-03  0.000000e+00 -1.445087e-03 -1.655822e-03  3.086420e-03
# 75%    4.847328e-01  5.000000e-01  5.086705e-01  4.780386e-01  4.938272e-01
# max    3.312542e+02  6.301000e+02  3.679812e+02  4.186559e+01  4.480206e+02
#
#           sensor_12
# count  1.558080e+06
# mean  -1.172605e-02
# std    3.911767e+01
# min   -6.125494e+02
# 25%   -5.805627e-01
# 50%    0.000000e+00
# 75%    5.703325e-01
# max    6.305111e+02

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1558080 entries, 0 to 1558079
# Data columns (total 16 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   sequence   1558080 non-null  int64
#  1   subject    1558080 non-null  int64
#  2   step       1558080 non-null  int64
#  3   sensor_00  1558080 non-null  float64
#  4   sensor_01  1558080 non-null  float64
#  5   sensor_02  1558080 non-null  float64
#  6   sensor_03  1558080 non-null  float64
#  7   sensor_04  1558080 non-null  float64
#  8   sensor_05  1558080 non-null  float64
#  9   sensor_06  1558080 non-null  float64
#  10  sensor_07  1558080 non-null  float64
#  11  sensor_08  1558080 non-null  float64
#  12  sensor_09  1558080 non-null  float64
#  13  sensor_10  1558080 non-null  float64
#  14  sensor_11  1558080 non-null  float64
#  15  sensor_12  1558080 non-null  float64
# dtypes: float64(13), int64(3)
# memory usage: 190.2 MB

# %% [markdown]
# Let us check if our dataset has any missing values.

# %%
cols = list(X_train.columns)
print(cols)
# Out:
# ['sequence', 'subject', 'step', 'sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12']

# %%
bool_df = pd.DataFrame(columns=X_train.columns)
for i in cols:
    bool_df[i] = pd.isnull(X_train[i])
    print( np.unique(bool_df[i], return_counts=True) )
# Out:
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))
# (array([False]), array([1558080], dtype=int64))

# %%
for i in cols:
    print(f" The number of non_null values for feature '{i}' : {(~bool_df[i]).values.sum()} ")
# Out:
#  The number of non_null values for feature 'sequence' : 1558080
#  The number of non_null values for feature 'subject' : 1558080
#  The number of non_null values for feature 'step' : 1558080
#  The number of non_null values for feature 'sensor_00' : 1558080
#  The number of non_null values for feature 'sensor_01' : 1558080
#  The number of non_null values for feature 'sensor_02' : 1558080
#  The number of non_null values for feature 'sensor_03' : 1558080
#  The number of non_null values for feature 'sensor_04' : 1558080
#  The number of non_null values for feature 'sensor_05' : 1558080
#  The number of non_null values for feature 'sensor_06' : 1558080
#  The number of non_null values for feature 'sensor_07' : 1558080
#  The number of non_null values for feature 'sensor_08' : 1558080
#  The number of non_null values for feature 'sensor_09' : 1558080
#  The number of non_null values for feature 'sensor_10' : 1558080
#  The number of non_null values for feature 'sensor_11' : 1558080
#  The number of non_null values for feature 'sensor_12' : 1558080

# %% [markdown]
# The ".isnull" function is used check if any value in the particular column / series / feature is not missing values. This function/method returns boolean values. All these values are stored in the another dataframe "bool_df". If there are no missing values, then the series for each feature will contain only false values.
#
# The "np.unique()" function is used to count if there are any True values. As we can see from the results above, there is only one unique values that is False.
#
# Just to be sure, we also use "~pd.values.sum()" to check the number of False values. It should match with our number of datapoints i.e. 1558080. Without the ~ sign the values or count of True values is returned.

# %%
X_train[cols].isna().sum()
# Out:
# sequence     0
# subject      0
# step         0
# sensor_00    0
# sensor_01    0
# sensor_02    0
# sensor_03    0
# sensor_04    0
# sensor_05    0
# sensor_06    0
# sensor_07    0
# sensor_08    0
# sensor_09    0
# sensor_10    0
# sensor_11    0
# sensor_12    0
# dtype: int64

# %% [markdown]
# Another way to check if the dataset has null values or missing values is to use `df.isna().sum()`. This gives us the total number of missing values. As we can see from the cell above none of the features have missing values.

# %%
X_train = X_train.drop(columns=['subject','step'])
X_train = X_train.groupby(['sequence']).mean()
y_seq = y_train['sequence']
y_train = y_train.drop(columns=['sequence'])

# %%
dc = DummyClassifier()
result_dict = {} 
dc.fit(X_train,y_train)
# Out:
# DummyClassifier()

# %% [markdown]
# We also need to check if the testing set has any missing values.

# %%
X_test = pd.read_csv("test.csv")
X_test_og = X_test # we may need this for heatmap and pariplot
X_test = X_test.drop(columns=['subject','step'])
X_test.isna().sum()
# Out:
# sequence     0
# sensor_00    0
# sensor_01    0
# sensor_02    0
# sensor_03    0
# sensor_04    0
# sensor_05    0
# sensor_06    0
# sensor_07    0
# sensor_08    0
# sensor_09    0
# sensor_10    0
# sensor_11    0
# sensor_12    0
# dtype: int64

# %% [markdown]
# From the result above, we can conclude that we do not have any missgin values in the testing set.

# %% [markdown]
# It is necessary to group the test set by sequence number just like we did it for training set.

# %%
X_test = X_test.groupby(['sequence']).mean() 
# X_test
predict_dc = dc.predict(X_test)
predict_dc_df = pd.DataFrame(predict_dc,columns=['state']) # creating a dataframe of the results
# predict_df

# %% [markdown]
# The following cell was created to create a dataframe with correct sequence numbers. Later in the execution this dataframe is merged with state prediction by each model.

# %%
list = []
i = 1
while i < 12219:
    list.append(25967+i)
    i += 1
col = np.array(list)
col_df = pd.DataFrame(col,columns=['sequence']) # creating a dataframe for sequence numbers. This df will be the same for
# all classifiers.
# col_df

final_dc_df = pd.concat([col_df,predict_dc_df],ignore_index=False, sort=False,axis=1) # concating the 
# final_df

# %%
final_dc_df.to_csv("Results/output_dummy.csv",index=False) # output the result to csv file

result_dict["Dummy_Classifer"] = mean_std_cross_val_scores(dc, X_train, y_train, cv=5, return_train_score=True)

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train,y_train)
predict_dtc = dtc.predict(X_test)
predict_dtc_df = pd.DataFrame(predict_dtc,columns=['state']) # creating a dataframe of the results

# %%
final_dtc_df = pd.concat([col_df,predict_dtc_df],ignore_index=False, sort=False,axis=1)
final_dtc_df.to_csv("Results/output_dtc.csv",index=False)
result_dict["DecitionTree_Classifier"] = mean_std_cross_val_scores(dtc, X_train, y_train, cv=5, return_train_score=True)

# %% [markdown]
# ### More Prepocessing

# %% [markdown]
# Initially, for the project checkpoint 1, we only checked for the null/missing values and tested the result of Dummy and Decision Tree Classifier. Meanwhile, we thought of more preprocessing that we could do. Thus we checked if the features are correlated. Although, it seems logical to assume that no two sensors can affect each other, it is quite possible that they may have some correlation between them.
#
# We will try to create a heatmap  of the data to see correlation.

# %%
import seaborn as sns

# %%
X_train_og = X_train_og.drop(columns=['subject','step'])
# X_train_og
X_train_og.groupby(['sequence']).mean()
correlation = X_train_og.corr()

plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Sensor data if grouped by mean')
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()

# %% [markdown]
# As we can see from the sensor heatmap, most sensors do not have significant correlation with each other. Sensors with correlation between 0.2 and 0.55, can be attributes to sensor noise.

# %%
X_train_og.groupby(['sequence']).median()
correlation = X_train_og.corr()

plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Sensor data if grouped by mean')
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)           
plt.show()

# %% [markdown]
# There is no difference if we group the data by mean or median. Hence it is safe to assume that classifier behaviour won't change much.
# Generally, with numerical data, we can do a interquartile analysis to see if the outliers should be included in the training set or not. With that in mind, we plotted the interquartile plot for each sensor. However, the operating range of the sensors were not provided. Hence, this analysis was not useful to us.

# %%
cols_og = X_train_og.columns.values.tolist()
cols_og.remove('sequence')
print(cols_og)
# Out:
# ['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12']

# %%
plt.figure(figsize=(15,45))
for count, value in enumerate(cols[3:]):
    plt.subplot(13, 2, count+1)
    fig = X_train.boxplot(column = value,color=dict(boxes='r', whiskers='r', medians='r', caps='r'))
    fig.set_title('')
    fig.set_ylabel(value)

# %%
## Did not end up using this. Computationally too expensive
## This was to plot a frequency histogram of the data.
# %matplotlib notebook
# a = X_train_og[cols_og[1]].value_counts(bins=800,sort=False).to_frame()
# a.plot()
# plt.xticks(rotation=60);
# plt.subplots_adjust(top=0.925, 
#                     bottom=0.30, 
#                     left=0.2, 
#                     right=0.90, 
#                     hspace=0.01, 
#                     wspace=0.01)
# plt.show()

# %% [markdown]
# The cell above shows the code that was written for plotting frequency histogram of the data. However, with over a million data points this cell was computationally quite heacy even when run on Palmetto Cluster.

# %% [markdown]
# ### Preprocessing: Pratt Method

# %%
# ### Train Data
# rowNames = ["mean","std","min","25%","50%","75%","max"]
# describeDict = {}
# for sensorNum in range(13):
#     for rowName in rowNames:
#         describeDict[f"sensor_{str(sensorNum).zfill(2)}_{rowName}"] = []
# for numSequence in range(max(X_train["sequence"])+1):
#     info = X_train[X_train["sequence"]==numSequence].describe()
#     for sensorNum in range(13):
#         for rowName in rowNames:
#             describeDict[f"sensor_{str(sensorNum).zfill(2)}_{rowName}"].append(info[f"sensor_{str(sensorNum).zfill(2)}"][rowName])
#     if(numSequence%10==0):
#         print(numSequence)
# describeDict

# splatt_train_df = pd.DataFrame.from_dict(describeDict)
# splatt_train_df

# %%
# testDict = {}
# for sensorNum in range(13):
#     for rowName in rowNames:
#         testDict[f"sensor_{str(sensorNum).zfill(2)}_{rowName}"] = []
# for numSequence in range(25968,38186):#max(X_test["sequence"])+1-min(X_test["sequence"])):
#     info = X_test[X_test["sequence"]==numSequence].describe()
#     for sensorNum in range(13):
#         for rowName in rowNames:
#             testDict[f"sensor_{str(sensorNum).zfill(2)}_{rowName}"].append(info[f"sensor_{str(sensorNum).zfill(2)}"][rowName])
#     if(numSequence%100==0):
#         print(numSequence)
# testDict
# splatt_test_df = pd.DataFrame.from_dict(testDict)
# splatt_test_df

# %% [markdown]
# We had a unique idea to use the statistical information about the given data. The idea was to use features like mean, standard deviation, variance, 25%, 50%, 75% and max to split each sensor. Meaning instead of original 13 sensor readings, we now use 7 statistical feature for each sensor per sensor, so total of 91 distinct features.
#
# The first cell above gives us the 91 feature dataframe for train dataset and the second cell gives the 91 feature dataframe for test dataset. These dataframes then could be used in the models. We discuss the results of using dataframes over other dataframes later in this report/jupyter notebook.

# %% [markdown]
# ## Other Classfiers
#
# After the interquartile analysis, we decided upon the model that we wanted try for our classification problem. The model we chose were :  Decision Tree Classifier, Gaussian Naive Bayes, Logistic Regression, Random Forest, Gradient Boosting, and CatBoost.
# Decision Tree is very commom classifier that is used in classification problem. Gaussian Naive Bayes classifier applies the Bayes' theorem to the data with the assumption that there is no correlation between the different features.Although, our heatmap showed reletively low correlation, we wanted to see if we could get the best result from assumming zero correlation. Logistic Regression is another common model used in classification problems, such email spam classification problem. Then the rest three models are part of ensemble techniques that are known to perform much better than the other classifiers mentioned.

# %%
pd.DataFrame(result_dict).T
# Out:
#                                   fit_time         score_time  \
# Dummy_Classifer          0.002 (+/- 0.000)  0.000 (+/- 0.000)
# DecitionTree_Classifier  0.264 (+/- 0.003)  0.002 (+/- 0.000)
#
#                                 test_score        train_score
# Dummy_Classifer          0.501 (+/- 0.000)  0.501 (+/- 0.000)
# DecitionTree_Classifier  0.613 (+/- 0.005)  1.000 (+/- 0.000)

# %% [markdown]
# We can see that Decision tree classifier is overfitting. Let us try different models and see if we see better test scores and train scores.
# #### Naive Bayes
# Naive Bayes methods are a set of supervised learning algorithms based on applying Bayes’ theorem with the “naive” assumption of conditional independence between every pair of features given the value of the class variable.

# %%
#Naive bayes
gnb = GaussianNB()
gnb.fit(X_train,y_train)
predict_gnb = gnb.predict(X_test)
predict_gnb_df = pd.DataFrame(predict_gnb,columns=['state']) # creating a dataframe of the results

final_gnb_df = pd.concat([col_df,predict_gnb_df],ignore_index=False, sort=False,axis=1)
final_gnb_df.to_csv("Results/output_gnb.csv",index=False)
result_dict["GNB_Classifier"] = mean_std_cross_val_scores(gnb, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                   fit_time         score_time  \
# Dummy_Classifer          0.002 (+/- 0.000)  0.000 (+/- 0.000)
# DecitionTree_Classifier  0.264 (+/- 0.003)  0.002 (+/- 0.000)
# GNB_Classifier           0.007 (+/- 0.000)  0.002 (+/- 0.001)
#
#                                 test_score        train_score
# Dummy_Classifer          0.501 (+/- 0.000)  0.501 (+/- 0.000)
# DecitionTree_Classifier  0.613 (+/- 0.005)  1.000 (+/- 0.000)
# GNB_Classifier           0.601 (+/- 0.008)  0.602 (+/- 0.009)

# %% [markdown]
# #### Logistic Regression

# %%
#Logistic Regression
lr = LogisticRegression(random_state=1)
lr.fit(X_train,y_train)
predict_lr = lr.predict(X_test)
predict_lr_df = pd.DataFrame(predict_lr,columns=['state']) # creating a dataframe of the results

final_lr_df = pd.concat([col_df,predict_lr_df],ignore_index=False, sort=False,axis=1)
final_lr_df.to_csv("Results/output_lr.csv",index=False)
result_dict["LogisticR_Classifier"] = mean_std_cross_val_scores(lr, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                   fit_time         score_time  \
# Dummy_Classifer          0.002 (+/- 0.000)  0.000 (+/- 0.000)
# DecitionTree_Classifier  0.264 (+/- 0.003)  0.002 (+/- 0.000)
# GNB_Classifier           0.007 (+/- 0.000)  0.002 (+/- 0.001)
# LogisticR_Classifier     0.049 (+/- 0.003)  0.002 (+/- 0.000)
#
#                                 test_score        train_score
# Dummy_Classifer          0.501 (+/- 0.000)  0.501 (+/- 0.000)
# DecitionTree_Classifier  0.613 (+/- 0.005)  1.000 (+/- 0.000)
# GNB_Classifier           0.601 (+/- 0.008)  0.602 (+/- 0.009)
# LogisticR_Classifier     0.547 (+/- 0.006)  0.548 (+/- 0.002)

# %% [markdown]
# #### Random Forest Classifier

# %%
#Random Forest
rf = RandomForestClassifier(n_estimators = 100, max_depth=10, random_state=0)
rf.fit(X_train,y_train)

predict_rf = rf.predict(X_test)
predict_rf_df = pd.DataFrame(predict_rf,columns=['state']) # creating a dataframe of the results

final_rf_df = pd.concat([col_df,predict_rf_df],ignore_index=False, sort=False,axis=1)
final_rf_df.to_csv("Results/output_rf.csv",index=False)
result_dict["RandomForest_Classifier"] = mean_std_cross_val_scores(rf, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                   fit_time         score_time  \
# Dummy_Classifer          0.002 (+/- 0.000)  0.000 (+/- 0.000)
# DecitionTree_Classifier  0.264 (+/- 0.003)  0.002 (+/- 0.000)
# GNB_Classifier           0.007 (+/- 0.000)  0.002 (+/- 0.001)
# LogisticR_Classifier     0.049 (+/- 0.003)  0.002 (+/- 0.000)
# RandomForest_Classifier  2.683 (+/- 0.034)  0.046 (+/- 0.000)
#
#                                 test_score        train_score
# Dummy_Classifer          0.501 (+/- 0.000)  0.501 (+/- 0.000)
# DecitionTree_Classifier  0.613 (+/- 0.005)  1.000 (+/- 0.000)
# GNB_Classifier           0.601 (+/- 0.008)  0.602 (+/- 0.009)
# LogisticR_Classifier     0.547 (+/- 0.006)  0.548 (+/- 0.002)
# RandomForest_Classifier  0.701 (+/- 0.006)  0.786 (+/- 0.002)

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
#Gradient Boosting
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=1, random_state=0)
gbc.fit(X_train,y_train)

predict_gbc = gbc.predict(X_test)
predict_gbc_df = pd.DataFrame(predict_gbc,columns=['state']) # creating a dataframe of the results

final_gbc_df = pd.concat([col_df,predict_gbc_df],ignore_index=False, sort=False,axis=1)
final_gbc_df.to_csv("Results/output_gbc.csv",index=False)
result_dict["GradBoost_Classifier"] = mean_std_cross_val_scores(gbc, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                   fit_time         score_time  \
# Dummy_Classifer          0.002 (+/- 0.000)  0.000 (+/- 0.000)
# DecitionTree_Classifier  0.264 (+/- 0.003)  0.002 (+/- 0.000)
# GNB_Classifier           0.007 (+/- 0.000)  0.002 (+/- 0.001)
# LogisticR_Classifier     0.049 (+/- 0.003)  0.002 (+/- 0.000)
# RandomForest_Classifier  2.683 (+/- 0.034)  0.046 (+/- 0.000)
# GradBoost_Classifier     1.889 (+/- 0.026)  0.004 (+/- 0.000)
#
#                                 test_score        train_score
# Dummy_Classifer          0.501 (+/- 0.000)  0.501 (+/- 0.000)
# DecitionTree_Classifier  0.613 (+/- 0.005)  1.000 (+/- 0.000)
# GNB_Classifier           0.601 (+/- 0.008)  0.602 (+/- 0.009)
# LogisticR_Classifier     0.547 (+/- 0.006)  0.548 (+/- 0.002)
# RandomForest_Classifier  0.701 (+/- 0.006)  0.786 (+/- 0.002)
# GradBoost_Classifier     0.685 (+/- 0.005)  0.692 (+/- 0.001)

# %% [markdown]
# ### More Preprocessing
#
# At this stage, we thought that we might be able to improve the performance all the baselines estimators by scaling the data. Hence, we used StandardScaler to scale the data. However, we did not get a better score when the result were uploaded to the Kaggle competition.
#
#    The code is given in the cells below. It is commented out, since we did not use it at all.

# %%
std_scale = StandardScaler()
answer = std_scale.fit_transform(X_train)
answer = pd.DataFrame(answer)
answer.columns = X_train.columns
# answer = answer.drop(columns=["subject","step"]) # MAY NOT NEED THIS LINE SINCE I ALREADY REMOVED THESE COLUMNS IN UPPER CELLS.
# answer # X_train

# THIS CELL GIVES A DATAFRAME WITH SCALED TRAIN DATA.

# %%
answer_t = std_scale.fit_transform(X_test)
answer_t = pd.DataFrame(answer_t)
# answer_t = answer_t.drop(columns=[0,1])# MAY NOT NEED THIS LINE SINCE I ALREADY REMOVED THESE COLUMNS IN UPPER CELLS.
answer_t.columns = X_train.columns
# answer_t # X_test

# THIS CELL GIVED A DATAFRAME WITH SCALED TEST DATA.

# %%
# #Random Forest
rf = RandomForestClassifier(n_estimators = 100, max_depth=10, random_state=0)
rf.fit(answer,y_train)

predict_rf = rf.predict_proba(answer_t)
predict_rf_proba = []
for i in range(len(predict_rf)):
    predict_rf_proba.append(predict_rf[i][1])
    
predict_rf_df = pd.DataFrame(predict_rf_proba,columns=['state']) # creating a dataframe of the results

final_rf_df = pd.concat([col_df,predict_rf_df],ignore_index=False, sort=False,axis=1)
final_rf_df.to_csv("output_rf_predict_proba_scaled.csv",index=False)
result_dict["RandomForest_Classifier_predict_proba_scaled"] = mean_std_cross_val_scores(rf, answer, y_train, cv=5, return_train_score=True)

# %% [markdown]
# ### Testing the performance of predict_proba

# %%
#Gradient Boosting
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=1, random_state=0)
gbc.fit(X_train,y_train)

predict_gbc = gbc.predict_proba(X_test)
predict_gbc_proba = []
for i in range(len(predict_gbc)):
    predict_gbc_proba.append(predict_gbc[i][1])

predict_gbc_df = pd.DataFrame(predict_gbc_proba,columns=['state']) # creating a dataframe of the results
final_gbc_df = pd.concat([col_df,predict_gbc_df],ignore_index=False, sort=False,axis=1)
final_gbc_df.to_csv("Results/output_gbc_proba.csv",index=False)


result_dict["GradBoost_Classifier_predict_proba"] = mean_std_cross_val_scores(gbc, X_train, y_train, cv=5, return_train_score=True)
pd.DataFrame(result_dict).T
# Out:
#                                                        fit_time  \
# Dummy_Classifer                               0.002 (+/- 0.000)
# DecitionTree_Classifier                       0.264 (+/- 0.003)
# GNB_Classifier                                0.007 (+/- 0.000)
# LogisticR_Classifier                          0.049 (+/- 0.003)
# RandomForest_Classifier                       2.683 (+/- 0.034)
# GradBoost_Classifier                          1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled  2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba            1.790 (+/- 0.005)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)

# %%
#Random Forest
rf = RandomForestClassifier(n_estimators = 100, max_depth=10, random_state=0)
rf.fit(X_train,y_train)

predict_rf = rf.predict_proba(X_test)
predict_rf_proba = []
for i in range(len(predict_rf)):
    predict_rf_proba.append(predict_rf[i][1])
    
predict_rf_df = pd.DataFrame(predict_rf_proba,columns=['state']) # creating a dataframe of the results

final_rf_df = pd.concat([col_df,predict_rf_df],ignore_index=False, sort=False,axis=1)
final_rf_df.to_csv("Results/output_rf_predict_proba.csv",index=False)
result_dict["RandomForest_Classifier_predict_proba"] = mean_std_cross_val_scores(rf, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                        fit_time  \
# Dummy_Classifer                               0.002 (+/- 0.000)
# DecitionTree_Classifier                       0.264 (+/- 0.003)
# GNB_Classifier                                0.007 (+/- 0.000)
# LogisticR_Classifier                          0.049 (+/- 0.003)
# RandomForest_Classifier                       2.683 (+/- 0.034)
# GradBoost_Classifier                          1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled  2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba            1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba         2.569 (+/- 0.005)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)

# %% [markdown]
# The kaggle score clearly improved when we used the predict_proba function. However, there were no changes in the model. In other words, the model was not improved in any sort of way. Since the task was provide classification and not the probabilities we decied not to pursue this path.

# %%
# CATboost
cb = CatBoostClassifier(random_state=0)
cb.fit(X_train,y_train)

predict_cb = cb.predict(X_test)
predict_cb_df = pd.DataFrame(predict_cb,columns=['state']) # creating a dataframe of the results

final_cb_df = pd.concat([col_df,predict_cb_df],ignore_index=False, sort=False,axis=1)
final_cb_df.to_csv("Results/output_catboost.csv",index=False)
result_dict["CATBoost_Classifier"] = mean_std_cross_val_scores(cb, X_train, y_train, cv=5, return_train_score=True)
# Out:
# Learning rate set to 0.04139
# 0:	learn: 0.6879476	total: 151ms	remaining: 2m 30s
# 1:	learn: 0.6832365	total: 156ms	remaining: 1m 17s
# 2:	learn: 0.6789200	total: 161ms	remaining: 53.6s
# 3:	learn: 0.6746342	total: 166ms	remaining: 41.4s
# 4:	learn: 0.6707278	total: 172ms	remaining: 34.2s
# 5:	learn: 0.6668593	total: 178ms	remaining: 29.4s
# 6:	learn: 0.6631236	total: 183ms	remaining: 25.9s
# 7:	learn: 0.6599042	total: 188ms	remaining: 23.3s
# 8:	learn: 0.6565385	total: 194ms	remaining: 21.3s
# 9:	learn: 0.6535577	total: 199ms	remaining: 19.7s
# 10:	learn: 0.6508196	total: 204ms	remaining: 18.3s
# 11:	learn: 0.6480229	total: 209ms	remaining: 17.2s
# 12:	learn: 0.6455043	total: 215ms	remaining: 16.3s
# 13:	learn: 0.6430186	total: 221ms	remaining: 15.6s
# 14:	learn: 0.6407470	total: 226ms	remaining: 14.9s
# 15:	learn: 0.6387911	total: 231ms	remaining: 14.2s
# 16:	learn: 0.6366498	total: 237ms	remaining: 13.7s
# 17:	learn: 0.6347020	total: 242ms	remaining: 13.2s
# 18:	learn: 0.6327167	total: 248ms	remaining: 12.8s
# 19:	learn: 0.6308451	total: 253ms	remaining: 12.4s
# 20:	learn: 0.6289468	total: 258ms	remaining: 12s
# 21:	learn: 0.6273186	total: 264ms	remaining: 11.7s
# 22:	learn: 0.6253985	total: 269ms	remaining: 11.4s
# 23:	learn: 0.6238813	total: 274ms	remaining: 11.1s
# 24:	learn: 0.6223302	total: 280ms	remaining: 10.9s
# 25:	learn: 0.6208891	total: 287ms	remaining: 10.8s
# 26:	learn: 0.6193671	total: 292ms	remaining: 10.5s
# 27:	learn: 0.6177819	total: 297ms	remaining: 10.3s
# 28:	learn: 0.6163718	total: 302ms	remaining: 10.1s
# 29:	learn: 0.6151960	total: 308ms	remaining: 9.96s
# 30:	learn: 0.6138611	total: 313ms	remaining: 9.78s
# 31:	learn: 0.6126656	total: 317ms	remaining: 9.6s
# 32:	learn: 0.6115633	total: 322ms	remaining: 9.45s
# 33:	learn: 0.6104552	total: 328ms	remaining: 9.31s
# 34:	learn: 0.6093004	total: 332ms	remaining: 9.16s
# 35:	learn: 0.6081752	total: 338ms	remaining: 9.04s
# 36:	learn: 0.6071906	total: 343ms	remaining: 8.93s
# 37:	learn: 0.6060816	total: 348ms	remaining: 8.81s
# 38:	learn: 0.6049679	total: 353ms	remaining: 8.71s
# 39:	learn: 0.6040083	total: 358ms	remaining: 8.59s
# 40:	learn: 0.6031115	total: 363ms	remaining: 8.49s
# 41:	learn: 0.6021189	total: 368ms	remaining: 8.39s
# 42:	learn: 0.6010438	total: 373ms	remaining: 8.31s
# 43:	learn: 0.6002128	total: 378ms	remaining: 8.22s
# 44:	learn: 0.5994108	total: 384ms	remaining: 8.15s
# 45:	learn: 0.5984482	total: 389ms	remaining: 8.08s
# 46:	learn: 0.5976485	total: 396ms	remaining: 8.03s
# 47:	learn: 0.5969274	total: 402ms	remaining: 7.98s
# 48:	learn: 0.5960215	total: 408ms	remaining: 7.91s
# 49:	learn: 0.5950296	total: 413ms	remaining: 7.84s
# 50:	learn: 0.5942466	total: 417ms	remaining: 7.77s
# 51:	learn: 0.5935798	total: 423ms	remaining: 7.7s
# 52:	learn: 0.5928211	total: 428ms	remaining: 7.64s
# 53:	learn: 0.5921535	total: 433ms	remaining: 7.58s
# 54:	learn: 0.5915021	total: 438ms	remaining: 7.53s
# 55:	learn: 0.5909362	total: 444ms	remaining: 7.48s
# 56:	learn: 0.5903992	total: 449ms	remaining: 7.43s
# 57:	learn: 0.5897026	total: 454ms	remaining: 7.38s
# 58:	learn: 0.5890648	total: 459ms	remaining: 7.32s
# 59:	learn: 0.5885781	total: 464ms	remaining: 7.28s
# 60:	learn: 0.5880376	total: 470ms	remaining: 7.23s
# 61:	learn: 0.5873974	total: 475ms	remaining: 7.19s
# 62:	learn: 0.5868539	total: 480ms	remaining: 7.14s
# 63:	learn: 0.5863734	total: 485ms	remaining: 7.1s
# 64:	learn: 0.5859022	total: 491ms	remaining: 7.06s
# 65:	learn: 0.5853786	total: 495ms	remaining: 7.01s
# 66:	learn: 0.5849648	total: 500ms	remaining: 6.96s
# 67:	learn: 0.5844503	total: 505ms	remaining: 6.92s
# 68:	learn: 0.5839227	total: 510ms	remaining: 6.88s
# 69:	learn: 0.5834644	total: 515ms	remaining: 6.84s
# 70:	learn: 0.5829895	total: 520ms	remaining: 6.8s
# 71:	learn: 0.5825282	total: 525ms	remaining: 6.76s
# 72:	learn: 0.5820282	total: 530ms	remaining: 6.73s
# 73:	learn: 0.5815291	total: 535ms	remaining: 6.7s
# 74:	learn: 0.5810781	total: 540ms	remaining: 6.66s
# 75:	learn: 0.5806128	total: 545ms	remaining: 6.63s
# 76:	learn: 0.5802157	total: 551ms	remaining: 6.6s
# 77:	learn: 0.5794434	total: 556ms	remaining: 6.57s
# 78:	learn: 0.5790704	total: 561ms	remaining: 6.54s
# 79:	learn: 0.5786638	total: 567ms	remaining: 6.52s
# 80:	learn: 0.5781867	total: 572ms	remaining: 6.49s
# 81:	learn: 0.5777165	total: 579ms	remaining: 6.48s
# 82:	learn: 0.5773653	total: 585ms	remaining: 6.46s
# 83:	learn: 0.5768917	total: 591ms	remaining: 6.44s
# 84:	learn: 0.5764439	total: 596ms	remaining: 6.42s
# 85:	learn: 0.5761375	total: 602ms	remaining: 6.4s
# 86:	learn: 0.5757780	total: 608ms	remaining: 6.38s
# 87:	learn: 0.5754456	total: 614ms	remaining: 6.37s
# 88:	learn: 0.5750992	total: 620ms	remaining: 6.35s
# 89:	learn: 0.5747226	total: 626ms	remaining: 6.33s
# 90:	learn: 0.5743227	total: 632ms	remaining: 6.31s
# 91:	learn: 0.5740170	total: 637ms	remaining: 6.28s
# 92:	learn: 0.5736397	total: 642ms	remaining: 6.26s
# 93:	learn: 0.5733052	total: 648ms	remaining: 6.24s
# 94:	learn: 0.5730448	total: 654ms	remaining: 6.23s
# 95:	learn: 0.5727736	total: 661ms	remaining: 6.22s
# 96:	learn: 0.5723979	total: 667ms	remaining: 6.21s
# 97:	learn: 0.5721052	total: 671ms	remaining: 6.18s
# 98:	learn: 0.5718137	total: 677ms	remaining: 6.16s
# 99:	learn: 0.5714975	total: 683ms	remaining: 6.15s
# 100:	learn: 0.5711834	total: 690ms	remaining: 6.14s
# 101:	learn: 0.5708887	total: 696ms	remaining: 6.13s
# 102:	learn: 0.5705369	total: 702ms	remaining: 6.11s
# 103:	learn: 0.5703219	total: 707ms	remaining: 6.09s
# 104:	learn: 0.5699861	total: 712ms	remaining: 6.07s
# 105:	learn: 0.5696353	total: 718ms	remaining: 6.05s
# 106:	learn: 0.5693629	total: 723ms	remaining: 6.04s
# 107:	learn: 0.5691646	total: 728ms	remaining: 6.01s
# 108:	learn: 0.5688890	total: 735ms	remaining: 6s
# 109:	learn: 0.5686415	total: 740ms	remaining: 5.99s
# 110:	learn: 0.5683597	total: 745ms	remaining: 5.97s
# 111:	learn: 0.5681017	total: 750ms	remaining: 5.95s
# 112:	learn: 0.5677768	total: 756ms	remaining: 5.93s
# 113:	learn: 0.5675234	total: 762ms	remaining: 5.92s
# 114:	learn: 0.5672194	total: 768ms	remaining: 5.91s
# 115:	learn: 0.5669891	total: 775ms	remaining: 5.91s
# 116:	learn: 0.5666999	total: 781ms	remaining: 5.9s
# 117:	learn: 0.5664719	total: 788ms	remaining: 5.89s
# 118:	learn: 0.5662288	total: 795ms	remaining: 5.88s
# 119:	learn: 0.5660006	total: 799ms	remaining: 5.86s
# 120:	learn: 0.5657897	total: 806ms	remaining: 5.85s
# 121:	learn: 0.5655856	total: 811ms	remaining: 5.84s
# 122:	learn: 0.5652680	total: 817ms	remaining: 5.83s
# 123:	learn: 0.5649596	total: 823ms	remaining: 5.81s
# 124:	learn: 0.5646163	total: 829ms	remaining: 5.8s
# 125:	learn: 0.5644127	total: 834ms	remaining: 5.79s
# 126:	learn: 0.5641593	total: 840ms	remaining: 5.77s
# 127:	learn: 0.5639062	total: 846ms	remaining: 5.76s
# 128:	learn: 0.5637306	total: 851ms	remaining: 5.75s
# 129:	learn: 0.5634140	total: 857ms	remaining: 5.73s
# 130:	learn: 0.5632430	total: 863ms	remaining: 5.72s
# 131:	learn: 0.5630116	total: 869ms	remaining: 5.71s
# 132:	learn: 0.5628282	total: 876ms	remaining: 5.71s
# 133:	learn: 0.5625827	total: 882ms	remaining: 5.7s
# 134:	learn: 0.5624075	total: 888ms	remaining: 5.69s
# 135:	learn: 0.5622103	total: 894ms	remaining: 5.68s
# 136:	learn: 0.5619716	total: 900ms	remaining: 5.67s
# 137:	learn: 0.5617293	total: 906ms	remaining: 5.66s
# 138:	learn: 0.5614876	total: 911ms	remaining: 5.64s
# 139:	learn: 0.5612726	total: 917ms	remaining: 5.63s
# 140:	learn: 0.5611273	total: 922ms	remaining: 5.62s
# 141:	learn: 0.5609512	total: 928ms	remaining: 5.61s
# 142:	learn: 0.5607147	total: 933ms	remaining: 5.59s
# 143:	learn: 0.5604425	total: 939ms	remaining: 5.58s
# 144:	learn: 0.5602050	total: 944ms	remaining: 5.57s
# 145:	learn: 0.5599448	total: 950ms	remaining: 5.56s
# 146:	learn: 0.5597845	total: 955ms	remaining: 5.54s
# 147:	learn: 0.5596115	total: 960ms	remaining: 5.53s
# 148:	learn: 0.5593756	total: 967ms	remaining: 5.52s
# 149:	learn: 0.5591517	total: 974ms	remaining: 5.52s
# 150:	learn: 0.5589659	total: 980ms	remaining: 5.51s
# 151:	learn: 0.5587636	total: 986ms	remaining: 5.5s
# 152:	learn: 0.5586304	total: 992ms	remaining: 5.49s
# 153:	learn: 0.5584365	total: 998ms	remaining: 5.48s
# 154:	learn: 0.5582435	total: 1s	remaining: 5.47s
# 155:	learn: 0.5580615	total: 1.01s	remaining: 5.46s
# 156:	learn: 0.5578254	total: 1.02s	remaining: 5.46s
# 157:	learn: 0.5573668	total: 1.02s	remaining: 5.45s
# 158:	learn: 0.5572104	total: 1.03s	remaining: 5.44s
# 159:	learn: 0.5570262	total: 1.03s	remaining: 5.43s
# 160:	learn: 0.5568213	total: 1.04s	remaining: 5.42s
# 161:	learn: 0.5566808	total: 1.05s	remaining: 5.41s
# 162:	learn: 0.5564786	total: 1.05s	remaining: 5.4s
# 163:	learn: 0.5562982	total: 1.06s	remaining: 5.4s
# 164:	learn: 0.5560475	total: 1.06s	remaining: 5.39s
# 165:	learn: 0.5558884	total: 1.07s	remaining: 5.38s
# 166:	learn: 0.5556688	total: 1.08s	remaining: 5.37s
# 167:	learn: 0.5554077	total: 1.08s	remaining: 5.36s
# 168:	learn: 0.5553214	total: 1.09s	remaining: 5.35s
# 169:	learn: 0.5551396	total: 1.09s	remaining: 5.33s
# 170:	learn: 0.5549138	total: 1.1s	remaining: 5.32s
# 171:	learn: 0.5547332	total: 1.1s	remaining: 5.31s
# 172:	learn: 0.5545197	total: 1.11s	remaining: 5.3s
# 173:	learn: 0.5543357	total: 1.12s	remaining: 5.3s
# 174:	learn: 0.5541460	total: 1.12s	remaining: 5.29s
# 175:	learn: 0.5539508	total: 1.13s	remaining: 5.29s
# 176:	learn: 0.5537494	total: 1.14s	remaining: 5.28s
# 177:	learn: 0.5535222	total: 1.14s	remaining: 5.27s
# 178:	learn: 0.5533445	total: 1.15s	remaining: 5.27s
# 179:	learn: 0.5531685	total: 1.15s	remaining: 5.26s
# 180:	learn: 0.5530172	total: 1.16s	remaining: 5.25s
# 181:	learn: 0.5528273	total: 1.17s	remaining: 5.24s
# 182:	learn: 0.5526079	total: 1.17s	remaining: 5.23s
# 183:	learn: 0.5525009	total: 1.18s	remaining: 5.22s
# 184:	learn: 0.5523864	total: 1.18s	remaining: 5.21s
# 185:	learn: 0.5521362	total: 1.19s	remaining: 5.2s
# 186:	learn: 0.5519995	total: 1.19s	remaining: 5.18s
# 187:	learn: 0.5518363	total: 1.2s	remaining: 5.17s
# 188:	learn: 0.5517251	total: 1.2s	remaining: 5.16s
# 189:	learn: 0.5515860	total: 1.21s	remaining: 5.15s
# 190:	learn: 0.5514027	total: 1.21s	remaining: 5.14s
# 191:	learn: 0.5512424	total: 1.22s	remaining: 5.13s
# 192:	learn: 0.5511068	total: 1.22s	remaining: 5.12s
# 193:	learn: 0.5509118	total: 1.23s	remaining: 5.1s
# 194:	learn: 0.5507383	total: 1.23s	remaining: 5.09s
# 195:	learn: 0.5505887	total: 1.24s	remaining: 5.08s
# 196:	learn: 0.5504408	total: 1.24s	remaining: 5.07s
# 197:	learn: 0.5501295	total: 1.25s	remaining: 5.06s
# 198:	learn: 0.5499583	total: 1.25s	remaining: 5.05s
# 199:	learn: 0.5497510	total: 1.26s	remaining: 5.04s
# 200:	learn: 0.5496589	total: 1.26s	remaining: 5.03s
# 201:	learn: 0.5494918	total: 1.27s	remaining: 5.01s
# 202:	learn: 0.5493010	total: 1.27s	remaining: 5s
# 203:	learn: 0.5490573	total: 1.28s	remaining: 4.99s
# 204:	learn: 0.5488502	total: 1.28s	remaining: 4.98s
# 205:	learn: 0.5486841	total: 1.29s	remaining: 4.97s
# 206:	learn: 0.5485390	total: 1.29s	remaining: 4.96s
# 207:	learn: 0.5483492	total: 1.3s	remaining: 4.95s
# 208:	learn: 0.5482111	total: 1.3s	remaining: 4.94s
# 209:	learn: 0.5480745	total: 1.31s	remaining: 4.93s
# 210:	learn: 0.5479359	total: 1.31s	remaining: 4.92s
# 211:	learn: 0.5477877	total: 1.32s	remaining: 4.91s
# 212:	learn: 0.5476084	total: 1.33s	remaining: 4.9s
# 213:	learn: 0.5474845	total: 1.33s	remaining: 4.89s
# 214:	learn: 0.5473220	total: 1.34s	remaining: 4.88s
# 215:	learn: 0.5471027	total: 1.34s	remaining: 4.87s
# 216:	learn: 0.5469364	total: 1.35s	remaining: 4.86s
# 217:	learn: 0.5467690	total: 1.35s	remaining: 4.85s
# 218:	learn: 0.5465785	total: 1.36s	remaining: 4.84s
# 219:	learn: 0.5464352	total: 1.36s	remaining: 4.83s
# 220:	learn: 0.5463342	total: 1.37s	remaining: 4.82s
# 221:	learn: 0.5462345	total: 1.37s	remaining: 4.81s
# 222:	learn: 0.5460929	total: 1.38s	remaining: 4.8s
# 223:	learn: 0.5459590	total: 1.38s	remaining: 4.79s
# 224:	learn: 0.5458490	total: 1.39s	remaining: 4.78s
# 225:	learn: 0.5456881	total: 1.39s	remaining: 4.77s
# 226:	learn: 0.5455520	total: 1.4s	remaining: 4.76s
# 227:	learn: 0.5451409	total: 1.4s	remaining: 4.75s
# 228:	learn: 0.5450080	total: 1.41s	remaining: 4.74s
# 229:	learn: 0.5448973	total: 1.41s	remaining: 4.73s
# 230:	learn: 0.5446088	total: 1.42s	remaining: 4.72s
# 231:	learn: 0.5444458	total: 1.42s	remaining: 4.71s
# 232:	learn: 0.5443106	total: 1.43s	remaining: 4.71s
# 233:	learn: 0.5441597	total: 1.44s	remaining: 4.7s
# 234:	learn: 0.5440100	total: 1.44s	remaining: 4.69s
# 235:	learn: 0.5438386	total: 1.45s	remaining: 4.68s
# 236:	learn: 0.5436946	total: 1.45s	remaining: 4.67s
# 237:	learn: 0.5435740	total: 1.46s	remaining: 4.66s
# 238:	learn: 0.5433953	total: 1.46s	remaining: 4.66s
# 239:	learn: 0.5432413	total: 1.47s	remaining: 4.65s
# 240:	learn: 0.5430394	total: 1.47s	remaining: 4.64s
# 241:	learn: 0.5428788	total: 1.48s	remaining: 4.63s
# 242:	learn: 0.5427068	total: 1.48s	remaining: 4.62s
# 243:	learn: 0.5423602	total: 1.49s	remaining: 4.61s
# 244:	learn: 0.5422153	total: 1.49s	remaining: 4.6s
# 245:	learn: 0.5420682	total: 1.5s	remaining: 4.59s
# 246:	learn: 0.5418979	total: 1.5s	remaining: 4.59s
# 247:	learn: 0.5417847	total: 1.51s	remaining: 4.58s
# 248:	learn: 0.5416469	total: 1.51s	remaining: 4.57s
# 249:	learn: 0.5414842	total: 1.52s	remaining: 4.56s
# 250:	learn: 0.5412420	total: 1.52s	remaining: 4.55s
# 251:	learn: 0.5410562	total: 1.53s	remaining: 4.54s
# 252:	learn: 0.5409032	total: 1.53s	remaining: 4.53s
# 253:	learn: 0.5407354	total: 1.54s	remaining: 4.52s
# 254:	learn: 0.5405311	total: 1.55s	remaining: 4.52s
# 255:	learn: 0.5404088	total: 1.55s	remaining: 4.51s
# 256:	learn: 0.5402589	total: 1.55s	remaining: 4.5s
# 257:	learn: 0.5401172	total: 1.56s	remaining: 4.49s
# 258:	learn: 0.5400029	total: 1.56s	remaining: 4.48s
# 259:	learn: 0.5398887	total: 1.57s	remaining: 4.47s
# 260:	learn: 0.5397547	total: 1.57s	remaining: 4.46s
# 261:	learn: 0.5396130	total: 1.58s	remaining: 4.45s
# 262:	learn: 0.5394939	total: 1.58s	remaining: 4.44s
# 263:	learn: 0.5393433	total: 1.59s	remaining: 4.43s
# 264:	learn: 0.5391553	total: 1.59s	remaining: 4.42s
# 265:	learn: 0.5389957	total: 1.6s	remaining: 4.41s
# 266:	learn: 0.5388268	total: 1.6s	remaining: 4.41s
# 267:	learn: 0.5386313	total: 1.61s	remaining: 4.39s
# 268:	learn: 0.5384090	total: 1.61s	remaining: 4.39s
# 269:	learn: 0.5382544	total: 1.62s	remaining: 4.38s
# 270:	learn: 0.5380415	total: 1.62s	remaining: 4.37s
# 271:	learn: 0.5378597	total: 1.63s	remaining: 4.36s
# 272:	learn: 0.5377333	total: 1.63s	remaining: 4.35s
# 273:	learn: 0.5375653	total: 1.64s	remaining: 4.35s
# 274:	learn: 0.5373990	total: 1.65s	remaining: 4.34s
# 275:	learn: 0.5372362	total: 1.65s	remaining: 4.33s
# 276:	learn: 0.5369887	total: 1.66s	remaining: 4.33s
# 277:	learn: 0.5368464	total: 1.66s	remaining: 4.32s
# 278:	learn: 0.5367154	total: 1.67s	remaining: 4.31s
# 279:	learn: 0.5365752	total: 1.67s	remaining: 4.3s
# 280:	learn: 0.5364314	total: 1.68s	remaining: 4.29s
# 281:	learn: 0.5360849	total: 1.68s	remaining: 4.28s
# 282:	learn: 0.5359277	total: 1.69s	remaining: 4.28s
# 283:	learn: 0.5357974	total: 1.69s	remaining: 4.27s
# 284:	learn: 0.5356699	total: 1.7s	remaining: 4.26s
# 285:	learn: 0.5354983	total: 1.71s	remaining: 4.26s
# 286:	learn: 0.5353575	total: 1.71s	remaining: 4.25s
# 287:	learn: 0.5352082	total: 1.72s	remaining: 4.24s
# 288:	learn: 0.5350479	total: 1.72s	remaining: 4.23s
# 289:	learn: 0.5347096	total: 1.73s	remaining: 4.23s
# 290:	learn: 0.5345529	total: 1.73s	remaining: 4.22s
# 291:	learn: 0.5344256	total: 1.74s	remaining: 4.21s
# 292:	learn: 0.5342038	total: 1.74s	remaining: 4.2s
# 293:	learn: 0.5340516	total: 1.75s	remaining: 4.2s
# 294:	learn: 0.5338341	total: 1.75s	remaining: 4.19s
# 295:	learn: 0.5337101	total: 1.76s	remaining: 4.18s
# 296:	learn: 0.5335937	total: 1.76s	remaining: 4.17s
# 297:	learn: 0.5334647	total: 1.77s	remaining: 4.17s
# 298:	learn: 0.5333068	total: 1.77s	remaining: 4.16s
# 299:	learn: 0.5332035	total: 1.78s	remaining: 4.15s
# 300:	learn: 0.5331178	total: 1.78s	remaining: 4.14s
# 301:	learn: 0.5329440	total: 1.79s	remaining: 4.14s
# 302:	learn: 0.5327848	total: 1.79s	remaining: 4.13s
# 303:	learn: 0.5326053	total: 1.8s	remaining: 4.12s
# 304:	learn: 0.5324661	total: 1.81s	remaining: 4.12s
# 305:	learn: 0.5323088	total: 1.81s	remaining: 4.11s
# 306:	learn: 0.5321806	total: 1.82s	remaining: 4.1s
# 307:	learn: 0.5319262	total: 1.82s	remaining: 4.09s
# 308:	learn: 0.5316955	total: 1.83s	remaining: 4.08s
# 309:	learn: 0.5315680	total: 1.83s	remaining: 4.08s
# 310:	learn: 0.5314244	total: 1.84s	remaining: 4.07s
# 311:	learn: 0.5312729	total: 1.84s	remaining: 4.06s
# 312:	learn: 0.5311538	total: 1.85s	remaining: 4.05s
# 313:	learn: 0.5309891	total: 1.85s	remaining: 4.05s
# 314:	learn: 0.5308145	total: 1.86s	remaining: 4.04s
# 315:	learn: 0.5306416	total: 1.86s	remaining: 4.03s
# 316:	learn: 0.5305451	total: 1.87s	remaining: 4.03s
# 317:	learn: 0.5302198	total: 1.87s	remaining: 4.02s
# 318:	learn: 0.5300454	total: 1.88s	remaining: 4.01s
# 319:	learn: 0.5298623	total: 1.88s	remaining: 4s
# 320:	learn: 0.5297373	total: 1.89s	remaining: 3.99s
# 321:	learn: 0.5295916	total: 1.89s	remaining: 3.99s
# 322:	learn: 0.5294436	total: 1.9s	remaining: 3.98s
# 323:	learn: 0.5293277	total: 1.9s	remaining: 3.97s
# 324:	learn: 0.5291624	total: 1.91s	remaining: 3.96s
# 325:	learn: 0.5290196	total: 1.92s	remaining: 3.96s
# 326:	learn: 0.5289029	total: 1.92s	remaining: 3.95s
# 327:	learn: 0.5287941	total: 1.93s	remaining: 3.94s
# 328:	learn: 0.5286592	total: 1.93s	remaining: 3.94s
# 329:	learn: 0.5282304	total: 1.94s	remaining: 3.93s
# 330:	learn: 0.5280561	total: 1.94s	remaining: 3.92s
# 331:	learn: 0.5279357	total: 1.95s	remaining: 3.92s
# 332:	learn: 0.5277647	total: 1.95s	remaining: 3.91s
# 333:	learn: 0.5275293	total: 1.96s	remaining: 3.9s
# 334:	learn: 0.5274238	total: 1.96s	remaining: 3.89s
# 335:	learn: 0.5272478	total: 1.97s	remaining: 3.89s
# 336:	learn: 0.5271269	total: 1.97s	remaining: 3.88s
# 337:	learn: 0.5269311	total: 1.98s	remaining: 3.88s
# 338:	learn: 0.5267827	total: 1.98s	remaining: 3.87s
# 339:	learn: 0.5266223	total: 1.99s	remaining: 3.86s
# 340:	learn: 0.5265055	total: 2s	remaining: 3.86s
# 341:	learn: 0.5263748	total: 2s	remaining: 3.85s
# 342:	learn: 0.5262539	total: 2.01s	remaining: 3.84s
# 343:	learn: 0.5261509	total: 2.01s	remaining: 3.84s
# 344:	learn: 0.5260134	total: 2.02s	remaining: 3.83s
# 345:	learn: 0.5258945	total: 2.02s	remaining: 3.82s
# 346:	learn: 0.5257470	total: 2.03s	remaining: 3.82s
# 347:	learn: 0.5256081	total: 2.03s	remaining: 3.81s
# 348:	learn: 0.5254419	total: 2.04s	remaining: 3.8s
# 349:	learn: 0.5252482	total: 2.04s	remaining: 3.79s
# 350:	learn: 0.5251012	total: 2.05s	remaining: 3.79s
# 351:	learn: 0.5249840	total: 2.05s	remaining: 3.78s
# 352:	learn: 0.5248455	total: 2.06s	remaining: 3.77s
# 353:	learn: 0.5246974	total: 2.06s	remaining: 3.77s
# 354:	learn: 0.5245909	total: 2.07s	remaining: 3.76s
# 355:	learn: 0.5243143	total: 2.08s	remaining: 3.75s
# 356:	learn: 0.5242130	total: 2.08s	remaining: 3.75s
# 357:	learn: 0.5240683	total: 2.09s	remaining: 3.74s
# 358:	learn: 0.5239565	total: 2.09s	remaining: 3.73s
# 359:	learn: 0.5238515	total: 2.1s	remaining: 3.73s
# 360:	learn: 0.5236779	total: 2.1s	remaining: 3.72s
# 361:	learn: 0.5234765	total: 2.11s	remaining: 3.71s
# 362:	learn: 0.5233020	total: 2.11s	remaining: 3.71s
# 363:	learn: 0.5231798	total: 2.12s	remaining: 3.7s
# 364:	learn: 0.5230256	total: 2.12s	remaining: 3.69s
# 365:	learn: 0.5228886	total: 2.13s	remaining: 3.69s
# 366:	learn: 0.5227456	total: 2.13s	remaining: 3.68s
# 367:	learn: 0.5226476	total: 2.14s	remaining: 3.67s
# 368:	learn: 0.5225001	total: 2.15s	remaining: 3.67s
# 369:	learn: 0.5223643	total: 2.15s	remaining: 3.66s
# 370:	learn: 0.5222461	total: 2.16s	remaining: 3.66s
# 371:	learn: 0.5221363	total: 2.16s	remaining: 3.65s
# 372:	learn: 0.5219680	total: 2.17s	remaining: 3.65s
# 373:	learn: 0.5218564	total: 2.17s	remaining: 3.64s
# 374:	learn: 0.5217164	total: 2.18s	remaining: 3.63s
# 375:	learn: 0.5215604	total: 2.19s	remaining: 3.63s
# 376:	learn: 0.5214232	total: 2.19s	remaining: 3.62s
# 377:	learn: 0.5212772	total: 2.2s	remaining: 3.61s
# 378:	learn: 0.5211345	total: 2.2s	remaining: 3.61s
# 379:	learn: 0.5209423	total: 2.21s	remaining: 3.6s
# 380:	learn: 0.5206010	total: 2.21s	remaining: 3.6s
# 381:	learn: 0.5204750	total: 2.22s	remaining: 3.59s
# 382:	learn: 0.5203606	total: 2.22s	remaining: 3.58s
# 383:	learn: 0.5202275	total: 2.23s	remaining: 3.58s
# 384:	learn: 0.5200954	total: 2.23s	remaining: 3.57s
# 385:	learn: 0.5200068	total: 2.24s	remaining: 3.56s
# 386:	learn: 0.5198789	total: 2.25s	remaining: 3.56s
# 387:	learn: 0.5197463	total: 2.25s	remaining: 3.55s
# 388:	learn: 0.5195177	total: 2.26s	remaining: 3.54s
# 389:	learn: 0.5193416	total: 2.26s	remaining: 3.54s
# 390:	learn: 0.5191937	total: 2.27s	remaining: 3.53s
# 391:	learn: 0.5190937	total: 2.27s	remaining: 3.52s
# 392:	learn: 0.5189224	total: 2.28s	remaining: 3.52s
# 393:	learn: 0.5188270	total: 2.28s	remaining: 3.51s
# 394:	learn: 0.5186953	total: 2.29s	remaining: 3.5s
# 395:	learn: 0.5185639	total: 2.29s	remaining: 3.5s
# 396:	learn: 0.5184760	total: 2.3s	remaining: 3.49s
# 397:	learn: 0.5183043	total: 2.3s	remaining: 3.48s
# 398:	learn: 0.5182094	total: 2.31s	remaining: 3.48s
# 399:	learn: 0.5180923	total: 2.31s	remaining: 3.47s
# 400:	learn: 0.5179770	total: 2.32s	remaining: 3.46s
# 401:	learn: 0.5178435	total: 2.32s	remaining: 3.46s
# 402:	learn: 0.5176860	total: 2.33s	remaining: 3.45s
# 403:	learn: 0.5175481	total: 2.33s	remaining: 3.44s
# 404:	learn: 0.5174272	total: 2.34s	remaining: 3.44s
# 405:	learn: 0.5173177	total: 2.35s	remaining: 3.43s
# 406:	learn: 0.5171901	total: 2.35s	remaining: 3.42s
# 407:	learn: 0.5170872	total: 2.36s	remaining: 3.42s
# 408:	learn: 0.5169697	total: 2.36s	remaining: 3.41s
# 409:	learn: 0.5168228	total: 2.37s	remaining: 3.4s
# 410:	learn: 0.5167305	total: 2.37s	remaining: 3.4s
# 411:	learn: 0.5166047	total: 2.38s	remaining: 3.39s
# 412:	learn: 0.5164672	total: 2.38s	remaining: 3.38s
# 413:	learn: 0.5162986	total: 2.39s	remaining: 3.38s
# 414:	learn: 0.5161530	total: 2.39s	remaining: 3.37s
# 415:	learn: 0.5160618	total: 2.4s	remaining: 3.37s
# 416:	learn: 0.5158683	total: 2.4s	remaining: 3.36s
# 417:	learn: 0.5157056	total: 2.41s	remaining: 3.35s
# 418:	learn: 0.5154419	total: 2.41s	remaining: 3.35s
# 419:	learn: 0.5152896	total: 2.42s	remaining: 3.34s
# 420:	learn: 0.5151622	total: 2.42s	remaining: 3.33s
# 421:	learn: 0.5150416	total: 2.43s	remaining: 3.33s
# 422:	learn: 0.5148568	total: 2.44s	remaining: 3.32s
# 423:	learn: 0.5147685	total: 2.44s	remaining: 3.31s
# 424:	learn: 0.5146395	total: 2.44s	remaining: 3.31s
# 425:	learn: 0.5144842	total: 2.45s	remaining: 3.3s
# 426:	learn: 0.5143958	total: 2.46s	remaining: 3.29s
# 427:	learn: 0.5142747	total: 2.46s	remaining: 3.29s
# 428:	learn: 0.5141816	total: 2.47s	remaining: 3.28s
# 429:	learn: 0.5140806	total: 2.47s	remaining: 3.27s
# 430:	learn: 0.5139545	total: 2.48s	remaining: 3.27s
# 431:	learn: 0.5138548	total: 2.48s	remaining: 3.26s
# 432:	learn: 0.5137604	total: 2.49s	remaining: 3.26s
# 433:	learn: 0.5136242	total: 2.49s	remaining: 3.25s
# 434:	learn: 0.5134786	total: 2.5s	remaining: 3.24s
# 435:	learn: 0.5133858	total: 2.5s	remaining: 3.24s
# 436:	learn: 0.5132792	total: 2.51s	remaining: 3.23s
# 437:	learn: 0.5131286	total: 2.51s	remaining: 3.22s
# 438:	learn: 0.5129426	total: 2.52s	remaining: 3.22s
# 439:	learn: 0.5127797	total: 2.52s	remaining: 3.21s
# 440:	learn: 0.5126291	total: 2.53s	remaining: 3.2s
# 441:	learn: 0.5125412	total: 2.53s	remaining: 3.2s
# 442:	learn: 0.5124292	total: 2.54s	remaining: 3.19s
# 443:	learn: 0.5123012	total: 2.54s	remaining: 3.19s
# 444:	learn: 0.5121517	total: 2.55s	remaining: 3.18s
# 445:	learn: 0.5119935	total: 2.55s	remaining: 3.17s
# 446:	learn: 0.5118422	total: 2.56s	remaining: 3.17s
# 447:	learn: 0.5117144	total: 2.56s	remaining: 3.16s
# 448:	learn: 0.5115221	total: 2.57s	remaining: 3.15s
# 449:	learn: 0.5114088	total: 2.58s	remaining: 3.15s
# 450:	learn: 0.5113011	total: 2.58s	remaining: 3.14s
# 451:	learn: 0.5110051	total: 2.59s	remaining: 3.14s
# 452:	learn: 0.5107999	total: 2.59s	remaining: 3.13s
# 453:	learn: 0.5106275	total: 2.6s	remaining: 3.12s
# 454:	learn: 0.5105410	total: 2.6s	remaining: 3.12s
# 455:	learn: 0.5103983	total: 2.61s	remaining: 3.11s
# 456:	learn: 0.5102533	total: 2.61s	remaining: 3.1s
# 457:	learn: 0.5101456	total: 2.62s	remaining: 3.1s
# 458:	learn: 0.5100489	total: 2.62s	remaining: 3.09s
# 459:	learn: 0.5099468	total: 2.63s	remaining: 3.09s
# 460:	learn: 0.5098445	total: 2.63s	remaining: 3.08s
# 461:	learn: 0.5096937	total: 2.64s	remaining: 3.07s
# 462:	learn: 0.5095692	total: 2.65s	remaining: 3.07s
# 463:	learn: 0.5094600	total: 2.65s	remaining: 3.06s
# 464:	learn: 0.5093022	total: 2.66s	remaining: 3.06s
# 465:	learn: 0.5091920	total: 2.66s	remaining: 3.05s
# 466:	learn: 0.5090223	total: 2.67s	remaining: 3.04s
# 467:	learn: 0.5087783	total: 2.67s	remaining: 3.04s
# 468:	learn: 0.5086255	total: 2.68s	remaining: 3.03s
# 469:	learn: 0.5084732	total: 2.68s	remaining: 3.02s
# 470:	learn: 0.5083473	total: 2.69s	remaining: 3.02s
# 471:	learn: 0.5082698	total: 2.69s	remaining: 3.01s
# 472:	learn: 0.5080973	total: 2.7s	remaining: 3.01s
# 473:	learn: 0.5079875	total: 2.71s	remaining: 3s
# 474:	learn: 0.5078219	total: 2.71s	remaining: 3s
# 475:	learn: 0.5077086	total: 2.71s	remaining: 2.99s
# 476:	learn: 0.5075874	total: 2.72s	remaining: 2.98s
# 477:	learn: 0.5074517	total: 2.73s	remaining: 2.98s
# 478:	learn: 0.5073184	total: 2.73s	remaining: 2.97s
# 479:	learn: 0.5071924	total: 2.74s	remaining: 2.96s
# 480:	learn: 0.5071149	total: 2.74s	remaining: 2.96s
# 481:	learn: 0.5069570	total: 2.75s	remaining: 2.95s
# 482:	learn: 0.5068434	total: 2.75s	remaining: 2.94s
# 483:	learn: 0.5067759	total: 2.76s	remaining: 2.94s
# 484:	learn: 0.5065467	total: 2.76s	remaining: 2.93s
# 485:	learn: 0.5063804	total: 2.77s	remaining: 2.93s
# 486:	learn: 0.5061994	total: 2.77s	remaining: 2.92s
# 487:	learn: 0.5060804	total: 2.78s	remaining: 2.92s
# 488:	learn: 0.5059468	total: 2.78s	remaining: 2.91s
# 489:	learn: 0.5058251	total: 2.79s	remaining: 2.9s
# 490:	learn: 0.5056809	total: 2.79s	remaining: 2.9s
# 491:	learn: 0.5055237	total: 2.8s	remaining: 2.89s
# 492:	learn: 0.5054309	total: 2.8s	remaining: 2.88s
# 493:	learn: 0.5052927	total: 2.81s	remaining: 2.88s
# 494:	learn: 0.5051799	total: 2.81s	remaining: 2.87s
# 495:	learn: 0.5050273	total: 2.82s	remaining: 2.86s
# 496:	learn: 0.5048695	total: 2.82s	remaining: 2.86s
# 497:	learn: 0.5047554	total: 2.83s	remaining: 2.85s
# 498:	learn: 0.5046624	total: 2.83s	remaining: 2.85s
# 499:	learn: 0.5045357	total: 2.84s	remaining: 2.84s
# 500:	learn: 0.5043969	total: 2.85s	remaining: 2.83s
# 501:	learn: 0.5043242	total: 2.85s	remaining: 2.83s
# 502:	learn: 0.5041857	total: 2.86s	remaining: 2.82s
# 503:	learn: 0.5038852	total: 2.86s	remaining: 2.82s
# 504:	learn: 0.5037698	total: 2.87s	remaining: 2.81s
# 505:	learn: 0.5036947	total: 2.87s	remaining: 2.8s
# 506:	learn: 0.5035824	total: 2.88s	remaining: 2.8s
# 507:	learn: 0.5034637	total: 2.88s	remaining: 2.79s
# 508:	learn: 0.5033260	total: 2.89s	remaining: 2.79s
# 509:	learn: 0.5031963	total: 2.89s	remaining: 2.78s
# 510:	learn: 0.5030482	total: 2.9s	remaining: 2.77s
# 511:	learn: 0.5029098	total: 2.9s	remaining: 2.77s
# 512:	learn: 0.5027738	total: 2.91s	remaining: 2.76s
# 513:	learn: 0.5026474	total: 2.91s	remaining: 2.75s
# 514:	learn: 0.5025452	total: 2.92s	remaining: 2.75s
# 515:	learn: 0.5024374	total: 2.92s	remaining: 2.74s
# 516:	learn: 0.5023109	total: 2.93s	remaining: 2.74s
# 517:	learn: 0.5022309	total: 2.94s	remaining: 2.73s
# 518:	learn: 0.5020858	total: 2.94s	remaining: 2.73s
# 519:	learn: 0.5019331	total: 2.95s	remaining: 2.72s
# 520:	learn: 0.5018134	total: 2.95s	remaining: 2.71s
# 521:	learn: 0.5016920	total: 2.96s	remaining: 2.71s
# 522:	learn: 0.5015844	total: 2.96s	remaining: 2.7s
# 523:	learn: 0.5014889	total: 2.97s	remaining: 2.7s
# 524:	learn: 0.5013320	total: 2.97s	remaining: 2.69s
# 525:	learn: 0.5011965	total: 2.98s	remaining: 2.69s
# 526:	learn: 0.5010807	total: 2.98s	remaining: 2.68s
# 527:	learn: 0.5009949	total: 2.99s	remaining: 2.67s
# 528:	learn: 0.5008360	total: 3s	remaining: 2.67s
# 529:	learn: 0.5007484	total: 3s	remaining: 2.66s
# 530:	learn: 0.5006541	total: 3.01s	remaining: 2.66s
# 531:	learn: 0.5004929	total: 3.01s	remaining: 2.65s
# 532:	learn: 0.5003989	total: 3.02s	remaining: 2.64s
# 533:	learn: 0.5002525	total: 3.02s	remaining: 2.64s
# 534:	learn: 0.5001357	total: 3.03s	remaining: 2.63s
# 535:	learn: 0.4998962	total: 3.03s	remaining: 2.63s
# 536:	learn: 0.4997546	total: 3.04s	remaining: 2.62s
# 537:	learn: 0.4996250	total: 3.04s	remaining: 2.61s
# 538:	learn: 0.4995382	total: 3.05s	remaining: 2.61s
# 539:	learn: 0.4994667	total: 3.06s	remaining: 2.6s
# 540:	learn: 0.4993226	total: 3.06s	remaining: 2.6s
# 541:	learn: 0.4991582	total: 3.06s	remaining: 2.59s
# 542:	learn: 0.4990775	total: 3.07s	remaining: 2.58s
# 543:	learn: 0.4989752	total: 3.08s	remaining: 2.58s
# 544:	learn: 0.4988655	total: 3.08s	remaining: 2.57s
# 545:	learn: 0.4987171	total: 3.09s	remaining: 2.57s
# 546:	learn: 0.4986061	total: 3.09s	remaining: 2.56s
# 547:	learn: 0.4985063	total: 3.1s	remaining: 2.56s
# 548:	learn: 0.4984265	total: 3.1s	remaining: 2.55s
# 549:	learn: 0.4983210	total: 3.11s	remaining: 2.54s
# 550:	learn: 0.4982180	total: 3.11s	remaining: 2.54s
# 551:	learn: 0.4980315	total: 3.12s	remaining: 2.53s
# 552:	learn: 0.4979115	total: 3.12s	remaining: 2.52s
# 553:	learn: 0.4977686	total: 3.13s	remaining: 2.52s
# 554:	learn: 0.4976062	total: 3.13s	remaining: 2.51s
# 555:	learn: 0.4974874	total: 3.14s	remaining: 2.51s
# 556:	learn: 0.4973501	total: 3.14s	remaining: 2.5s
# 557:	learn: 0.4972448	total: 3.15s	remaining: 2.49s
# 558:	learn: 0.4971202	total: 3.15s	remaining: 2.49s
# 559:	learn: 0.4969456	total: 3.16s	remaining: 2.48s
# 560:	learn: 0.4968615	total: 3.17s	remaining: 2.48s
# 561:	learn: 0.4967744	total: 3.17s	remaining: 2.47s
# 562:	learn: 0.4967032	total: 3.17s	remaining: 2.46s
# 563:	learn: 0.4965755	total: 3.18s	remaining: 2.46s
# 564:	learn: 0.4964291	total: 3.19s	remaining: 2.45s
# 565:	learn: 0.4962979	total: 3.19s	remaining: 2.45s
# 566:	learn: 0.4961686	total: 3.2s	remaining: 2.44s
# 567:	learn: 0.4960894	total: 3.2s	remaining: 2.43s
# 568:	learn: 0.4959568	total: 3.21s	remaining: 2.43s
# 569:	learn: 0.4957886	total: 3.21s	remaining: 2.42s
# 570:	learn: 0.4956962	total: 3.22s	remaining: 2.42s
# 571:	learn: 0.4956298	total: 3.22s	remaining: 2.41s
# 572:	learn: 0.4955538	total: 3.23s	remaining: 2.4s
# 573:	learn: 0.4954614	total: 3.23s	remaining: 2.4s
# 574:	learn: 0.4953671	total: 3.23s	remaining: 2.39s
# 575:	learn: 0.4952829	total: 3.24s	remaining: 2.38s
# 576:	learn: 0.4951913	total: 3.25s	remaining: 2.38s
# 577:	learn: 0.4950940	total: 3.25s	remaining: 2.37s
# 578:	learn: 0.4949335	total: 3.25s	remaining: 2.37s
# 579:	learn: 0.4948040	total: 3.26s	remaining: 2.36s
# 580:	learn: 0.4946983	total: 3.27s	remaining: 2.35s
# 581:	learn: 0.4945722	total: 3.27s	remaining: 2.35s
# 582:	learn: 0.4944241	total: 3.28s	remaining: 2.34s
# 583:	learn: 0.4943456	total: 3.28s	remaining: 2.34s
# 584:	learn: 0.4942134	total: 3.29s	remaining: 2.33s
# 585:	learn: 0.4941108	total: 3.29s	remaining: 2.33s
# 586:	learn: 0.4940161	total: 3.3s	remaining: 2.32s
# 587:	learn: 0.4939401	total: 3.3s	remaining: 2.31s
# 588:	learn: 0.4938629	total: 3.31s	remaining: 2.31s
# 589:	learn: 0.4937523	total: 3.31s	remaining: 2.3s
# 590:	learn: 0.4936248	total: 3.32s	remaining: 2.3s
# 591:	learn: 0.4935225	total: 3.32s	remaining: 2.29s
# 592:	learn: 0.4933278	total: 3.33s	remaining: 2.28s
# 593:	learn: 0.4932141	total: 3.33s	remaining: 2.28s
# 594:	learn: 0.4931474	total: 3.34s	remaining: 2.27s
# 595:	learn: 0.4930372	total: 3.34s	remaining: 2.27s
# 596:	learn: 0.4929073	total: 3.35s	remaining: 2.26s
# 597:	learn: 0.4928106	total: 3.35s	remaining: 2.25s
# 598:	learn: 0.4926991	total: 3.36s	remaining: 2.25s
# 599:	learn: 0.4925856	total: 3.36s	remaining: 2.24s
# 600:	learn: 0.4924140	total: 3.37s	remaining: 2.24s
# 601:	learn: 0.4923063	total: 3.38s	remaining: 2.23s
# 602:	learn: 0.4922060	total: 3.38s	remaining: 2.23s
# 603:	learn: 0.4920663	total: 3.39s	remaining: 2.22s
# 604:	learn: 0.4919721	total: 3.39s	remaining: 2.21s
# 605:	learn: 0.4918402	total: 3.4s	remaining: 2.21s
# 606:	learn: 0.4917288	total: 3.4s	remaining: 2.2s
# 607:	learn: 0.4915717	total: 3.41s	remaining: 2.2s
# 608:	learn: 0.4914347	total: 3.41s	remaining: 2.19s
# 609:	learn: 0.4913235	total: 3.42s	remaining: 2.18s
# 610:	learn: 0.4912037	total: 3.42s	remaining: 2.18s
# 611:	learn: 0.4910954	total: 3.43s	remaining: 2.17s
# 612:	learn: 0.4910019	total: 3.43s	remaining: 2.17s
# 613:	learn: 0.4909197	total: 3.44s	remaining: 2.16s
# 614:	learn: 0.4908111	total: 3.44s	remaining: 2.15s
# 615:	learn: 0.4906897	total: 3.45s	remaining: 2.15s
# 616:	learn: 0.4905980	total: 3.45s	remaining: 2.14s
# 617:	learn: 0.4905255	total: 3.46s	remaining: 2.14s
# 618:	learn: 0.4904246	total: 3.46s	remaining: 2.13s
# 619:	learn: 0.4902576	total: 3.47s	remaining: 2.13s
# 620:	learn: 0.4901088	total: 3.47s	remaining: 2.12s
# 621:	learn: 0.4900080	total: 3.48s	remaining: 2.11s
# 622:	learn: 0.4899050	total: 3.48s	remaining: 2.11s
# 623:	learn: 0.4898138	total: 3.49s	remaining: 2.1s
# 624:	learn: 0.4897068	total: 3.49s	remaining: 2.1s
# 625:	learn: 0.4896011	total: 3.5s	remaining: 2.09s
# 626:	learn: 0.4894522	total: 3.5s	remaining: 2.08s
# 627:	learn: 0.4893564	total: 3.51s	remaining: 2.08s
# 628:	learn: 0.4892395	total: 3.51s	remaining: 2.07s
# 629:	learn: 0.4891395	total: 3.52s	remaining: 2.07s
# 630:	learn: 0.4890530	total: 3.52s	remaining: 2.06s
# 631:	learn: 0.4889598	total: 3.53s	remaining: 2.05s
# 632:	learn: 0.4888305	total: 3.53s	remaining: 2.05s
# 633:	learn: 0.4887463	total: 3.54s	remaining: 2.04s
# 634:	learn: 0.4886564	total: 3.54s	remaining: 2.04s
# 635:	learn: 0.4885489	total: 3.55s	remaining: 2.03s
# 636:	learn: 0.4884302	total: 3.55s	remaining: 2.02s
# 637:	learn: 0.4883608	total: 3.56s	remaining: 2.02s
# 638:	learn: 0.4882556	total: 3.56s	remaining: 2.01s
# 639:	learn: 0.4881441	total: 3.57s	remaining: 2.01s
# 640:	learn: 0.4880305	total: 3.57s	remaining: 2s
# 641:	learn: 0.4879481	total: 3.58s	remaining: 2s
# 642:	learn: 0.4878391	total: 3.58s	remaining: 1.99s
# 643:	learn: 0.4876963	total: 3.59s	remaining: 1.98s
# 644:	learn: 0.4876251	total: 3.59s	remaining: 1.98s
# 645:	learn: 0.4875158	total: 3.6s	remaining: 1.97s
# 646:	learn: 0.4874433	total: 3.6s	remaining: 1.97s
# 647:	learn: 0.4873264	total: 3.61s	remaining: 1.96s
# 648:	learn: 0.4872298	total: 3.61s	remaining: 1.95s
# 649:	learn: 0.4871397	total: 3.62s	remaining: 1.95s
# 650:	learn: 0.4870314	total: 3.62s	remaining: 1.94s
# 651:	learn: 0.4869584	total: 3.63s	remaining: 1.94s
# 652:	learn: 0.4868772	total: 3.63s	remaining: 1.93s
# 653:	learn: 0.4867810	total: 3.64s	remaining: 1.92s
# 654:	learn: 0.4866844	total: 3.64s	remaining: 1.92s
# 655:	learn: 0.4865826	total: 3.65s	remaining: 1.91s
# 656:	learn: 0.4864291	total: 3.65s	remaining: 1.91s
# 657:	learn: 0.4862704	total: 3.66s	remaining: 1.9s
# 658:	learn: 0.4862162	total: 3.66s	remaining: 1.9s
# 659:	learn: 0.4861312	total: 3.67s	remaining: 1.89s
# 660:	learn: 0.4860193	total: 3.67s	remaining: 1.88s
# 661:	learn: 0.4859001	total: 3.68s	remaining: 1.88s
# 662:	learn: 0.4857457	total: 3.68s	remaining: 1.87s
# 663:	learn: 0.4856407	total: 3.69s	remaining: 1.86s
# 664:	learn: 0.4854905	total: 3.69s	remaining: 1.86s
# 665:	learn: 0.4853741	total: 3.69s	remaining: 1.85s
# 666:	learn: 0.4852977	total: 3.7s	remaining: 1.85s
# 667:	learn: 0.4852158	total: 3.7s	remaining: 1.84s
# 668:	learn: 0.4850446	total: 3.71s	remaining: 1.83s
# 669:	learn: 0.4849254	total: 3.71s	remaining: 1.83s
# 670:	learn: 0.4848210	total: 3.72s	remaining: 1.82s
# 671:	learn: 0.4847235	total: 3.72s	remaining: 1.82s
# 672:	learn: 0.4846502	total: 3.73s	remaining: 1.81s
# 673:	learn: 0.4845802	total: 3.73s	remaining: 1.8s
# 674:	learn: 0.4844459	total: 3.74s	remaining: 1.8s
# 675:	learn: 0.4843375	total: 3.74s	remaining: 1.79s
# 676:	learn: 0.4842530	total: 3.75s	remaining: 1.79s
# 677:	learn: 0.4841632	total: 3.75s	remaining: 1.78s
# 678:	learn: 0.4840809	total: 3.76s	remaining: 1.78s
# 679:	learn: 0.4839959	total: 3.76s	remaining: 1.77s
# 680:	learn: 0.4838820	total: 3.77s	remaining: 1.76s
# 681:	learn: 0.4837955	total: 3.77s	remaining: 1.76s
# 682:	learn: 0.4836857	total: 3.78s	remaining: 1.75s
# 683:	learn: 0.4836129	total: 3.79s	remaining: 1.75s
# 684:	learn: 0.4835168	total: 3.79s	remaining: 1.74s
# 685:	learn: 0.4834230	total: 3.8s	remaining: 1.74s
# 686:	learn: 0.4833253	total: 3.8s	remaining: 1.73s
# 687:	learn: 0.4832483	total: 3.81s	remaining: 1.73s
# 688:	learn: 0.4831665	total: 3.81s	remaining: 1.72s
# 689:	learn: 0.4830417	total: 3.82s	remaining: 1.71s
# 690:	learn: 0.4829870	total: 3.82s	remaining: 1.71s
# 691:	learn: 0.4829164	total: 3.83s	remaining: 1.7s
# 692:	learn: 0.4828217	total: 3.83s	remaining: 1.7s
# 693:	learn: 0.4826662	total: 3.84s	remaining: 1.69s
# 694:	learn: 0.4825680	total: 3.84s	remaining: 1.69s
# 695:	learn: 0.4824126	total: 3.85s	remaining: 1.68s
# 696:	learn: 0.4823378	total: 3.85s	remaining: 1.68s
# 697:	learn: 0.4822329	total: 3.86s	remaining: 1.67s
# 698:	learn: 0.4821626	total: 3.86s	remaining: 1.66s
# 699:	learn: 0.4820789	total: 3.87s	remaining: 1.66s
# 700:	learn: 0.4820026	total: 3.87s	remaining: 1.65s
# 701:	learn: 0.4818939	total: 3.88s	remaining: 1.65s
# 702:	learn: 0.4818035	total: 3.88s	remaining: 1.64s
# 703:	learn: 0.4817114	total: 3.89s	remaining: 1.64s
# 704:	learn: 0.4816172	total: 3.9s	remaining: 1.63s
# 705:	learn: 0.4814587	total: 3.9s	remaining: 1.62s
# 706:	learn: 0.4813432	total: 3.91s	remaining: 1.62s
# 707:	learn: 0.4812595	total: 3.91s	remaining: 1.61s
# 708:	learn: 0.4811913	total: 3.92s	remaining: 1.61s
# 709:	learn: 0.4810835	total: 3.92s	remaining: 1.6s
# 710:	learn: 0.4809694	total: 3.93s	remaining: 1.6s
# 711:	learn: 0.4808387	total: 3.93s	remaining: 1.59s
# 712:	learn: 0.4807146	total: 3.94s	remaining: 1.58s
# 713:	learn: 0.4806223	total: 3.94s	remaining: 1.58s
# 714:	learn: 0.4803614	total: 3.95s	remaining: 1.57s
# 715:	learn: 0.4802694	total: 3.95s	remaining: 1.57s
# 716:	learn: 0.4801637	total: 3.96s	remaining: 1.56s
# 717:	learn: 0.4800591	total: 3.96s	remaining: 1.55s
# 718:	learn: 0.4799560	total: 3.97s	remaining: 1.55s
# 719:	learn: 0.4797503	total: 3.97s	remaining: 1.54s
# 720:	learn: 0.4796496	total: 3.98s	remaining: 1.54s
# 721:	learn: 0.4795708	total: 3.98s	remaining: 1.53s
# 722:	learn: 0.4794674	total: 3.99s	remaining: 1.53s
# 723:	learn: 0.4793733	total: 3.99s	remaining: 1.52s
# 724:	learn: 0.4792666	total: 4s	remaining: 1.51s
# 725:	learn: 0.4792048	total: 4s	remaining: 1.51s
# 726:	learn: 0.4790890	total: 4s	remaining: 1.5s
# 727:	learn: 0.4790062	total: 4.01s	remaining: 1.5s
# 728:	learn: 0.4789001	total: 4.02s	remaining: 1.49s
# 729:	learn: 0.4787984	total: 4.02s	remaining: 1.49s
# 730:	learn: 0.4786690	total: 4.03s	remaining: 1.48s
# 731:	learn: 0.4785434	total: 4.03s	remaining: 1.48s
# 732:	learn: 0.4784918	total: 4.04s	remaining: 1.47s
# 733:	learn: 0.4784183	total: 4.04s	remaining: 1.47s
# 734:	learn: 0.4783018	total: 4.05s	remaining: 1.46s
# 735:	learn: 0.4782039	total: 4.05s	remaining: 1.45s
# 736:	learn: 0.4781099	total: 4.06s	remaining: 1.45s
# 737:	learn: 0.4780181	total: 4.06s	remaining: 1.44s
# 738:	learn: 0.4779204	total: 4.07s	remaining: 1.44s
# 739:	learn: 0.4778293	total: 4.07s	remaining: 1.43s
# 740:	learn: 0.4777095	total: 4.08s	remaining: 1.42s
# 741:	learn: 0.4775651	total: 4.08s	remaining: 1.42s
# 742:	learn: 0.4774369	total: 4.08s	remaining: 1.41s
# 743:	learn: 0.4772961	total: 4.09s	remaining: 1.41s
# 744:	learn: 0.4772018	total: 4.09s	remaining: 1.4s
# 745:	learn: 0.4771509	total: 4.1s	remaining: 1.4s
# 746:	learn: 0.4770288	total: 4.1s	remaining: 1.39s
# 747:	learn: 0.4768937	total: 4.11s	remaining: 1.38s
# 748:	learn: 0.4767860	total: 4.11s	remaining: 1.38s
# 749:	learn: 0.4766800	total: 4.12s	remaining: 1.37s
# 750:	learn: 0.4765855	total: 4.12s	remaining: 1.37s
# 751:	learn: 0.4764625	total: 4.13s	remaining: 1.36s
# 752:	learn: 0.4763400	total: 4.13s	remaining: 1.35s
# 753:	learn: 0.4762391	total: 4.14s	remaining: 1.35s
# 754:	learn: 0.4761301	total: 4.14s	remaining: 1.34s
# 755:	learn: 0.4760255	total: 4.15s	remaining: 1.34s
# 756:	learn: 0.4759252	total: 4.15s	remaining: 1.33s
# 757:	learn: 0.4758098	total: 4.16s	remaining: 1.33s
# 758:	learn: 0.4757669	total: 4.16s	remaining: 1.32s
# 759:	learn: 0.4756630	total: 4.17s	remaining: 1.31s
# 760:	learn: 0.4755602	total: 4.17s	remaining: 1.31s
# 761:	learn: 0.4753587	total: 4.17s	remaining: 1.3s
# 762:	learn: 0.4752283	total: 4.18s	remaining: 1.3s
# 763:	learn: 0.4751342	total: 4.18s	remaining: 1.29s
# 764:	learn: 0.4750696	total: 4.19s	remaining: 1.29s
# 765:	learn: 0.4749621	total: 4.19s	remaining: 1.28s
# 766:	learn: 0.4748775	total: 4.2s	remaining: 1.27s
# 767:	learn: 0.4746932	total: 4.2s	remaining: 1.27s
# 768:	learn: 0.4746127	total: 4.21s	remaining: 1.26s
# 769:	learn: 0.4745009	total: 4.21s	remaining: 1.26s
# 770:	learn: 0.4744038	total: 4.22s	remaining: 1.25s
# 771:	learn: 0.4743549	total: 4.22s	remaining: 1.25s
# 772:	learn: 0.4742410	total: 4.23s	remaining: 1.24s
# 773:	learn: 0.4741710	total: 4.23s	remaining: 1.24s
# 774:	learn: 0.4740239	total: 4.24s	remaining: 1.23s
# 775:	learn: 0.4739244	total: 4.24s	remaining: 1.22s
# 776:	learn: 0.4738033	total: 4.25s	remaining: 1.22s
# 777:	learn: 0.4737316	total: 4.25s	remaining: 1.21s
# 778:	learn: 0.4736515	total: 4.26s	remaining: 1.21s
# 779:	learn: 0.4735376	total: 4.26s	remaining: 1.2s
# 780:	learn: 0.4734556	total: 4.27s	remaining: 1.2s
# 781:	learn: 0.4732897	total: 4.28s	remaining: 1.19s
# 782:	learn: 0.4731786	total: 4.28s	remaining: 1.19s
# 783:	learn: 0.4730948	total: 4.29s	remaining: 1.18s
# 784:	learn: 0.4729764	total: 4.29s	remaining: 1.18s
# 785:	learn: 0.4728991	total: 4.3s	remaining: 1.17s
# 786:	learn: 0.4727861	total: 4.3s	remaining: 1.17s
# 787:	learn: 0.4727042	total: 4.31s	remaining: 1.16s
# 788:	learn: 0.4725966	total: 4.32s	remaining: 1.15s
# 789:	learn: 0.4724845	total: 4.32s	remaining: 1.15s
# 790:	learn: 0.4723696	total: 4.33s	remaining: 1.14s
# 791:	learn: 0.4722560	total: 4.34s	remaining: 1.14s
# 792:	learn: 0.4721520	total: 4.34s	remaining: 1.13s
# 793:	learn: 0.4720557	total: 4.35s	remaining: 1.13s
# 794:	learn: 0.4719343	total: 4.35s	remaining: 1.12s
# 795:	learn: 0.4718363	total: 4.36s	remaining: 1.12s
# 796:	learn: 0.4717199	total: 4.36s	remaining: 1.11s
# 797:	learn: 0.4716259	total: 4.37s	remaining: 1.11s
# 798:	learn: 0.4715376	total: 4.38s	remaining: 1.1s
# 799:	learn: 0.4714284	total: 4.38s	remaining: 1.09s
# 800:	learn: 0.4713213	total: 4.38s	remaining: 1.09s
# 801:	learn: 0.4712127	total: 4.39s	remaining: 1.08s
# 802:	learn: 0.4711003	total: 4.4s	remaining: 1.08s
# 803:	learn: 0.4710154	total: 4.4s	remaining: 1.07s
# 804:	learn: 0.4709305	total: 4.41s	remaining: 1.07s
# 805:	learn: 0.4708282	total: 4.41s	remaining: 1.06s
# 806:	learn: 0.4706782	total: 4.42s	remaining: 1.06s
# 807:	learn: 0.4705432	total: 4.42s	remaining: 1.05s
# 808:	learn: 0.4704228	total: 4.43s	remaining: 1.05s
# 809:	learn: 0.4703215	total: 4.44s	remaining: 1.04s
# 810:	learn: 0.4702454	total: 4.44s	remaining: 1.03s
# 811:	learn: 0.4701794	total: 4.45s	remaining: 1.03s
# 812:	learn: 0.4701046	total: 4.45s	remaining: 1.02s
# 813:	learn: 0.4700246	total: 4.46s	remaining: 1.02s
# 814:	learn: 0.4699553	total: 4.46s	remaining: 1.01s
# 815:	learn: 0.4698552	total: 4.47s	remaining: 1.01s
# 816:	learn: 0.4697598	total: 4.47s	remaining: 1s
# 817:	learn: 0.4696825	total: 4.48s	remaining: 997ms
# 818:	learn: 0.4696122	total: 4.49s	remaining: 992ms
# 819:	learn: 0.4695527	total: 4.49s	remaining: 986ms
# 820:	learn: 0.4694589	total: 4.5s	remaining: 981ms
# 821:	learn: 0.4693882	total: 4.5s	remaining: 975ms
# 822:	learn: 0.4693007	total: 4.51s	remaining: 970ms
# 823:	learn: 0.4691739	total: 4.51s	remaining: 964ms
# 824:	learn: 0.4691064	total: 4.52s	remaining: 959ms
# 825:	learn: 0.4690260	total: 4.53s	remaining: 953ms
# 826:	learn: 0.4689476	total: 4.53s	remaining: 948ms
# 827:	learn: 0.4688591	total: 4.54s	remaining: 943ms
# 828:	learn: 0.4687325	total: 4.54s	remaining: 937ms
# 829:	learn: 0.4686835	total: 4.55s	remaining: 932ms
# 830:	learn: 0.4685974	total: 4.55s	remaining: 926ms
# 831:	learn: 0.4685108	total: 4.56s	remaining: 921ms
# 832:	learn: 0.4684131	total: 4.56s	remaining: 915ms
# 833:	learn: 0.4683217	total: 4.57s	remaining: 910ms
# 834:	learn: 0.4682321	total: 4.58s	remaining: 904ms
# 835:	learn: 0.4681464	total: 4.58s	remaining: 899ms
# 836:	learn: 0.4680714	total: 4.59s	remaining: 893ms
# 837:	learn: 0.4680009	total: 4.59s	remaining: 888ms
# 838:	learn: 0.4678455	total: 4.6s	remaining: 882ms
# 839:	learn: 0.4677796	total: 4.6s	remaining: 877ms
# 840:	learn: 0.4676377	total: 4.61s	remaining: 872ms
# 841:	learn: 0.4675565	total: 4.62s	remaining: 866ms
# 842:	learn: 0.4674819	total: 4.62s	remaining: 861ms
# 843:	learn: 0.4673569	total: 4.63s	remaining: 856ms
# 844:	learn: 0.4672245	total: 4.63s	remaining: 850ms
# 845:	learn: 0.4671346	total: 4.64s	remaining: 845ms
# 846:	learn: 0.4670695	total: 4.64s	remaining: 839ms
# 847:	learn: 0.4669673	total: 4.65s	remaining: 834ms
# 848:	learn: 0.4667720	total: 4.66s	remaining: 828ms
# 849:	learn: 0.4667106	total: 4.66s	remaining: 823ms
# 850:	learn: 0.4666133	total: 4.67s	remaining: 817ms
# 851:	learn: 0.4665029	total: 4.67s	remaining: 812ms
# 852:	learn: 0.4663900	total: 4.68s	remaining: 806ms
# 853:	learn: 0.4663297	total: 4.68s	remaining: 801ms
# 854:	learn: 0.4661796	total: 4.69s	remaining: 795ms
# 855:	learn: 0.4660564	total: 4.69s	remaining: 790ms
# 856:	learn: 0.4659937	total: 4.7s	remaining: 784ms
# 857:	learn: 0.4659163	total: 4.7s	remaining: 779ms
# 858:	learn: 0.4658255	total: 4.71s	remaining: 773ms
# 859:	learn: 0.4657031	total: 4.71s	remaining: 768ms
# 860:	learn: 0.4656403	total: 4.72s	remaining: 762ms
# 861:	learn: 0.4655350	total: 4.72s	remaining: 756ms
# 862:	learn: 0.4654580	total: 4.73s	remaining: 751ms
# 863:	learn: 0.4653537	total: 4.73s	remaining: 745ms
# 864:	learn: 0.4652370	total: 4.74s	remaining: 740ms
# 865:	learn: 0.4651365	total: 4.74s	remaining: 734ms
# 866:	learn: 0.4650491	total: 4.75s	remaining: 728ms
# 867:	learn: 0.4649534	total: 4.75s	remaining: 723ms
# 868:	learn: 0.4649016	total: 4.76s	remaining: 717ms
# 869:	learn: 0.4647953	total: 4.76s	remaining: 712ms
# 870:	learn: 0.4646956	total: 4.77s	remaining: 706ms
# 871:	learn: 0.4646286	total: 4.77s	remaining: 701ms
# 872:	learn: 0.4645471	total: 4.78s	remaining: 695ms
# 873:	learn: 0.4644801	total: 4.78s	remaining: 690ms
# 874:	learn: 0.4643471	total: 4.79s	remaining: 684ms
# 875:	learn: 0.4642657	total: 4.79s	remaining: 678ms
# 876:	learn: 0.4641572	total: 4.8s	remaining: 673ms
# 877:	learn: 0.4640871	total: 4.8s	remaining: 667ms
# 878:	learn: 0.4639831	total: 4.81s	remaining: 662ms
# 879:	learn: 0.4638794	total: 4.81s	remaining: 656ms
# 880:	learn: 0.4638053	total: 4.82s	remaining: 651ms
# 881:	learn: 0.4636916	total: 4.82s	remaining: 645ms
# 882:	learn: 0.4635932	total: 4.83s	remaining: 640ms
# 883:	learn: 0.4635139	total: 4.83s	remaining: 634ms
# 884:	learn: 0.4634212	total: 4.84s	remaining: 629ms
# 885:	learn: 0.4633670	total: 4.84s	remaining: 623ms
# 886:	learn: 0.4632942	total: 4.85s	remaining: 618ms
# 887:	learn: 0.4631571	total: 4.85s	remaining: 612ms
# 888:	learn: 0.4630268	total: 4.86s	remaining: 607ms
# 889:	learn: 0.4629430	total: 4.86s	remaining: 601ms
# 890:	learn: 0.4628016	total: 4.87s	remaining: 595ms
# 891:	learn: 0.4627391	total: 4.87s	remaining: 590ms
# 892:	learn: 0.4626041	total: 4.88s	remaining: 584ms
# 893:	learn: 0.4625231	total: 4.88s	remaining: 579ms
# 894:	learn: 0.4624446	total: 4.88s	remaining: 573ms
# 895:	learn: 0.4623155	total: 4.89s	remaining: 568ms
# 896:	learn: 0.4621197	total: 4.89s	remaining: 562ms
# 897:	learn: 0.4619879	total: 4.9s	remaining: 556ms
# 898:	learn: 0.4619234	total: 4.9s	remaining: 551ms
# 899:	learn: 0.4618410	total: 4.91s	remaining: 545ms
# 900:	learn: 0.4617514	total: 4.91s	remaining: 540ms
# 901:	learn: 0.4616700	total: 4.92s	remaining: 534ms
# 902:	learn: 0.4615215	total: 4.92s	remaining: 529ms
# 903:	learn: 0.4614440	total: 4.93s	remaining: 523ms
# 904:	learn: 0.4613024	total: 4.93s	remaining: 518ms
# 905:	learn: 0.4611916	total: 4.94s	remaining: 512ms
# 906:	learn: 0.4611230	total: 4.94s	remaining: 507ms
# 907:	learn: 0.4610360	total: 4.95s	remaining: 501ms
# 908:	learn: 0.4609690	total: 4.95s	remaining: 496ms
# 909:	learn: 0.4608602	total: 4.96s	remaining: 490ms
# 910:	learn: 0.4607774	total: 4.96s	remaining: 485ms
# 911:	learn: 0.4607243	total: 4.96s	remaining: 479ms
# 912:	learn: 0.4606233	total: 4.97s	remaining: 474ms
# 913:	learn: 0.4605377	total: 4.97s	remaining: 468ms
# 914:	learn: 0.4604440	total: 4.98s	remaining: 462ms
# 915:	learn: 0.4603504	total: 4.98s	remaining: 457ms
# 916:	learn: 0.4602560	total: 4.99s	remaining: 451ms
# 917:	learn: 0.4601617	total: 4.99s	remaining: 446ms
# 918:	learn: 0.4600830	total: 5s	remaining: 440ms
# 919:	learn: 0.4600005	total: 5s	remaining: 435ms
# 920:	learn: 0.4599213	total: 5.01s	remaining: 429ms
# 921:	learn: 0.4598060	total: 5.01s	remaining: 424ms
# 922:	learn: 0.4596906	total: 5.01s	remaining: 418ms
# 923:	learn: 0.4595941	total: 5.02s	remaining: 413ms
# 924:	learn: 0.4594260	total: 5.02s	remaining: 407ms
# 925:	learn: 0.4593252	total: 5.03s	remaining: 402ms
# 926:	learn: 0.4592594	total: 5.03s	remaining: 396ms
# 927:	learn: 0.4591892	total: 5.04s	remaining: 391ms
# ...
# 692:	learn: 0.4767742	total: 3.15s	remaining: 1.39s
# 693:	learn: 0.4766176	total: 3.15s	remaining: 1.39s
# 694:	learn: 0.4765101	total: 3.16s	remaining: 1.39s
# 695:	learn: 0.4764242	total: 3.16s	remaining: 1.38s
# 696:	learn: 0.4763037	total: 3.17s	remaining: 1.38s
# 697:	learn: 0.4761550	total: 3.17s	remaining: 1.37s
# 698:	learn: 0.4760593	total: 3.18s	remaining: 1.37s
# 699:	learn: 0.4759816	total: 3.18s	remaining: 1.36s
# 700:	learn: 0.4758884	total: 3.19s	remaining: 1.36s
# 701:	learn: 0.4757850	total: 3.19s	remaining: 1.35s
# 702:	learn: 0.4756521	total: 3.19s	remaining: 1.35s
# 703:	learn: 0.4755502	total: 3.2s	remaining: 1.34s
# 704:	learn: 0.4754427	total: 3.2s	remaining: 1.34s
# 705:	learn: 0.4753201	total: 3.21s	remaining: 1.34s
# 706:	learn: 0.4752145	total: 3.21s	remaining: 1.33s
# 707:	learn: 0.4751140	total: 3.22s	remaining: 1.33s
# 708:	learn: 0.4750060	total: 3.22s	remaining: 1.32s
# 709:	learn: 0.4748769	total: 3.23s	remaining: 1.32s
# 710:	learn: 0.4747349	total: 3.23s	remaining: 1.31s
# 711:	learn: 0.4746193	total: 3.23s	remaining: 1.31s
# 712:	learn: 0.4745066	total: 3.24s	remaining: 1.3s
# 713:	learn: 0.4743668	total: 3.24s	remaining: 1.3s
# 714:	learn: 0.4742563	total: 3.25s	remaining: 1.29s
# 715:	learn: 0.4741607	total: 3.25s	remaining: 1.29s
# 716:	learn: 0.4740637	total: 3.25s	remaining: 1.28s
# 717:	learn: 0.4738957	total: 3.26s	remaining: 1.28s
# 718:	learn: 0.4738281	total: 3.26s	remaining: 1.27s
# 719:	learn: 0.4737207	total: 3.27s	remaining: 1.27s
# 720:	learn: 0.4735545	total: 3.27s	remaining: 1.27s
# 721:	learn: 0.4734621	total: 3.28s	remaining: 1.26s
# 722:	learn: 0.4733347	total: 3.28s	remaining: 1.26s
# 723:	learn: 0.4732020	total: 3.29s	remaining: 1.25s
# 724:	learn: 0.4731328	total: 3.29s	remaining: 1.25s
# 725:	learn: 0.4730261	total: 3.3s	remaining: 1.24s
# 726:	learn: 0.4729088	total: 3.3s	remaining: 1.24s
# 727:	learn: 0.4727891	total: 3.31s	remaining: 1.24s
# 728:	learn: 0.4726638	total: 3.31s	remaining: 1.23s
# 729:	learn: 0.4725272	total: 3.31s	remaining: 1.23s
# 730:	learn: 0.4724032	total: 3.32s	remaining: 1.22s
# 731:	learn: 0.4723017	total: 3.33s	remaining: 1.22s
# 732:	learn: 0.4722161	total: 3.33s	remaining: 1.21s
# 733:	learn: 0.4721099	total: 3.33s	remaining: 1.21s
# 734:	learn: 0.4719465	total: 3.34s	remaining: 1.2s
# 735:	learn: 0.4718629	total: 3.34s	remaining: 1.2s
# 736:	learn: 0.4717404	total: 3.35s	remaining: 1.2s
# 737:	learn: 0.4715744	total: 3.35s	remaining: 1.19s
# 738:	learn: 0.4714431	total: 3.36s	remaining: 1.19s
# 739:	learn: 0.4713168	total: 3.36s	remaining: 1.18s
# 740:	learn: 0.4712438	total: 3.37s	remaining: 1.18s
# 741:	learn: 0.4711826	total: 3.37s	remaining: 1.17s
# 742:	learn: 0.4710680	total: 3.38s	remaining: 1.17s
# 743:	learn: 0.4709434	total: 3.38s	remaining: 1.16s
# 744:	learn: 0.4708250	total: 3.39s	remaining: 1.16s
# 745:	learn: 0.4707669	total: 3.39s	remaining: 1.16s
# 746:	learn: 0.4706341	total: 3.4s	remaining: 1.15s
# 747:	learn: 0.4705136	total: 3.4s	remaining: 1.15s
# 748:	learn: 0.4703851	total: 3.41s	remaining: 1.14s
# 749:	learn: 0.4702412	total: 3.41s	remaining: 1.14s
# 750:	learn: 0.4701436	total: 3.42s	remaining: 1.13s
# 751:	learn: 0.4700502	total: 3.42s	remaining: 1.13s
# 752:	learn: 0.4699358	total: 3.42s	remaining: 1.12s
# 753:	learn: 0.4698251	total: 3.43s	remaining: 1.12s
# 754:	learn: 0.4696906	total: 3.43s	remaining: 1.11s
# 755:	learn: 0.4696276	total: 3.44s	remaining: 1.11s
# 756:	learn: 0.4695309	total: 3.44s	remaining: 1.1s
# 757:	learn: 0.4694101	total: 3.45s	remaining: 1.1s
# 758:	learn: 0.4693353	total: 3.45s	remaining: 1.09s
# 759:	learn: 0.4692179	total: 3.46s	remaining: 1.09s
# 760:	learn: 0.4691460	total: 3.46s	remaining: 1.09s
# 761:	learn: 0.4690465	total: 3.46s	remaining: 1.08s
# 762:	learn: 0.4689626	total: 3.47s	remaining: 1.08s
# 763:	learn: 0.4688160	total: 3.47s	remaining: 1.07s
# 764:	learn: 0.4687361	total: 3.48s	remaining: 1.07s
# 765:	learn: 0.4686226	total: 3.48s	remaining: 1.06s
# 766:	learn: 0.4684713	total: 3.49s	remaining: 1.06s
# 767:	learn: 0.4683369	total: 3.49s	remaining: 1.05s
# 768:	learn: 0.4682627	total: 3.5s	remaining: 1.05s
# 769:	learn: 0.4681966	total: 3.5s	remaining: 1.04s
# 770:	learn: 0.4680854	total: 3.5s	remaining: 1.04s
# 771:	learn: 0.4679691	total: 3.51s	remaining: 1.04s
# 772:	learn: 0.4678485	total: 3.51s	remaining: 1.03s
# 773:	learn: 0.4677465	total: 3.52s	remaining: 1.03s
# 774:	learn: 0.4676745	total: 3.52s	remaining: 1.02s
# 775:	learn: 0.4675274	total: 3.53s	remaining: 1.02s
# 776:	learn: 0.4674115	total: 3.53s	remaining: 1.01s
# 777:	learn: 0.4673321	total: 3.54s	remaining: 1.01s
# 778:	learn: 0.4671907	total: 3.54s	remaining: 1s
# 779:	learn: 0.4671141	total: 3.54s	remaining: 1s
# 780:	learn: 0.4670117	total: 3.55s	remaining: 996ms
# 781:	learn: 0.4669288	total: 3.55s	remaining: 991ms
# 782:	learn: 0.4668339	total: 3.56s	remaining: 986ms
# 783:	learn: 0.4667274	total: 3.56s	remaining: 982ms
# 784:	learn: 0.4666410	total: 3.57s	remaining: 977ms
# 785:	learn: 0.4665483	total: 3.57s	remaining: 973ms
# 786:	learn: 0.4664512	total: 3.58s	remaining: 968ms
# 787:	learn: 0.4663307	total: 3.58s	remaining: 963ms
# 788:	learn: 0.4661896	total: 3.58s	remaining: 959ms
# 789:	learn: 0.4660802	total: 3.59s	remaining: 954ms
# 790:	learn: 0.4659561	total: 3.59s	remaining: 950ms
# 791:	learn: 0.4658471	total: 3.6s	remaining: 945ms
# 792:	learn: 0.4657454	total: 3.6s	remaining: 941ms
# 793:	learn: 0.4656252	total: 3.61s	remaining: 936ms
# 794:	learn: 0.4655072	total: 3.61s	remaining: 932ms
# 795:	learn: 0.4653632	total: 3.62s	remaining: 927ms
# 796:	learn: 0.4652841	total: 3.62s	remaining: 923ms
# 797:	learn: 0.4651433	total: 3.63s	remaining: 918ms
# 798:	learn: 0.4650510	total: 3.63s	remaining: 914ms
# 799:	learn: 0.4649652	total: 3.63s	remaining: 909ms
# 800:	learn: 0.4649001	total: 3.64s	remaining: 904ms
# 801:	learn: 0.4647885	total: 3.64s	remaining: 900ms
# 802:	learn: 0.4646793	total: 3.65s	remaining: 895ms
# 803:	learn: 0.4646067	total: 3.65s	remaining: 891ms
# 804:	learn: 0.4645281	total: 3.66s	remaining: 886ms
# 805:	learn: 0.4644529	total: 3.66s	remaining: 882ms
# 806:	learn: 0.4643669	total: 3.67s	remaining: 877ms
# 807:	learn: 0.4642692	total: 3.67s	remaining: 872ms
# 808:	learn: 0.4641881	total: 3.68s	remaining: 868ms
# 809:	learn: 0.4640701	total: 3.68s	remaining: 863ms
# 810:	learn: 0.4639758	total: 3.68s	remaining: 859ms
# 811:	learn: 0.4638851	total: 3.69s	remaining: 854ms
# 812:	learn: 0.4637919	total: 3.69s	remaining: 849ms
# 813:	learn: 0.4637195	total: 3.7s	remaining: 845ms
# 814:	learn: 0.4636490	total: 3.7s	remaining: 840ms
# 815:	learn: 0.4635238	total: 3.71s	remaining: 836ms
# 816:	learn: 0.4634201	total: 3.71s	remaining: 831ms
# 817:	learn: 0.4633302	total: 3.71s	remaining: 827ms
# 818:	learn: 0.4632580	total: 3.72s	remaining: 822ms
# 819:	learn: 0.4631143	total: 3.72s	remaining: 818ms
# 820:	learn: 0.4630553	total: 3.73s	remaining: 813ms
# 821:	learn: 0.4629376	total: 3.73s	remaining: 808ms
# 822:	learn: 0.4628277	total: 3.74s	remaining: 804ms
# 823:	learn: 0.4627017	total: 3.74s	remaining: 799ms
# 824:	learn: 0.4625708	total: 3.75s	remaining: 795ms
# 825:	learn: 0.4624508	total: 3.75s	remaining: 790ms
# 826:	learn: 0.4623839	total: 3.75s	remaining: 786ms
# 827:	learn: 0.4622786	total: 3.76s	remaining: 781ms
# 828:	learn: 0.4622041	total: 3.76s	remaining: 776ms
# 829:	learn: 0.4620835	total: 3.77s	remaining: 772ms
# 830:	learn: 0.4619686	total: 3.77s	remaining: 767ms
# 831:	learn: 0.4618927	total: 3.78s	remaining: 763ms
# 832:	learn: 0.4617383	total: 3.78s	remaining: 758ms
# 833:	learn: 0.4616341	total: 3.79s	remaining: 753ms
# 834:	learn: 0.4615389	total: 3.79s	remaining: 749ms
# 835:	learn: 0.4614686	total: 3.79s	remaining: 744ms
# 836:	learn: 0.4613669	total: 3.8s	remaining: 740ms
# 837:	learn: 0.4612838	total: 3.8s	remaining: 735ms
# 838:	learn: 0.4611512	total: 3.81s	remaining: 731ms
# 839:	learn: 0.4610497	total: 3.81s	remaining: 726ms
# 840:	learn: 0.4609835	total: 3.81s	remaining: 721ms
# 841:	learn: 0.4609062	total: 3.82s	remaining: 717ms
# 842:	learn: 0.4608180	total: 3.82s	remaining: 712ms
# 843:	learn: 0.4607329	total: 3.83s	remaining: 708ms
# 844:	learn: 0.4606336	total: 3.83s	remaining: 703ms
# 845:	learn: 0.4605464	total: 3.84s	remaining: 699ms
# 846:	learn: 0.4603541	total: 3.84s	remaining: 694ms
# 847:	learn: 0.4602445	total: 3.85s	remaining: 689ms
# 848:	learn: 0.4601073	total: 3.85s	remaining: 685ms
# 849:	learn: 0.4600220	total: 3.85s	remaining: 680ms
# 850:	learn: 0.4599288	total: 3.86s	remaining: 676ms
# 851:	learn: 0.4597469	total: 3.86s	remaining: 671ms
# 852:	learn: 0.4596805	total: 3.87s	remaining: 667ms
# 853:	learn: 0.4596053	total: 3.87s	remaining: 662ms
# 854:	learn: 0.4595259	total: 3.88s	remaining: 657ms
# 855:	learn: 0.4594390	total: 3.88s	remaining: 653ms
# 856:	learn: 0.4593323	total: 3.88s	remaining: 648ms
# 857:	learn: 0.4592308	total: 3.89s	remaining: 644ms
# 858:	learn: 0.4591333	total: 3.89s	remaining: 639ms
# 859:	learn: 0.4589727	total: 3.9s	remaining: 635ms
# 860:	learn: 0.4589022	total: 3.9s	remaining: 630ms
# 861:	learn: 0.4587849	total: 3.91s	remaining: 626ms
# 862:	learn: 0.4585961	total: 3.91s	remaining: 621ms
# 863:	learn: 0.4585095	total: 3.92s	remaining: 617ms
# 864:	learn: 0.4583827	total: 3.92s	remaining: 612ms
# 865:	learn: 0.4582873	total: 3.93s	remaining: 608ms
# 866:	learn: 0.4581268	total: 3.93s	remaining: 603ms
# 867:	learn: 0.4580121	total: 3.94s	remaining: 598ms
# 868:	learn: 0.4579469	total: 3.94s	remaining: 594ms
# 869:	learn: 0.4578488	total: 3.94s	remaining: 589ms
# 870:	learn: 0.4577678	total: 3.95s	remaining: 585ms
# 871:	learn: 0.4576533	total: 3.95s	remaining: 580ms
# 872:	learn: 0.4575289	total: 3.96s	remaining: 576ms
# 873:	learn: 0.4573817	total: 3.96s	remaining: 571ms
# 874:	learn: 0.4572652	total: 3.97s	remaining: 567ms
# 875:	learn: 0.4571588	total: 3.97s	remaining: 562ms
# 876:	learn: 0.4570441	total: 3.98s	remaining: 558ms
# 877:	learn: 0.4569239	total: 3.98s	remaining: 553ms
# 878:	learn: 0.4568340	total: 3.98s	remaining: 548ms
# 879:	learn: 0.4567390	total: 3.99s	remaining: 544ms
# 880:	learn: 0.4566240	total: 3.99s	remaining: 539ms
# 881:	learn: 0.4565424	total: 4s	remaining: 535ms
# 882:	learn: 0.4564573	total: 4s	remaining: 530ms
# 883:	learn: 0.4563836	total: 4.01s	remaining: 526ms
# 884:	learn: 0.4563102	total: 4.01s	remaining: 521ms
# 885:	learn: 0.4562217	total: 4.01s	remaining: 517ms
# 886:	learn: 0.4561089	total: 4.02s	remaining: 512ms
# 887:	learn: 0.4560378	total: 4.02s	remaining: 508ms
# 888:	learn: 0.4559461	total: 4.03s	remaining: 503ms
# 889:	learn: 0.4558688	total: 4.03s	remaining: 498ms
# 890:	learn: 0.4557912	total: 4.04s	remaining: 494ms
# 891:	learn: 0.4556578	total: 4.04s	remaining: 489ms
# 892:	learn: 0.4555264	total: 4.05s	remaining: 485ms
# 893:	learn: 0.4554214	total: 4.05s	remaining: 480ms
# 894:	learn: 0.4553288	total: 4.05s	remaining: 476ms
# 895:	learn: 0.4552028	total: 4.06s	remaining: 471ms
# 896:	learn: 0.4550508	total: 4.06s	remaining: 467ms
# 897:	learn: 0.4549324	total: 4.07s	remaining: 462ms
# 898:	learn: 0.4548415	total: 4.07s	remaining: 458ms
# 899:	learn: 0.4547434	total: 4.08s	remaining: 453ms
# 900:	learn: 0.4546650	total: 4.08s	remaining: 448ms
# 901:	learn: 0.4545726	total: 4.08s	remaining: 444ms
# 902:	learn: 0.4544861	total: 4.09s	remaining: 439ms
# 903:	learn: 0.4543828	total: 4.09s	remaining: 435ms
# 904:	learn: 0.4543020	total: 4.1s	remaining: 430ms
# 905:	learn: 0.4541575	total: 4.1s	remaining: 426ms
# 906:	learn: 0.4541047	total: 4.11s	remaining: 421ms
# 907:	learn: 0.4539955	total: 4.11s	remaining: 417ms
# 908:	learn: 0.4539166	total: 4.12s	remaining: 412ms
# 909:	learn: 0.4538287	total: 4.12s	remaining: 408ms
# 910:	learn: 0.4537301	total: 4.13s	remaining: 403ms
# 911:	learn: 0.4536472	total: 4.13s	remaining: 399ms
# 912:	learn: 0.4535528	total: 4.13s	remaining: 394ms
# 913:	learn: 0.4534520	total: 4.14s	remaining: 390ms
# 914:	learn: 0.4533496	total: 4.14s	remaining: 385ms
# 915:	learn: 0.4532549	total: 4.15s	remaining: 380ms
# 916:	learn: 0.4531839	total: 4.15s	remaining: 376ms
# 917:	learn: 0.4530603	total: 4.16s	remaining: 371ms
# 918:	learn: 0.4529671	total: 4.16s	remaining: 367ms
# 919:	learn: 0.4528828	total: 4.17s	remaining: 362ms
# 920:	learn: 0.4527628	total: 4.17s	remaining: 358ms
# 921:	learn: 0.4526549	total: 4.18s	remaining: 353ms
# 922:	learn: 0.4525532	total: 4.18s	remaining: 349ms
# 923:	learn: 0.4524488	total: 4.18s	remaining: 344ms
# 924:	learn: 0.4523488	total: 4.19s	remaining: 340ms
# 925:	learn: 0.4522524	total: 4.19s	remaining: 335ms
# 926:	learn: 0.4521634	total: 4.2s	remaining: 331ms
# 927:	learn: 0.4520343	total: 4.2s	remaining: 326ms
# 928:	learn: 0.4519484	total: 4.21s	remaining: 321ms
# 929:	learn: 0.4518676	total: 4.21s	remaining: 317ms
# 930:	learn: 0.4517084	total: 4.21s	remaining: 312ms
# 931:	learn: 0.4515722	total: 4.22s	remaining: 308ms
# 932:	learn: 0.4514923	total: 4.22s	remaining: 303ms
# 933:	learn: 0.4514051	total: 4.23s	remaining: 299ms
# 934:	learn: 0.4512936	total: 4.23s	remaining: 294ms
# 935:	learn: 0.4511640	total: 4.24s	remaining: 290ms
# 936:	learn: 0.4510435	total: 4.24s	remaining: 285ms
# 937:	learn: 0.4509938	total: 4.25s	remaining: 281ms
# 938:	learn: 0.4509273	total: 4.26s	remaining: 277ms
# 939:	learn: 0.4508770	total: 4.26s	remaining: 272ms
# 940:	learn: 0.4507271	total: 4.27s	remaining: 268ms
# 941:	learn: 0.4506465	total: 4.27s	remaining: 263ms
# 942:	learn: 0.4505633	total: 4.28s	remaining: 259ms
# 943:	learn: 0.4504873	total: 4.28s	remaining: 254ms
# 944:	learn: 0.4503810	total: 4.29s	remaining: 249ms
# 945:	learn: 0.4502379	total: 4.29s	remaining: 245ms
# 946:	learn: 0.4501407	total: 4.29s	remaining: 240ms
# 947:	learn: 0.4500501	total: 4.3s	remaining: 236ms
# 948:	learn: 0.4499816	total: 4.3s	remaining: 231ms
# 949:	learn: 0.4499166	total: 4.31s	remaining: 227ms
# 950:	learn: 0.4498336	total: 4.31s	remaining: 222ms
# 951:	learn: 0.4497675	total: 4.32s	remaining: 218ms
# 952:	learn: 0.4497053	total: 4.32s	remaining: 213ms
# 953:	learn: 0.4495919	total: 4.33s	remaining: 209ms
# 954:	learn: 0.4495003	total: 4.33s	remaining: 204ms
# 955:	learn: 0.4493984	total: 4.33s	remaining: 200ms
# 956:	learn: 0.4492871	total: 4.34s	remaining: 195ms
# 957:	learn: 0.4491735	total: 4.34s	remaining: 190ms
# 958:	learn: 0.4491108	total: 4.35s	remaining: 186ms
# 959:	learn: 0.4489973	total: 4.35s	remaining: 181ms
# 960:	learn: 0.4489027	total: 4.36s	remaining: 177ms
# 961:	learn: 0.4488231	total: 4.36s	remaining: 172ms
# 962:	learn: 0.4487558	total: 4.37s	remaining: 168ms
# 963:	learn: 0.4485988	total: 4.37s	remaining: 163ms
# 964:	learn: 0.4485109	total: 4.38s	remaining: 159ms
# 965:	learn: 0.4484131	total: 4.38s	remaining: 154ms
# 966:	learn: 0.4483342	total: 4.39s	remaining: 150ms
# 967:	learn: 0.4482445	total: 4.39s	remaining: 145ms
# 968:	learn: 0.4481307	total: 4.39s	remaining: 141ms
# 969:	learn: 0.4480194	total: 4.4s	remaining: 136ms
# 970:	learn: 0.4479495	total: 4.4s	remaining: 132ms
# 971:	learn: 0.4478683	total: 4.41s	remaining: 127ms
# 972:	learn: 0.4477212	total: 4.41s	remaining: 122ms
# 973:	learn: 0.4475764	total: 4.42s	remaining: 118ms
# 974:	learn: 0.4474061	total: 4.42s	remaining: 113ms
# 975:	learn: 0.4473257	total: 4.42s	remaining: 109ms
# 976:	learn: 0.4472457	total: 4.43s	remaining: 104ms
# 977:	learn: 0.4471205	total: 4.43s	remaining: 99.7ms
# 978:	learn: 0.4470188	total: 4.44s	remaining: 95.2ms
# 979:	learn: 0.4469175	total: 4.44s	remaining: 90.7ms
# 980:	learn: 0.4468386	total: 4.45s	remaining: 86.1ms
# 981:	learn: 0.4467043	total: 4.45s	remaining: 81.6ms
# 982:	learn: 0.4466131	total: 4.46s	remaining: 77.1ms
# 983:	learn: 0.4464551	total: 4.46s	remaining: 72.6ms
# 984:	learn: 0.4463647	total: 4.47s	remaining: 68ms
# 985:	learn: 0.4462474	total: 4.47s	remaining: 63.5ms
# 986:	learn: 0.4461697	total: 4.47s	remaining: 59ms
# 987:	learn: 0.4460716	total: 4.48s	remaining: 54.4ms
# 988:	learn: 0.4459787	total: 4.48s	remaining: 49.9ms
# 989:	learn: 0.4459242	total: 4.49s	remaining: 45.3ms
# 990:	learn: 0.4458600	total: 4.49s	remaining: 40.8ms
# 991:	learn: 0.4457927	total: 4.5s	remaining: 36.3ms
# 992:	learn: 0.4456698	total: 4.5s	remaining: 31.7ms
# 993:	learn: 0.4456106	total: 4.51s	remaining: 27.2ms
# 994:	learn: 0.4455313	total: 4.51s	remaining: 22.7ms
# 995:	learn: 0.4454777	total: 4.52s	remaining: 18.1ms
# 996:	learn: 0.4454020	total: 4.52s	remaining: 13.6ms
# 997:	learn: 0.4452936	total: 4.53s	remaining: 9.07ms
# 998:	learn: 0.4452193	total: 4.53s	remaining: 4.54ms
# 999:	learn: 0.4451195	total: 4.54s	remaining: 0us

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                        fit_time  \
# Dummy_Classifer                               0.002 (+/- 0.000)
# DecitionTree_Classifier                       0.264 (+/- 0.003)
# GNB_Classifier                                0.007 (+/- 0.000)
# LogisticR_Classifier                          0.049 (+/- 0.003)
# RandomForest_Classifier                       2.683 (+/- 0.034)
# GradBoost_Classifier                          1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled  2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba            1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba         2.569 (+/- 0.005)
# CATBoost_Classifier                           4.707 (+/- 0.125)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)

# %% [markdown]
# ### Hyperparameter Optimization

# %% [markdown]
# After the baseline runs for each classifier were done, we moved on to hyperparameter tuning. To simplify the hyperparameter tuning, we decided to go with GridSearchCV. We first define parameter grids for each of the classfier and then use GridSearchCV.

# %%
from sklearn import tree
# %matplotlib notebook
plt.figure(figsize=(100,30))
tree.plot_tree(dtc,filled=True)
plt.show()

# %% [markdown]
# Lookin at the output above, we can see that Decision Tree is way too saturated and in some cases the number of samples in a node is as low as 1. Hence some tuning is necessary.
# Note - This section is used only when we needed to find the parameters. There is no need to run this every run, hence it is commented out.

# %%
param_grid_dtc = {"max_depth":[10,15,20],"min_impurity_decrease":[0.2,0.1,0.05,0]}
param_grid_rf = {"n_estimators":[50,100,150,200],"max_features":[100,1000,10000,15000]}
param_grid_lr = {"C":[0.01, 0.1, 1, 10, 100, 1000],"max_iter":[100,500,1000,2000]}
param_grid_gnb = {"var_smoothing":[1e-9,1e-8,1e-10,1e-12]}
param_grid_gbc = {"n_estimators":[10,100,500,1000],"max_depth":[5,10,50,100],"learning_rate":[0.1,0.01,0.001]}
param_grid_cb = {"iterations":[100,500,1000],"learning_rate":[0.1,0.01,0.001]}

# %%
# grid_search_dtc = GridSearchCV(dtc, param_grid_dtc, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_dtc.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_dtc.best_params_}.")

# %%
# grid_search_rf = GridSearchCV(rf, param_grid_rf, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_rf.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_rf.best_params_}.")

# %%
# grid_search_lr = GridSearchCV(lr, param_grid_lr, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_lr.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_lr.best_params_}.")

# %%
# grid_search_gnb = GridSearchCV(gnb, param_grid_gnb, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_gnb.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_gnb.best_params_}.")

# %%
# grid_search_gbc = GridSearchCV(gbc, param_grid_gbc, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_gbc.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_gbc.best_params_}.")

# %%
# grid_search_cb = GridSearchCV(cb, param_grid_cb, cv=5, n_jobs=-1, return_train_score=True)
# grid_search_cb.fit(X_train,y_train)
# print(f" The best parameter values are {grid_search_cb.best_params_}.")

# %% [markdown]
# Once the best parameters were found for each of the classifiers, we ran all the models again with these parameters.

# %%
dtc = DecisionTreeClassifier(max_depth=10,min_impurity_decrease=0)
dtc.fit(X_train,y_train)
predict_dtc = dtc.predict(X_test)
predict_dtc_df = pd.DataFrame(predict_dtc,columns=['state']) # creating a dataframe of the results
final_dtc_df = pd.concat([col_df,predict_dtc_df],ignore_index=False, sort=False,axis=1)
final_dtc_df.to_csv("Results/output_dtc_tuned.csv",index=False)
result_dict["DecisionTree_Classifier_tuned"] = mean_std_cross_val_scores(dtc, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                        fit_time  \
# Dummy_Classifer                               0.002 (+/- 0.000)
# DecitionTree_Classifier                       0.264 (+/- 0.003)
# GNB_Classifier                                0.007 (+/- 0.000)
# LogisticR_Classifier                          0.049 (+/- 0.003)
# RandomForest_Classifier                       2.683 (+/- 0.034)
# GradBoost_Classifier                          1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled  2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba            1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba         2.569 (+/- 0.005)
# CATBoost_Classifier                           4.707 (+/- 0.125)
# DecitionTree_Classifier_tuned                 0.162 (+/- 0.002)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
# DecitionTree_Classifier_tuned                 0.002 (+/- 0.000)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
# DecitionTree_Classifier_tuned                 0.654 (+/- 0.005)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)
# DecitionTree_Classifier_tuned                 0.746 (+/- 0.007)

# %%
#Random Forest tuned
rf = RandomForestClassifier(n_estimators = 150, max_depth=10,max_features=100, random_state=0)
rf.fit(X_train,y_train)

predict_rf = rf.predict(X_test)
predict_rf_df = pd.DataFrame(predict_rf,columns=['state']) # creating a dataframe of the results

final_rf_df = pd.concat([col_df,predict_rf_df],ignore_index=False, sort=False,axis=1)
final_rf_df.to_csv("Results/output_rf_tuned.csv",index=False)
result_dict["RandomForest_Classifier_tuned"] = mean_std_cross_val_scores(rf, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                         fit_time  \
# Dummy_Classifer                                0.002 (+/- 0.000)
# DecitionTree_Classifier                        0.264 (+/- 0.003)
# GNB_Classifier                                 0.007 (+/- 0.000)
# LogisticR_Classifier                           0.049 (+/- 0.003)
# RandomForest_Classifier                        2.683 (+/- 0.034)
# GradBoost_Classifier                           1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled   2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba             1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba          2.569 (+/- 0.005)
# CATBoost_Classifier                            4.707 (+/- 0.125)
# DecitionTree_Classifier_tuned                  0.162 (+/- 0.002)
# RandomForest_Classifier_tuned                 15.249 (+/- 0.160)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
# DecitionTree_Classifier_tuned                 0.002 (+/- 0.000)
# RandomForest_Classifier_tuned                 0.067 (+/- 0.001)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
# DecitionTree_Classifier_tuned                 0.654 (+/- 0.005)
# RandomForest_Classifier_tuned                 0.699 (+/- 0.007)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)
# DecitionTree_Classifier_tuned                 0.746 (+/- 0.007)
# RandomForest_Classifier_tuned                 0.803 (+/- 0.004)

# %%
#Logistic Regression tuned
lr = LogisticRegression(C=0.1,max_iter=100,random_state=1)
lr.fit(X_train,y_train)
predict_lr = lr.predict(X_test)
predict_lr_df = pd.DataFrame(predict_lr,columns=['state']) # creating a dataframe of the results

final_lr_df = pd.concat([col_df,predict_lr_df],ignore_index=False, sort=False,axis=1)
final_lr_df.to_csv("Results/output_lr_tuned.csv",index=False)
result_dict["LogisticR_Classifier_tuned"] = mean_std_cross_val_scores(lr, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                         fit_time  \
# Dummy_Classifer                                0.002 (+/- 0.000)
# DecitionTree_Classifier                        0.264 (+/- 0.003)
# GNB_Classifier                                 0.007 (+/- 0.000)
# LogisticR_Classifier                           0.049 (+/- 0.003)
# RandomForest_Classifier                        2.683 (+/- 0.034)
# GradBoost_Classifier                           1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled   2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba             1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba          2.569 (+/- 0.005)
# CATBoost_Classifier                            4.707 (+/- 0.125)
# DecitionTree_Classifier_tuned                  0.162 (+/- 0.002)
# RandomForest_Classifier_tuned                 15.249 (+/- 0.160)
# LogisticR_Classifier_tuned                     0.040 (+/- 0.003)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
# DecitionTree_Classifier_tuned                 0.002 (+/- 0.000)
# RandomForest_Classifier_tuned                 0.067 (+/- 0.001)
# LogisticR_Classifier_tuned                    0.001 (+/- 0.000)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
# DecitionTree_Classifier_tuned                 0.654 (+/- 0.005)
# RandomForest_Classifier_tuned                 0.699 (+/- 0.007)
# LogisticR_Classifier_tuned                    0.547 (+/- 0.006)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)
# DecitionTree_Classifier_tuned                 0.746 (+/- 0.007)
# RandomForest_Classifier_tuned                 0.803 (+/- 0.004)
# LogisticR_Classifier_tuned                    0.549 (+/- 0.002)

# %%
#Gradient Boosting
gbc = GradientBoostingClassifier(n_estimators=1000, learning_rate=0.01, max_depth=5, random_state=0)
gbc.fit(X_train,y_train)

predict_gbc = gbc.predict(X_test)
predict_gbc_df = pd.DataFrame(predict_gbc,columns=['state']) # creating a dataframe of the results

final_gbc_df = pd.concat([col_df,predict_gbc_df],ignore_index=False, sort=False,axis=1)
final_gbc_df.to_csv("Results/output_gbc_tuned.csv",index=False)
result_dict["GradBoost_Classifier_tuned"] = mean_std_cross_val_scores(gbc, X_train, y_train, cv=5, return_train_score=True)

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                         fit_time  \
# Dummy_Classifer                                0.002 (+/- 0.000)
# DecitionTree_Classifier                        0.264 (+/- 0.003)
# GNB_Classifier                                 0.007 (+/- 0.000)
# LogisticR_Classifier                           0.049 (+/- 0.003)
# RandomForest_Classifier                        2.683 (+/- 0.034)
# GradBoost_Classifier                           1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled   2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba             1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba          2.569 (+/- 0.005)
# CATBoost_Classifier                            4.707 (+/- 0.125)
# DecitionTree_Classifier_tuned                  0.162 (+/- 0.002)
# RandomForest_Classifier_tuned                 15.249 (+/- 0.160)
# LogisticR_Classifier_tuned                     0.040 (+/- 0.003)
# GradBoost_Classifier_tuned                    81.706 (+/- 0.129)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
# DecitionTree_Classifier_tuned                 0.002 (+/- 0.000)
# RandomForest_Classifier_tuned                 0.067 (+/- 0.001)
# LogisticR_Classifier_tuned                    0.001 (+/- 0.000)
# GradBoost_Classifier_tuned                    0.097 (+/- 0.001)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
# DecitionTree_Classifier_tuned                 0.654 (+/- 0.005)
# RandomForest_Classifier_tuned                 0.699 (+/- 0.007)
# LogisticR_Classifier_tuned                    0.547 (+/- 0.006)
# GradBoost_Classifier_tuned                    0.719 (+/- 0.007)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)
# DecitionTree_Classifier_tuned                 0.746 (+/- 0.007)
# RandomForest_Classifier_tuned                 0.803 (+/- 0.004)
# LogisticR_Classifier_tuned                    0.549 (+/- 0.002)
# GradBoost_Classifier_tuned                    0.779 (+/- 0.003)

# %%
# CATboost tuned
cb = CatBoostClassifier(iterations=500,learning_rate=0.1,random_state=0)
cb.fit(X_train,y_train)

predict_cb = cb.predict(X_test)
predict_cb_df = pd.DataFrame(predict_cb,columns=['state']) # creating a dataframe of the results

final_cb_df = pd.concat([col_df,predict_cb_df],ignore_index=False, sort=False,axis=1)
final_cb_df.to_csv("Results/output_catboost_tuned.csv",index=False)
result_dict["CATBoost_Classifier_tuned"] = mean_std_cross_val_scores(cb, X_train, y_train, cv=5, return_train_score=True)
# Out:
# 0:	learn: 0.6809866	total: 6.01ms	remaining: 3s
# 1:	learn: 0.6713213	total: 11.3ms	remaining: 2.81s
# 2:	learn: 0.6618938	total: 16.2ms	remaining: 2.69s
# 3:	learn: 0.6542404	total: 22.3ms	remaining: 2.76s
# 4:	learn: 0.6471430	total: 27.1ms	remaining: 2.68s
# 5:	learn: 0.6413453	total: 32.7ms	remaining: 2.69s
# 6:	learn: 0.6358896	total: 38.2ms	remaining: 2.69s
# 7:	learn: 0.6314101	total: 42.7ms	remaining: 2.63s
# 8:	learn: 0.6268863	total: 47.9ms	remaining: 2.62s
# 9:	learn: 0.6228024	total: 52.5ms	remaining: 2.57s
# 10:	learn: 0.6192339	total: 56.8ms	remaining: 2.53s
# 11:	learn: 0.6157247	total: 62.1ms	remaining: 2.53s
# 12:	learn: 0.6127486	total: 68.5ms	remaining: 2.57s
# 13:	learn: 0.6099648	total: 73.4ms	remaining: 2.55s
# 14:	learn: 0.6074870	total: 78.3ms	remaining: 2.53s
# 15:	learn: 0.6050981	total: 84.1ms	remaining: 2.54s
# 16:	learn: 0.6026596	total: 89.9ms	remaining: 2.55s
# 17:	learn: 0.6003809	total: 95.8ms	remaining: 2.57s
# 18:	learn: 0.5983733	total: 103ms	remaining: 2.62s
# 19:	learn: 0.5963017	total: 109ms	remaining: 2.63s
# 20:	learn: 0.5945856	total: 115ms	remaining: 2.63s
# 21:	learn: 0.5930276	total: 121ms	remaining: 2.62s
# 22:	learn: 0.5911160	total: 126ms	remaining: 2.62s
# 23:	learn: 0.5893507	total: 132ms	remaining: 2.62s
# 24:	learn: 0.5885293	total: 136ms	remaining: 2.59s
# 25:	learn: 0.5872437	total: 141ms	remaining: 2.58s
# 26:	learn: 0.5860022	total: 147ms	remaining: 2.57s
# 27:	learn: 0.5846787	total: 152ms	remaining: 2.56s
# 28:	learn: 0.5836369	total: 157ms	remaining: 2.55s
# 29:	learn: 0.5822480	total: 162ms	remaining: 2.53s
# 30:	learn: 0.5811928	total: 166ms	remaining: 2.51s
# 31:	learn: 0.5802192	total: 171ms	remaining: 2.5s
# 32:	learn: 0.5792018	total: 176ms	remaining: 2.49s
# 33:	learn: 0.5782244	total: 181ms	remaining: 2.48s
# 34:	learn: 0.5774229	total: 187ms	remaining: 2.49s
# 35:	learn: 0.5765310	total: 194ms	remaining: 2.5s
# 36:	learn: 0.5757997	total: 199ms	remaining: 2.49s
# 37:	learn: 0.5749432	total: 205ms	remaining: 2.49s
# 38:	learn: 0.5742077	total: 211ms	remaining: 2.49s
# 39:	learn: 0.5733239	total: 216ms	remaining: 2.48s
# 40:	learn: 0.5725987	total: 222ms	remaining: 2.48s
# 41:	learn: 0.5718033	total: 227ms	remaining: 2.47s
# 42:	learn: 0.5711760	total: 232ms	remaining: 2.47s
# 43:	learn: 0.5705405	total: 237ms	remaining: 2.46s
# 44:	learn: 0.5700543	total: 242ms	remaining: 2.45s
# 45:	learn: 0.5692013	total: 247ms	remaining: 2.44s
# 46:	learn: 0.5686432	total: 252ms	remaining: 2.43s
# 47:	learn: 0.5681065	total: 257ms	remaining: 2.42s
# 48:	learn: 0.5675182	total: 262ms	remaining: 2.41s
# 49:	learn: 0.5670065	total: 267ms	remaining: 2.4s
# 50:	learn: 0.5664454	total: 272ms	remaining: 2.4s
# 51:	learn: 0.5659124	total: 278ms	remaining: 2.39s
# 52:	learn: 0.5652906	total: 283ms	remaining: 2.38s
# 53:	learn: 0.5646689	total: 287ms	remaining: 2.37s
# 54:	learn: 0.5641588	total: 292ms	remaining: 2.37s
# 55:	learn: 0.5635150	total: 297ms	remaining: 2.35s
# 56:	learn: 0.5631029	total: 301ms	remaining: 2.34s
# 57:	learn: 0.5627280	total: 306ms	remaining: 2.33s
# 58:	learn: 0.5623365	total: 311ms	remaining: 2.32s
# 59:	learn: 0.5618896	total: 315ms	remaining: 2.31s
# 60:	learn: 0.5615079	total: 320ms	remaining: 2.3s
# 61:	learn: 0.5609368	total: 325ms	remaining: 2.29s
# 62:	learn: 0.5605272	total: 329ms	remaining: 2.29s
# 63:	learn: 0.5600932	total: 334ms	remaining: 2.27s
# 64:	learn: 0.5594495	total: 339ms	remaining: 2.27s
# 65:	learn: 0.5591006	total: 345ms	remaining: 2.27s
# 66:	learn: 0.5586218	total: 349ms	remaining: 2.26s
# 67:	learn: 0.5581334	total: 354ms	remaining: 2.25s
# 68:	learn: 0.5577139	total: 359ms	remaining: 2.24s
# 69:	learn: 0.5572359	total: 364ms	remaining: 2.23s
# 70:	learn: 0.5567053	total: 369ms	remaining: 2.23s
# 71:	learn: 0.5562352	total: 375ms	remaining: 2.23s
# 72:	learn: 0.5557729	total: 379ms	remaining: 2.22s
# 73:	learn: 0.5553776	total: 385ms	remaining: 2.21s
# 74:	learn: 0.5550111	total: 389ms	remaining: 2.21s
# 75:	learn: 0.5545113	total: 394ms	remaining: 2.2s
# 76:	learn: 0.5539954	total: 399ms	remaining: 2.19s
# 77:	learn: 0.5535054	total: 404ms	remaining: 2.18s
# 78:	learn: 0.5531635	total: 408ms	remaining: 2.17s
# 79:	learn: 0.5526848	total: 413ms	remaining: 2.17s
# 80:	learn: 0.5523767	total: 418ms	remaining: 2.16s
# 81:	learn: 0.5517963	total: 422ms	remaining: 2.15s
# 82:	learn: 0.5514899	total: 427ms	remaining: 2.15s
# 83:	learn: 0.5512047	total: 432ms	remaining: 2.14s
# 84:	learn: 0.5508395	total: 436ms	remaining: 2.13s
# 85:	learn: 0.5505807	total: 441ms	remaining: 2.12s
# 86:	learn: 0.5501738	total: 446ms	remaining: 2.12s
# 87:	learn: 0.5496081	total: 451ms	remaining: 2.11s
# 88:	learn: 0.5492767	total: 456ms	remaining: 2.1s
# 89:	learn: 0.5487841	total: 461ms	remaining: 2.1s
# 90:	learn: 0.5478092	total: 465ms	remaining: 2.09s
# 91:	learn: 0.5473511	total: 470ms	remaining: 2.08s
# 92:	learn: 0.5470337	total: 475ms	remaining: 2.08s
# 93:	learn: 0.5466918	total: 480ms	remaining: 2.07s
# 94:	learn: 0.5463054	total: 485ms	remaining: 2.06s
# 95:	learn: 0.5457887	total: 490ms	remaining: 2.06s
# 96:	learn: 0.5454511	total: 495ms	remaining: 2.06s
# 97:	learn: 0.5450466	total: 499ms	remaining: 2.05s
# 98:	learn: 0.5448065	total: 504ms	remaining: 2.04s
# 99:	learn: 0.5443259	total: 509ms	remaining: 2.04s
# 100:	learn: 0.5440222	total: 514ms	remaining: 2.03s
# 101:	learn: 0.5436839	total: 518ms	remaining: 2.02s
# 102:	learn: 0.5432570	total: 523ms	remaining: 2.02s
# 103:	learn: 0.5428707	total: 528ms	remaining: 2.01s
# 104:	learn: 0.5425899	total: 532ms	remaining: 2s
# 105:	learn: 0.5421979	total: 537ms	remaining: 2s
# 106:	learn: 0.5419516	total: 541ms	remaining: 1.99s
# 107:	learn: 0.5416315	total: 545ms	remaining: 1.98s
# 108:	learn: 0.5412947	total: 550ms	remaining: 1.97s
# 109:	learn: 0.5409939	total: 556ms	remaining: 1.97s
# 110:	learn: 0.5406681	total: 561ms	remaining: 1.97s
# 111:	learn: 0.5402196	total: 567ms	remaining: 1.96s
# 112:	learn: 0.5399645	total: 572ms	remaining: 1.96s
# 113:	learn: 0.5397050	total: 577ms	remaining: 1.95s
# 114:	learn: 0.5394097	total: 582ms	remaining: 1.95s
# 115:	learn: 0.5382464	total: 586ms	remaining: 1.94s
# 116:	learn: 0.5379352	total: 591ms	remaining: 1.93s
# 117:	learn: 0.5376803	total: 596ms	remaining: 1.93s
# 118:	learn: 0.5373542	total: 600ms	remaining: 1.92s
# 119:	learn: 0.5366399	total: 605ms	remaining: 1.92s
# 120:	learn: 0.5362544	total: 610ms	remaining: 1.91s
# 121:	learn: 0.5357823	total: 615ms	remaining: 1.9s
# 122:	learn: 0.5355159	total: 619ms	remaining: 1.9s
# 123:	learn: 0.5351297	total: 624ms	remaining: 1.89s
# 124:	learn: 0.5347357	total: 628ms	remaining: 1.88s
# 125:	learn: 0.5345138	total: 633ms	remaining: 1.88s
# 126:	learn: 0.5342758	total: 637ms	remaining: 1.87s
# 127:	learn: 0.5339450	total: 642ms	remaining: 1.86s
# 128:	learn: 0.5332222	total: 646ms	remaining: 1.86s
# 129:	learn: 0.5324654	total: 651ms	remaining: 1.85s
# 130:	learn: 0.5321230	total: 656ms	remaining: 1.85s
# 131:	learn: 0.5316513	total: 661ms	remaining: 1.84s
# 132:	learn: 0.5311973	total: 666ms	remaining: 1.84s
# 133:	learn: 0.5307711	total: 671ms	remaining: 1.83s
# 134:	learn: 0.5296138	total: 676ms	remaining: 1.83s
# 135:	learn: 0.5292663	total: 680ms	remaining: 1.82s
# 136:	learn: 0.5289779	total: 685ms	remaining: 1.82s
# 137:	learn: 0.5285433	total: 690ms	remaining: 1.81s
# 138:	learn: 0.5281418	total: 695ms	remaining: 1.8s
# 139:	learn: 0.5277632	total: 700ms	remaining: 1.8s
# 140:	learn: 0.5274461	total: 704ms	remaining: 1.79s
# 141:	learn: 0.5271194	total: 709ms	remaining: 1.79s
# 142:	learn: 0.5266764	total: 713ms	remaining: 1.78s
# 143:	learn: 0.5263105	total: 718ms	remaining: 1.77s
# 144:	learn: 0.5258012	total: 722ms	remaining: 1.77s
# 145:	learn: 0.5252863	total: 727ms	remaining: 1.76s
# 146:	learn: 0.5250598	total: 734ms	remaining: 1.76s
# 147:	learn: 0.5246819	total: 739ms	remaining: 1.76s
# 148:	learn: 0.5244255	total: 745ms	remaining: 1.75s
# 149:	learn: 0.5241940	total: 750ms	remaining: 1.75s
# 150:	learn: 0.5238234	total: 754ms	remaining: 1.74s
# 151:	learn: 0.5235515	total: 759ms	remaining: 1.74s
# 152:	learn: 0.5231811	total: 764ms	remaining: 1.73s
# 153:	learn: 0.5229140	total: 768ms	remaining: 1.73s
# 154:	learn: 0.5225463	total: 773ms	remaining: 1.72s
# 155:	learn: 0.5222385	total: 778ms	remaining: 1.71s
# 156:	learn: 0.5219150	total: 782ms	remaining: 1.71s
# 157:	learn: 0.5216608	total: 787ms	remaining: 1.7s
# 158:	learn: 0.5212708	total: 791ms	remaining: 1.7s
# 159:	learn: 0.5209710	total: 796ms	remaining: 1.69s
# 160:	learn: 0.5205890	total: 800ms	remaining: 1.69s
# 161:	learn: 0.5202564	total: 805ms	remaining: 1.68s
# 162:	learn: 0.5193775	total: 810ms	remaining: 1.67s
# 163:	learn: 0.5189892	total: 814ms	remaining: 1.67s
# 164:	learn: 0.5186938	total: 819ms	remaining: 1.66s
# 165:	learn: 0.5183315	total: 824ms	remaining: 1.66s
# 166:	learn: 0.5179539	total: 829ms	remaining: 1.65s
# 167:	learn: 0.5176997	total: 833ms	remaining: 1.65s
# 168:	learn: 0.5174512	total: 838ms	remaining: 1.64s
# 169:	learn: 0.5171145	total: 843ms	remaining: 1.64s
# 170:	learn: 0.5165760	total: 847ms	remaining: 1.63s
# 171:	learn: 0.5162259	total: 852ms	remaining: 1.62s
# 172:	learn: 0.5159847	total: 857ms	remaining: 1.62s
# 173:	learn: 0.5156317	total: 862ms	remaining: 1.61s
# 174:	learn: 0.5153268	total: 866ms	remaining: 1.61s
# 175:	learn: 0.5149323	total: 871ms	remaining: 1.6s
# 176:	learn: 0.5146944	total: 876ms	remaining: 1.6s
# 177:	learn: 0.5143574	total: 881ms	remaining: 1.59s
# 178:	learn: 0.5139749	total: 885ms	remaining: 1.59s
# 179:	learn: 0.5136079	total: 890ms	remaining: 1.58s
# 180:	learn: 0.5132549	total: 894ms	remaining: 1.57s
# 181:	learn: 0.5128628	total: 899ms	remaining: 1.57s
# 182:	learn: 0.5121520	total: 904ms	remaining: 1.56s
# 183:	learn: 0.5118334	total: 908ms	remaining: 1.56s
# 184:	learn: 0.5115878	total: 913ms	remaining: 1.55s
# 185:	learn: 0.5113182	total: 919ms	remaining: 1.55s
# 186:	learn: 0.5110756	total: 924ms	remaining: 1.54s
# 187:	learn: 0.5106242	total: 929ms	remaining: 1.54s
# 188:	learn: 0.5103844	total: 934ms	remaining: 1.54s
# 189:	learn: 0.5100854	total: 938ms	remaining: 1.53s
# 190:	learn: 0.5098249	total: 943ms	remaining: 1.53s
# 191:	learn: 0.5096329	total: 948ms	remaining: 1.52s
# 192:	learn: 0.5094156	total: 952ms	remaining: 1.51s
# 193:	learn: 0.5090032	total: 957ms	remaining: 1.51s
# 194:	learn: 0.5087533	total: 962ms	remaining: 1.5s
# 195:	learn: 0.5085138	total: 966ms	remaining: 1.5s
# 196:	learn: 0.5082354	total: 971ms	remaining: 1.49s
# 197:	learn: 0.5080261	total: 977ms	remaining: 1.49s
# 198:	learn: 0.5077627	total: 981ms	remaining: 1.48s
# 199:	learn: 0.5072081	total: 986ms	remaining: 1.48s
# 200:	learn: 0.5068782	total: 991ms	remaining: 1.47s
# 201:	learn: 0.5066039	total: 996ms	remaining: 1.47s
# 202:	learn: 0.5061390	total: 1s	remaining: 1.46s
# 203:	learn: 0.5058877	total: 1.01s	remaining: 1.46s
# 204:	learn: 0.5055934	total: 1.01s	remaining: 1.46s
# 205:	learn: 0.5051700	total: 1.02s	remaining: 1.45s
# 206:	learn: 0.5049098	total: 1.02s	remaining: 1.45s
# 207:	learn: 0.5045541	total: 1.03s	remaining: 1.44s
# 208:	learn: 0.5043317	total: 1.03s	remaining: 1.44s
# 209:	learn: 0.5041519	total: 1.03s	remaining: 1.43s
# 210:	learn: 0.5038473	total: 1.04s	remaining: 1.42s
# 211:	learn: 0.5036675	total: 1.04s	remaining: 1.42s
# 212:	learn: 0.5032629	total: 1.05s	remaining: 1.41s
# 213:	learn: 0.5029409	total: 1.05s	remaining: 1.41s
# 214:	learn: 0.5026280	total: 1.06s	remaining: 1.4s
# 215:	learn: 0.5023215	total: 1.06s	remaining: 1.4s
# 216:	learn: 0.5021387	total: 1.07s	remaining: 1.39s
# 217:	learn: 0.5019197	total: 1.07s	remaining: 1.39s
# 218:	learn: 0.5016188	total: 1.08s	remaining: 1.38s
# 219:	learn: 0.5013467	total: 1.08s	remaining: 1.38s
# 220:	learn: 0.5011582	total: 1.09s	remaining: 1.37s
# 221:	learn: 0.5009029	total: 1.09s	remaining: 1.37s
# 222:	learn: 0.5003459	total: 1.1s	remaining: 1.37s
# 223:	learn: 0.5001015	total: 1.11s	remaining: 1.36s
# 224:	learn: 0.4998063	total: 1.11s	remaining: 1.36s
# 225:	learn: 0.4994543	total: 1.12s	remaining: 1.35s
# 226:	learn: 0.4992195	total: 1.12s	remaining: 1.35s
# 227:	learn: 0.4989153	total: 1.13s	remaining: 1.34s
# 228:	learn: 0.4986083	total: 1.13s	remaining: 1.34s
# 229:	learn: 0.4983811	total: 1.14s	remaining: 1.33s
# 230:	learn: 0.4980964	total: 1.14s	remaining: 1.33s
# 231:	learn: 0.4977827	total: 1.15s	remaining: 1.32s
# 232:	learn: 0.4975422	total: 1.15s	remaining: 1.32s
# 233:	learn: 0.4972936	total: 1.16s	remaining: 1.31s
# 234:	learn: 0.4970926	total: 1.16s	remaining: 1.31s
# 235:	learn: 0.4968180	total: 1.17s	remaining: 1.3s
# 236:	learn: 0.4965671	total: 1.17s	remaining: 1.3s
# 237:	learn: 0.4960815	total: 1.18s	remaining: 1.29s
# 238:	learn: 0.4957540	total: 1.18s	remaining: 1.29s
# 239:	learn: 0.4955470	total: 1.19s	remaining: 1.28s
# 240:	learn: 0.4952203	total: 1.19s	remaining: 1.28s
# 241:	learn: 0.4948747	total: 1.2s	remaining: 1.27s
# 242:	learn: 0.4945206	total: 1.2s	remaining: 1.27s
# 243:	learn: 0.4942608	total: 1.21s	remaining: 1.26s
# 244:	learn: 0.4939534	total: 1.21s	remaining: 1.26s
# 245:	learn: 0.4937286	total: 1.21s	remaining: 1.25s
# 246:	learn: 0.4934395	total: 1.22s	remaining: 1.25s
# 247:	learn: 0.4931603	total: 1.22s	remaining: 1.24s
# 248:	learn: 0.4928173	total: 1.23s	remaining: 1.24s
# 249:	learn: 0.4926199	total: 1.23s	remaining: 1.23s
# 250:	learn: 0.4923523	total: 1.24s	remaining: 1.23s
# 251:	learn: 0.4920563	total: 1.24s	remaining: 1.22s
# 252:	learn: 0.4918689	total: 1.25s	remaining: 1.22s
# 253:	learn: 0.4915281	total: 1.25s	remaining: 1.21s
# 254:	learn: 0.4913177	total: 1.26s	remaining: 1.21s
# 255:	learn: 0.4910726	total: 1.26s	remaining: 1.2s
# 256:	learn: 0.4907391	total: 1.27s	remaining: 1.2s
# 257:	learn: 0.4905473	total: 1.27s	remaining: 1.19s
# 258:	learn: 0.4902653	total: 1.28s	remaining: 1.19s
# 259:	learn: 0.4899795	total: 1.28s	remaining: 1.18s
# 260:	learn: 0.4895445	total: 1.29s	remaining: 1.18s
# 261:	learn: 0.4892552	total: 1.29s	remaining: 1.17s
# 262:	learn: 0.4891117	total: 1.3s	remaining: 1.17s
# 263:	learn: 0.4887812	total: 1.3s	remaining: 1.16s
# 264:	learn: 0.4885867	total: 1.31s	remaining: 1.16s
# 265:	learn: 0.4883947	total: 1.31s	remaining: 1.15s
# 266:	learn: 0.4881747	total: 1.32s	remaining: 1.15s
# 267:	learn: 0.4878743	total: 1.32s	remaining: 1.14s
# 268:	learn: 0.4876533	total: 1.33s	remaining: 1.14s
# 269:	learn: 0.4874924	total: 1.33s	remaining: 1.14s
# 270:	learn: 0.4872154	total: 1.34s	remaining: 1.13s
# 271:	learn: 0.4868064	total: 1.34s	remaining: 1.13s
# 272:	learn: 0.4865885	total: 1.35s	remaining: 1.12s
# 273:	learn: 0.4862912	total: 1.35s	remaining: 1.11s
# 274:	learn: 0.4860283	total: 1.36s	remaining: 1.11s
# 275:	learn: 0.4857692	total: 1.36s	remaining: 1.1s
# 276:	learn: 0.4854173	total: 1.36s	remaining: 1.1s
# 277:	learn: 0.4852055	total: 1.37s	remaining: 1.09s
# 278:	learn: 0.4849450	total: 1.38s	remaining: 1.09s
# 279:	learn: 0.4846228	total: 1.38s	remaining: 1.08s
# 280:	learn: 0.4844210	total: 1.38s	remaining: 1.08s
# 281:	learn: 0.4841758	total: 1.39s	remaining: 1.07s
# 282:	learn: 0.4838423	total: 1.39s	remaining: 1.07s
# 283:	learn: 0.4835906	total: 1.4s	remaining: 1.06s
# 284:	learn: 0.4832568	total: 1.4s	remaining: 1.06s
# 285:	learn: 0.4829545	total: 1.41s	remaining: 1.05s
# 286:	learn: 0.4827683	total: 1.41s	remaining: 1.05s
# 287:	learn: 0.4825856	total: 1.42s	remaining: 1.04s
# 288:	learn: 0.4823655	total: 1.42s	remaining: 1.04s
# 289:	learn: 0.4821006	total: 1.43s	remaining: 1.03s
# 290:	learn: 0.4818747	total: 1.43s	remaining: 1.03s
# 291:	learn: 0.4815391	total: 1.44s	remaining: 1.02s
# 292:	learn: 0.4813365	total: 1.44s	remaining: 1.02s
# 293:	learn: 0.4810413	total: 1.45s	remaining: 1.01s
# 294:	learn: 0.4807214	total: 1.45s	remaining: 1.01s
# 295:	learn: 0.4804787	total: 1.46s	remaining: 1s
# 296:	learn: 0.4801949	total: 1.46s	remaining: 999ms
# 297:	learn: 0.4799640	total: 1.47s	remaining: 994ms
# 298:	learn: 0.4797776	total: 1.47s	remaining: 990ms
# 299:	learn: 0.4794678	total: 1.48s	remaining: 985ms
# 300:	learn: 0.4792969	total: 1.48s	remaining: 980ms
# 301:	learn: 0.4789686	total: 1.49s	remaining: 975ms
# 302:	learn: 0.4787024	total: 1.49s	remaining: 971ms
# 303:	learn: 0.4784186	total: 1.5s	remaining: 966ms
# 304:	learn: 0.4781089	total: 1.5s	remaining: 961ms
# 305:	learn: 0.4779395	total: 1.51s	remaining: 956ms
# 306:	learn: 0.4778200	total: 1.51s	remaining: 951ms
# 307:	learn: 0.4776070	total: 1.52s	remaining: 946ms
# 308:	learn: 0.4773103	total: 1.52s	remaining: 941ms
# 309:	learn: 0.4770705	total: 1.53s	remaining: 935ms
# 310:	learn: 0.4766781	total: 1.53s	remaining: 930ms
# 311:	learn: 0.4764262	total: 1.53s	remaining: 925ms
# 312:	learn: 0.4761209	total: 1.54s	remaining: 920ms
# 313:	learn: 0.4759786	total: 1.54s	remaining: 915ms
# 314:	learn: 0.4756664	total: 1.55s	remaining: 910ms
# 315:	learn: 0.4753971	total: 1.55s	remaining: 905ms
# 316:	learn: 0.4751530	total: 1.56s	remaining: 900ms
# 317:	learn: 0.4749657	total: 1.56s	remaining: 895ms
# 318:	learn: 0.4746417	total: 1.57s	remaining: 890ms
# 319:	learn: 0.4744818	total: 1.57s	remaining: 885ms
# 320:	learn: 0.4742195	total: 1.58s	remaining: 880ms
# 321:	learn: 0.4738932	total: 1.58s	remaining: 875ms
# 322:	learn: 0.4736771	total: 1.59s	remaining: 870ms
# 323:	learn: 0.4734624	total: 1.59s	remaining: 864ms
# 324:	learn: 0.4732833	total: 1.6s	remaining: 860ms
# 325:	learn: 0.4731020	total: 1.6s	remaining: 855ms
# 326:	learn: 0.4729113	total: 1.6s	remaining: 850ms
# 327:	learn: 0.4726738	total: 1.61s	remaining: 845ms
# 328:	learn: 0.4724506	total: 1.61s	remaining: 839ms
# 329:	learn: 0.4722513	total: 1.62s	remaining: 834ms
# 330:	learn: 0.4719836	total: 1.62s	remaining: 829ms
# 331:	learn: 0.4717473	total: 1.63s	remaining: 825ms
# 332:	learn: 0.4715243	total: 1.63s	remaining: 820ms
# 333:	learn: 0.4713403	total: 1.64s	remaining: 815ms
# 334:	learn: 0.4710685	total: 1.64s	remaining: 810ms
# 335:	learn: 0.4708941	total: 1.65s	remaining: 805ms
# 336:	learn: 0.4707063	total: 1.65s	remaining: 800ms
# 337:	learn: 0.4705029	total: 1.66s	remaining: 795ms
# 338:	learn: 0.4702373	total: 1.66s	remaining: 790ms
# 339:	learn: 0.4700434	total: 1.67s	remaining: 785ms
# 340:	learn: 0.4698471	total: 1.67s	remaining: 780ms
# 341:	learn: 0.4694761	total: 1.68s	remaining: 775ms
# 342:	learn: 0.4692614	total: 1.68s	remaining: 770ms
# 343:	learn: 0.4690220	total: 1.69s	remaining: 765ms
# 344:	learn: 0.4688148	total: 1.69s	remaining: 760ms
# 345:	learn: 0.4684746	total: 1.7s	remaining: 755ms
# 346:	learn: 0.4682945	total: 1.7s	remaining: 750ms
# 347:	learn: 0.4680438	total: 1.71s	remaining: 745ms
# 348:	learn: 0.4677302	total: 1.71s	remaining: 740ms
# 349:	learn: 0.4675379	total: 1.72s	remaining: 735ms
# 350:	learn: 0.4673056	total: 1.72s	remaining: 731ms
# 351:	learn: 0.4670143	total: 1.73s	remaining: 726ms
# 352:	learn: 0.4668253	total: 1.73s	remaining: 721ms
# 353:	learn: 0.4666397	total: 1.74s	remaining: 716ms
# 354:	learn: 0.4663066	total: 1.74s	remaining: 711ms
# 355:	learn: 0.4660335	total: 1.75s	remaining: 706ms
# 356:	learn: 0.4658188	total: 1.75s	remaining: 701ms
# 357:	learn: 0.4656156	total: 1.75s	remaining: 696ms
# 358:	learn: 0.4653876	total: 1.76s	remaining: 691ms
# 359:	learn: 0.4651051	total: 1.76s	remaining: 686ms
# 360:	learn: 0.4649046	total: 1.77s	remaining: 681ms
# 361:	learn: 0.4646815	total: 1.77s	remaining: 676ms
# 362:	learn: 0.4645466	total: 1.78s	remaining: 671ms
# 363:	learn: 0.4644148	total: 1.78s	remaining: 666ms
# 364:	learn: 0.4641658	total: 1.79s	remaining: 661ms
# 365:	learn: 0.4639560	total: 1.79s	remaining: 657ms
# 366:	learn: 0.4636695	total: 1.8s	remaining: 652ms
# 367:	learn: 0.4635176	total: 1.8s	remaining: 646ms
# 368:	learn: 0.4632715	total: 1.81s	remaining: 641ms
# 369:	learn: 0.4630580	total: 1.81s	remaining: 637ms
# 370:	learn: 0.4628254	total: 1.82s	remaining: 632ms
# 371:	learn: 0.4625352	total: 1.82s	remaining: 627ms
# 372:	learn: 0.4623636	total: 1.82s	remaining: 622ms
# 373:	learn: 0.4621207	total: 1.83s	remaining: 617ms
# 374:	learn: 0.4617987	total: 1.84s	remaining: 612ms
# 375:	learn: 0.4615745	total: 1.84s	remaining: 607ms
# 376:	learn: 0.4613099	total: 1.85s	remaining: 602ms
# 377:	learn: 0.4610242	total: 1.85s	remaining: 597ms
# 378:	learn: 0.4607791	total: 1.85s	remaining: 592ms
# 379:	learn: 0.4604954	total: 1.86s	remaining: 587ms
# 380:	learn: 0.4603275	total: 1.86s	remaining: 582ms
# 381:	learn: 0.4601332	total: 1.87s	remaining: 577ms
# 382:	learn: 0.4599649	total: 1.87s	remaining: 572ms
# 383:	learn: 0.4597980	total: 1.88s	remaining: 567ms
# 384:	learn: 0.4595725	total: 1.88s	remaining: 562ms
# 385:	learn: 0.4592921	total: 1.89s	remaining: 557ms
# 386:	learn: 0.4591081	total: 1.89s	remaining: 552ms
# 387:	learn: 0.4589394	total: 1.9s	remaining: 547ms
# 388:	learn: 0.4587178	total: 1.9s	remaining: 543ms
# 389:	learn: 0.4584374	total: 1.91s	remaining: 538ms
# 390:	learn: 0.4582590	total: 1.91s	remaining: 533ms
# 391:	learn: 0.4579628	total: 1.92s	remaining: 528ms
# 392:	learn: 0.4577017	total: 1.92s	remaining: 523ms
# 393:	learn: 0.4574660	total: 1.93s	remaining: 518ms
# 394:	learn: 0.4572753	total: 1.93s	remaining: 514ms
# 395:	learn: 0.4570629	total: 1.94s	remaining: 508ms
# 396:	learn: 0.4568123	total: 1.94s	remaining: 504ms
# 397:	learn: 0.4564884	total: 1.95s	remaining: 499ms
# 398:	learn: 0.4562306	total: 1.95s	remaining: 494ms
# 399:	learn: 0.4560911	total: 1.96s	remaining: 489ms
# 400:	learn: 0.4558892	total: 1.96s	remaining: 484ms
# 401:	learn: 0.4556822	total: 1.96s	remaining: 479ms
# 402:	learn: 0.4555416	total: 1.97s	remaining: 474ms
# 403:	learn: 0.4553066	total: 1.97s	remaining: 469ms
# 404:	learn: 0.4551127	total: 1.98s	remaining: 464ms
# 405:	learn: 0.4549583	total: 1.98s	remaining: 459ms
# 406:	learn: 0.4546917	total: 1.99s	remaining: 455ms
# 407:	learn: 0.4543803	total: 1.99s	remaining: 450ms
# 408:	learn: 0.4541667	total: 2s	remaining: 445ms
# 409:	learn: 0.4539826	total: 2s	remaining: 440ms
# 410:	learn: 0.4538086	total: 2.01s	remaining: 435ms
# 411:	learn: 0.4536915	total: 2.01s	remaining: 430ms
# 412:	learn: 0.4534519	total: 2.02s	remaining: 425ms
# 413:	learn: 0.4532522	total: 2.02s	remaining: 421ms
# 414:	learn: 0.4530893	total: 2.03s	remaining: 416ms
# 415:	learn: 0.4528859	total: 2.03s	remaining: 411ms
# 416:	learn: 0.4526505	total: 2.04s	remaining: 406ms
# 417:	learn: 0.4523769	total: 2.04s	remaining: 401ms
# 418:	learn: 0.4521297	total: 2.05s	remaining: 396ms
# 419:	learn: 0.4519587	total: 2.05s	remaining: 391ms
# 420:	learn: 0.4517101	total: 2.06s	remaining: 386ms
# 421:	learn: 0.4515535	total: 2.06s	remaining: 381ms
# 422:	learn: 0.4513272	total: 2.07s	remaining: 376ms
# 423:	learn: 0.4511622	total: 2.07s	remaining: 371ms
# 424:	learn: 0.4509754	total: 2.08s	remaining: 366ms
# 425:	learn: 0.4505109	total: 2.08s	remaining: 361ms
# 426:	learn: 0.4503486	total: 2.08s	remaining: 357ms
# 427:	learn: 0.4500602	total: 2.09s	remaining: 352ms
# 428:	learn: 0.4498779	total: 2.09s	remaining: 347ms
# 429:	learn: 0.4496126	total: 2.1s	remaining: 342ms
# 430:	learn: 0.4494310	total: 2.1s	remaining: 337ms
# 431:	learn: 0.4492511	total: 2.11s	remaining: 332ms
# 432:	learn: 0.4490304	total: 2.11s	remaining: 327ms
# 433:	learn: 0.4488610	total: 2.12s	remaining: 322ms
# 434:	learn: 0.4486290	total: 2.12s	remaining: 317ms
# 435:	learn: 0.4483040	total: 2.13s	remaining: 312ms
# 436:	learn: 0.4480824	total: 2.13s	remaining: 307ms
# 437:	learn: 0.4479012	total: 2.14s	remaining: 302ms
# 438:	learn: 0.4477041	total: 2.14s	remaining: 298ms
# 439:	learn: 0.4475390	total: 2.15s	remaining: 293ms
# 440:	learn: 0.4473233	total: 2.15s	remaining: 288ms
# 441:	learn: 0.4471299	total: 2.15s	remaining: 283ms
# 442:	learn: 0.4469389	total: 2.16s	remaining: 278ms
# 443:	learn: 0.4467140	total: 2.16s	remaining: 273ms
# 444:	learn: 0.4465194	total: 2.17s	remaining: 268ms
# 445:	learn: 0.4463960	total: 2.17s	remaining: 263ms
# 446:	learn: 0.4462554	total: 2.18s	remaining: 258ms
# 447:	learn: 0.4460254	total: 2.18s	remaining: 253ms
# 448:	learn: 0.4458433	total: 2.19s	remaining: 248ms
# 449:	learn: 0.4457175	total: 2.19s	remaining: 243ms
# 450:	learn: 0.4455115	total: 2.19s	remaining: 239ms
# 451:	learn: 0.4452727	total: 2.2s	remaining: 234ms
# 452:	learn: 0.4451094	total: 2.21s	remaining: 229ms
# 453:	learn: 0.4448361	total: 2.21s	remaining: 224ms
# 454:	learn: 0.4446092	total: 2.21s	remaining: 219ms
# 455:	learn: 0.4444878	total: 2.22s	remaining: 214ms
# 456:	learn: 0.4443104	total: 2.22s	remaining: 209ms
# 457:	learn: 0.4440971	total: 2.23s	remaining: 204ms
# 458:	learn: 0.4437570	total: 2.23s	remaining: 199ms
# 459:	learn: 0.4435811	total: 2.24s	remaining: 195ms
# 460:	learn: 0.4434110	total: 2.24s	remaining: 190ms
# 461:	learn: 0.4431559	total: 2.25s	remaining: 185ms
# 462:	learn: 0.4429633	total: 2.25s	remaining: 180ms
# 463:	learn: 0.4427856	total: 2.26s	remaining: 175ms
# 464:	learn: 0.4426158	total: 2.26s	remaining: 170ms
# 465:	learn: 0.4424408	total: 2.27s	remaining: 165ms
# 466:	learn: 0.4421346	total: 2.27s	remaining: 161ms
# 467:	learn: 0.4419225	total: 2.28s	remaining: 156ms
# 468:	learn: 0.4416720	total: 2.28s	remaining: 151ms
# 469:	learn: 0.4414521	total: 2.29s	remaining: 146ms
# 470:	learn: 0.4412609	total: 2.29s	remaining: 141ms
# 471:	learn: 0.4411303	total: 2.29s	remaining: 136ms
# 472:	learn: 0.4408922	total: 2.3s	remaining: 131ms
# 473:	learn: 0.4406625	total: 2.3s	remaining: 126ms
# 474:	learn: 0.4403942	total: 2.31s	remaining: 122ms
# 475:	learn: 0.4401947	total: 2.31s	remaining: 117ms
# 476:	learn: 0.4399798	total: 2.32s	remaining: 112ms
# 477:	learn: 0.4398588	total: 2.32s	remaining: 107ms
# 478:	learn: 0.4396377	total: 2.33s	remaining: 102ms
# 479:	learn: 0.4394872	total: 2.33s	remaining: 97.2ms
# 480:	learn: 0.4392601	total: 2.34s	remaining: 92.3ms
# 481:	learn: 0.4391094	total: 2.34s	remaining: 87.5ms
# 482:	learn: 0.4389499	total: 2.35s	remaining: 82.6ms
# 483:	learn: 0.4387395	total: 2.35s	remaining: 77.7ms
# 484:	learn: 0.4385619	total: 2.35s	remaining: 72.9ms
# 485:	learn: 0.4384184	total: 2.36s	remaining: 68ms
# 486:	learn: 0.4382028	total: 2.36s	remaining: 63.1ms
# 487:	learn: 0.4380573	total: 2.37s	remaining: 58.3ms
# 488:	learn: 0.4377918	total: 2.37s	remaining: 53.4ms
# 489:	learn: 0.4375370	total: 2.38s	remaining: 48.5ms
# 490:	learn: 0.4373733	total: 2.38s	remaining: 43.7ms
# 491:	learn: 0.4372220	total: 2.39s	remaining: 38.8ms
# 492:	learn: 0.4370326	total: 2.39s	remaining: 34ms
# 493:	learn: 0.4368253	total: 2.4s	remaining: 29.1ms
# 494:	learn: 0.4364982	total: 2.4s	remaining: 24.3ms
# 495:	learn: 0.4363412	total: 2.41s	remaining: 19.4ms
# 496:	learn: 0.4362013	total: 2.41s	remaining: 14.6ms
# 497:	learn: 0.4358998	total: 2.42s	remaining: 9.7ms
# 498:	learn: 0.4357355	total: 2.42s	remaining: 4.85ms
# 499:	learn: 0.4356641	total: 2.42s	remaining: 0us
# 0:	learn: 0.6813988	total: 4.54ms	remaining: 2.26s
# 1:	learn: 0.6715650	total: 9.64ms	remaining: 2.4s
# 2:	learn: 0.6628739	total: 14.1ms	remaining: 2.33s
# 3:	learn: 0.6551080	total: 18.6ms	remaining: 2.31s
# 4:	learn: 0.6482661	total: 22.6ms	remaining: 2.24s
# 5:	learn: 0.6419852	total: 27ms	remaining: 2.22s
# 6:	learn: 0.6364409	total: 30.8ms	remaining: 2.17s
# 7:	learn: 0.6318693	total: 36.5ms	remaining: 2.24s
# 8:	learn: 0.6275078	total: 40.4ms	remaining: 2.21s
# 9:	learn: 0.6233319	total: 44.6ms	remaining: 2.19s
# 10:	learn: 0.6196270	total: 49.6ms	remaining: 2.2s
# 11:	learn: 0.6162364	total: 53.9ms	remaining: 2.19s
# 12:	learn: 0.6130055	total: 58.3ms	remaining: 2.19s
# 13:	learn: 0.6101429	total: 62.5ms	remaining: 2.17s
# 14:	learn: 0.6073031	total: 66.5ms	remaining: 2.15s
# 15:	learn: 0.6050012	total: 70.7ms	remaining: 2.14s
# 16:	learn: 0.6030448	total: 74.9ms	remaining: 2.13s
# 17:	learn: 0.6007232	total: 79.3ms	remaining: 2.12s
# 18:	learn: 0.5987096	total: 83.6ms	remaining: 2.12s
# 19:	learn: 0.5967173	total: 88.4ms	remaining: 2.12s
# 20:	learn: 0.5948765	total: 93.2ms	remaining: 2.13s
# 21:	learn: 0.5932537	total: 97.7ms	remaining: 2.12s
# 22:	learn: 0.5917693	total: 102ms	remaining: 2.12s
# 23:	learn: 0.5900508	total: 106ms	remaining: 2.11s
# 24:	learn: 0.5886487	total: 111ms	remaining: 2.11s
# 25:	learn: 0.5872991	total: 115ms	remaining: 2.09s
# 26:	learn: 0.5859583	total: 119ms	remaining: 2.08s
# 27:	learn: 0.5846856	total: 123ms	remaining: 2.07s
# 28:	learn: 0.5833527	total: 127ms	remaining: 2.06s
# 29:	learn: 0.5822523	total: 132ms	remaining: 2.06s
# 30:	learn: 0.5814244	total: 136ms	remaining: 2.06s
# 31:	learn: 0.5803751	total: 142ms	remaining: 2.07s
# 32:	learn: 0.5792392	total: 146ms	remaining: 2.07s
# 33:	learn: 0.5783464	total: 151ms	remaining: 2.07s
# 34:	learn: 0.5776245	total: 155ms	remaining: 2.06s
# 35:	learn: 0.5766779	total: 160ms	remaining: 2.06s
# 36:	learn: 0.5756874	total: 164ms	remaining: 2.05s
# 37:	learn: 0.5739962	total: 168ms	remaining: 2.04s
# 38:	learn: 0.5733147	total: 172ms	remaining: 2.04s
# 39:	learn: 0.5723852	total: 177ms	remaining: 2.03s
# 40:	learn: 0.5717157	total: 181ms	remaining: 2.02s
# 41:	learn: 0.5710871	total: 185ms	remaining: 2.01s
# 42:	learn: 0.5702528	total: 189ms	remaining: 2.01s
# 43:	learn: 0.5696651	total: 193ms	remaining: 2s
# 44:	learn: 0.5691335	total: 197ms	remaining: 1.99s
# 45:	learn: 0.5683331	total: 202ms	remaining: 1.99s
# 46:	learn: 0.5676288	total: 206ms	remaining: 1.99s
# 47:	learn: 0.5668543	total: 210ms	remaining: 1.98s
# 48:	learn: 0.5661472	total: 215ms	remaining: 1.98s
# 49:	learn: 0.5655690	total: 219ms	remaining: 1.97s
# 50:	learn: 0.5649478	total: 224ms	remaining: 1.97s
# 51:	learn: 0.5641631	total: 228ms	remaining: 1.96s
# 52:	learn: 0.5636696	total: 232ms	remaining: 1.96s
# 53:	learn: 0.5630841	total: 236ms	remaining: 1.95s
# 54:	learn: 0.5625524	total: 241ms	remaining: 1.95s
# 55:	learn: 0.5620289	total: 245ms	remaining: 1.94s
# 56:	learn: 0.5615127	total: 249ms	remaining: 1.93s
# 57:	learn: 0.5608695	total: 253ms	remaining: 1.93s
# 58:	learn: 0.5603280	total: 257ms	remaining: 1.92s
# 59:	learn: 0.5597809	total: 262ms	remaining: 1.92s
# 60:	learn: 0.5593212	total: 266ms	remaining: 1.92s
# 61:	learn: 0.5588343	total: 271ms	remaining: 1.91s
# 62:	learn: 0.5584314	total: 275ms	remaining: 1.91s
# 63:	learn: 0.5577129	total: 280ms	remaining: 1.91s
# 64:	learn: 0.5573830	total: 284ms	remaining: 1.9s
# 65:	learn: 0.5568746	total: 289ms	remaining: 1.9s
# 66:	learn: 0.5563243	total: 294ms	remaining: 1.9s
# 67:	learn: 0.5558620	total: 298ms	remaining: 1.89s
# 68:	learn: 0.5553475	total: 303ms	remaining: 1.89s
# 69:	learn: 0.5548571	total: 307ms	remaining: 1.89s
# 70:	learn: 0.5544315	total: 311ms	remaining: 1.88s
# 71:	learn: 0.5540768	total: 315ms	remaining: 1.87s
# 72:	learn: 0.5537554	total: 319ms	remaining: 1.87s
# 73:	learn: 0.5531371	total: 324ms	remaining: 1.87s
# 74:	learn: 0.5525614	total: 329ms	remaining: 1.86s
# 75:	learn: 0.5523214	total: 333ms	remaining: 1.86s
# 76:	learn: 0.5519376	total: 337ms	remaining: 1.85s
# 77:	learn: 0.5514464	total: 341ms	remaining: 1.85s
# 78:	learn: 0.5507972	total: 346ms	remaining: 1.84s
# 79:	learn: 0.5504546	total: 350ms	remaining: 1.84s
# 80:	learn: 0.5500131	total: 354ms	remaining: 1.83s
# 81:	learn: 0.5493182	total: 359ms	remaining: 1.83s
# 82:	learn: 0.5489208	total: 362ms	remaining: 1.82s
# 83:	learn: 0.5485125	total: 367ms	remaining: 1.81s
# 84:	learn: 0.5476010	total: 371ms	remaining: 1.81s
# 85:	learn: 0.5471330	total: 375ms	remaining: 1.81s
# 86:	learn: 0.5466845	total: 379ms	remaining: 1.8s
# 87:	learn: 0.5462448	total: 384ms	remaining: 1.8s
# 88:	learn: 0.5459258	total: 388ms	remaining: 1.79s
# 89:	learn: 0.5455035	total: 392ms	remaining: 1.79s
# 90:	learn: 0.5449431	total: 397ms	remaining: 1.78s
# 91:	learn: 0.5445191	total: 402ms	remaining: 1.78s
# 92:	learn: 0.5441453	total: 407ms	remaining: 1.78s
# 93:	learn: 0.5437951	total: 411ms	remaining: 1.77s
# 94:	learn: 0.5434489	total: 415ms	remaining: 1.77s
# 95:	learn: 0.5431092	total: 420ms	remaining: 1.77s
# 96:	learn: 0.5425733	total: 424ms	remaining: 1.76s
# 97:	learn: 0.5421124	total: 429ms	remaining: 1.76s
# 98:	learn: 0.5417374	total: 433ms	remaining: 1.75s
# 99:	learn: 0.5413443	total: 437ms	remaining: 1.75s
# 100:	learn: 0.5409565	total: 441ms	remaining: 1.74s
# 101:	learn: 0.5405285	total: 446ms	remaining: 1.74s
# 102:	learn: 0.5399933	total: 451ms	remaining: 1.74s
# 103:	learn: 0.5396318	total: 456ms	remaining: 1.74s
# 104:	learn: 0.5391409	total: 461ms	remaining: 1.73s
# 105:	learn: 0.5387452	total: 465ms	remaining: 1.73s
# 106:	learn: 0.5384265	total: 469ms	remaining: 1.72s
# 107:	learn: 0.5381020	total: 474ms	remaining: 1.72s
# 108:	learn: 0.5377081	total: 478ms	remaining: 1.71s
# 109:	learn: 0.5373252	total: 482ms	remaining: 1.71s
# 110:	learn: 0.5367657	total: 486ms	remaining: 1.7s
# 111:	learn: 0.5362408	total: 491ms	remaining: 1.7s
# 112:	learn: 0.5358930	total: 496ms	remaining: 1.7s
# 113:	learn: 0.5354375	total: 501ms	remaining: 1.69s
# 114:	learn: 0.5349205	total: 505ms	remaining: 1.69s
# 115:	learn: 0.5345409	total: 509ms	remaining: 1.68s
# 116:	learn: 0.5341872	total: 513ms	remaining: 1.68s
# 117:	learn: 0.5337930	total: 518ms	remaining: 1.68s
# 118:	learn: 0.5333390	total: 522ms	remaining: 1.67s
# 119:	learn: 0.5328939	total: 526ms	remaining: 1.67s
# 120:	learn: 0.5323729	total: 531ms	remaining: 1.66s
# 121:	learn: 0.5319404	total: 535ms	remaining: 1.66s
# 122:	learn: 0.5316925	total: 539ms	remaining: 1.65s
# 123:	learn: 0.5313301	total: 543ms	remaining: 1.65s
# 124:	learn: 0.5308470	total: 547ms	remaining: 1.64s
# 125:	learn: 0.5304839	total: 552ms	remaining: 1.64s
# 126:	learn: 0.5299558	total: 556ms	remaining: 1.63s
# 127:	learn: 0.5294178	total: 560ms	remaining: 1.63s
# 128:	learn: 0.5290028	total: 565ms	remaining: 1.62s
# 129:	learn: 0.5284836	total: 569ms	remaining: 1.62s
# 130:	learn: 0.5281188	total: 573ms	remaining: 1.61s
# 131:	learn: 0.5277839	total: 577ms	remaining: 1.61s
# 132:	learn: 0.5273827	total: 581ms	remaining: 1.6s
# 133:	learn: 0.5270058	total: 586ms	remaining: 1.6s
# 134:	learn: 0.5264651	total: 590ms	remaining: 1.59s
# 135:	learn: 0.5259255	total: 594ms	remaining: 1.59s
# 136:	learn: 0.5255283	total: 598ms	remaining: 1.58s
# 137:	learn: 0.5251759	total: 603ms	remaining: 1.58s
# 138:	learn: 0.5247669	total: 607ms	remaining: 1.58s
# 139:	learn: 0.5242391	total: 611ms	remaining: 1.57s
# 140:	learn: 0.5238576	total: 615ms	remaining: 1.57s
# 141:	learn: 0.5235188	total: 619ms	remaining: 1.56s
# 142:	learn: 0.5227488	total: 626ms	remaining: 1.56s
# 143:	learn: 0.5223946	total: 630ms	remaining: 1.56s
# 144:	learn: 0.5219705	total: 633ms	remaining: 1.55s
# 145:	learn: 0.5215466	total: 638ms	remaining: 1.55s
# 146:	learn: 0.5211048	total: 643ms	remaining: 1.54s
# 147:	learn: 0.5207409	total: 648ms	remaining: 1.54s
# 148:	learn: 0.5203864	total: 653ms	remaining: 1.54s
# 149:	learn: 0.5200352	total: 658ms	remaining: 1.53s
# 150:	learn: 0.5196730	total: 663ms	remaining: 1.53s
# 151:	learn: 0.5193237	total: 667ms	remaining: 1.53s
# 152:	learn: 0.5189986	total: 672ms	remaining: 1.52s
# 153:	learn: 0.5186933	total: 676ms	remaining: 1.52s
# 154:	learn: 0.5182941	total: 681ms	remaining: 1.51s
# 155:	learn: 0.5179609	total: 685ms	remaining: 1.51s
# 156:	learn: 0.5174973	total: 689ms	remaining: 1.5s
# 157:	learn: 0.5167012	total: 693ms	remaining: 1.5s
# 158:	learn: 0.5164598	total: 697ms	remaining: 1.5s
# 159:	learn: 0.5161299	total: 702ms	remaining: 1.49s
# 160:	learn: 0.5157434	total: 706ms	remaining: 1.49s
# 161:	learn: 0.5153790	total: 710ms	remaining: 1.48s
# 162:	learn: 0.5149816	total: 714ms	remaining: 1.48s
# 163:	learn: 0.5146640	total: 718ms	remaining: 1.47s
# 164:	learn: 0.5144099	total: 723ms	remaining: 1.47s
# 165:	learn: 0.5140591	total: 727ms	remaining: 1.46s
# 166:	learn: 0.5136282	total: 731ms	remaining: 1.46s
# 167:	learn: 0.5134017	total: 735ms	remaining: 1.45s
# 168:	learn: 0.5130760	total: 740ms	remaining: 1.45s
# 169:	learn: 0.5125905	total: 744ms	remaining: 1.44s
# 170:	learn: 0.5123915	total: 748ms	remaining: 1.44s
# 171:	learn: 0.5119628	total: 752ms	remaining: 1.43s
# 172:	learn: 0.5117053	total: 757ms	remaining: 1.43s
# 173:	learn: 0.5114048	total: 761ms	remaining: 1.43s
# 174:	learn: 0.5110362	total: 765ms	remaining: 1.42s
# 175:	learn: 0.5106039	total: 769ms	remaining: 1.42s
# 176:	learn: 0.5102619	total: 773ms	remaining: 1.41s
# 177:	learn: 0.5097905	total: 777ms	remaining: 1.41s
# 178:	learn: 0.5093317	total: 782ms	remaining: 1.4s
# 179:	learn: 0.5089378	total: 786ms	remaining: 1.4s
# 180:	learn: 0.5085608	total: 791ms	remaining: 1.39s
# 181:	learn: 0.5083265	total: 795ms	remaining: 1.39s
# 182:	learn: 0.5080286	total: 800ms	remaining: 1.39s
# 183:	learn: 0.5076479	total: 804ms	remaining: 1.38s
# 184:	learn: 0.5073191	total: 808ms	remaining: 1.38s
# 185:	learn: 0.5068728	total: 813ms	remaining: 1.37s
# 186:	learn: 0.5064995	total: 817ms	remaining: 1.37s
# 187:	learn: 0.5059017	total: 822ms	remaining: 1.36s
# 188:	learn: 0.5055305	total: 828ms	remaining: 1.36s
# 189:	learn: 0.5052114	total: 834ms	remaining: 1.36s
# 190:	learn: 0.5048412	total: 840ms	remaining: 1.36s
# 191:	learn: 0.5044486	total: 845ms	remaining: 1.35s
# 192:	learn: 0.5041266	total: 849ms	remaining: 1.35s
# 193:	learn: 0.5035461	total: 853ms	remaining: 1.35s
# 194:	learn: 0.5033476	total: 858ms	remaining: 1.34s
# 195:	learn: 0.5030326	total: 862ms	remaining: 1.34s
# 196:	learn: 0.5026638	total: 866ms	remaining: 1.33s
# 197:	learn: 0.5022932	total: 870ms	remaining: 1.33s
# 198:	learn: 0.5020265	total: 875ms	remaining: 1.32s
# 199:	learn: 0.5015944	total: 879ms	remaining: 1.32s
# 200:	learn: 0.5011004	total: 883ms	remaining: 1.31s
# 201:	learn: 0.5007679	total: 888ms	remaining: 1.31s
# 202:	learn: 0.5005417	total: 892ms	remaining: 1.3s
# 203:	learn: 0.5000906	total: 896ms	remaining: 1.3s
# 204:	learn: 0.4998194	total: 901ms	remaining: 1.29s
# 205:	learn: 0.4994604	total: 905ms	remaining: 1.29s
# 206:	learn: 0.4992869	total: 909ms	remaining: 1.29s
# 207:	learn: 0.4989009	total: 913ms	remaining: 1.28s
# 208:	learn: 0.4985970	total: 918ms	remaining: 1.28s
# 209:	learn: 0.4982316	total: 922ms	remaining: 1.27s
# 210:	learn: 0.4978389	total: 926ms	remaining: 1.27s
# 211:	learn: 0.4975193	total: 930ms	remaining: 1.26s
# 212:	learn: 0.4972311	total: 935ms	remaining: 1.26s
# 213:	learn: 0.4969525	total: 939ms	remaining: 1.25s
# 214:	learn: 0.4966730	total: 944ms	remaining: 1.25s
# 215:	learn: 0.4962103	total: 948ms	remaining: 1.25s
# 216:	learn: 0.4958479	total: 952ms	remaining: 1.24s
# 217:	learn: 0.4954479	total: 957ms	remaining: 1.24s
# 218:	learn: 0.4950551	total: 961ms	remaining: 1.23s
# 219:	learn: 0.4946472	total: 965ms	remaining: 1.23s
# 220:	learn: 0.4941144	total: 969ms	remaining: 1.22s
# 221:	learn: 0.4938477	total: 974ms	remaining: 1.22s
# 222:	learn: 0.4935062	total: 979ms	remaining: 1.22s
# 223:	learn: 0.4931517	total: 983ms	remaining: 1.21s
# 224:	learn: 0.4927803	total: 987ms	remaining: 1.21s
# 225:	learn: 0.4925142	total: 992ms	remaining: 1.2s
# 226:	learn: 0.4922053	total: 996ms	remaining: 1.2s
# 227:	learn: 0.4920064	total: 1s	remaining: 1.19s
# 228:	learn: 0.4917136	total: 1s	remaining: 1.19s
# 229:	learn: 0.4913575	total: 1.01s	remaining: 1.19s
# 230:	learn: 0.4908764	total: 1.01s	remaining: 1.18s
# 231:	learn: 0.4904761	total: 1.02s	remaining: 1.18s
# 232:	learn: 0.4899749	total: 1.02s	remaining: 1.17s
# 233:	learn: 0.4896358	total: 1.03s	remaining: 1.17s
# 234:	learn: 0.4892663	total: 1.03s	remaining: 1.17s
# 235:	learn: 0.4889866	total: 1.04s	remaining: 1.16s
# 236:	learn: 0.4886873	total: 1.04s	remaining: 1.16s
# 237:	learn: 0.4882920	total: 1.05s	remaining: 1.15s
# 238:	learn: 0.4880069	total: 1.05s	remaining: 1.15s
# 239:	learn: 0.4876426	total: 1.05s	remaining: 1.14s
# 240:	learn: 0.4871628	total: 1.06s	remaining: 1.14s
# 241:	learn: 0.4868597	total: 1.06s	remaining: 1.13s
# 242:	learn: 0.4865146	total: 1.07s	remaining: 1.13s
# 243:	learn: 0.4863068	total: 1.07s	remaining: 1.13s
# 244:	learn: 0.4859660	total: 1.08s	remaining: 1.12s
# 245:	learn: 0.4857009	total: 1.08s	remaining: 1.11s
# 246:	learn: 0.4853911	total: 1.08s	remaining: 1.11s
# 247:	learn: 0.4850439	total: 1.09s	remaining: 1.11s
# 248:	learn: 0.4846815	total: 1.09s	remaining: 1.1s
# 249:	learn: 0.4844411	total: 1.1s	remaining: 1.1s
# 250:	learn: 0.4841815	total: 1.1s	remaining: 1.09s
# 251:	learn: 0.4839584	total: 1.11s	remaining: 1.09s
# 252:	learn: 0.4836969	total: 1.11s	remaining: 1.08s
# 253:	learn: 0.4834876	total: 1.12s	remaining: 1.08s
# 254:	learn: 0.4831403	total: 1.12s	remaining: 1.08s
# 255:	learn: 0.4828468	total: 1.13s	remaining: 1.07s
# 256:	learn: 0.4825425	total: 1.13s	remaining: 1.07s
# 257:	learn: 0.4821577	total: 1.13s	remaining: 1.06s
# 258:	learn: 0.4816990	total: 1.14s	remaining: 1.06s
# 259:	learn: 0.4812132	total: 1.14s	remaining: 1.05s
# 260:	learn: 0.4809899	total: 1.15s	remaining: 1.05s
# 261:	learn: 0.4806369	total: 1.15s	remaining: 1.05s
# 262:	learn: 0.4803271	total: 1.16s	remaining: 1.04s
# 263:	learn: 0.4801254	total: 1.16s	remaining: 1.04s
# 264:	learn: 0.4797979	total: 1.16s	remaining: 1.03s
# 265:	learn: 0.4794728	total: 1.17s	remaining: 1.03s
# 266:	learn: 0.4792408	total: 1.17s	remaining: 1.02s
# 267:	learn: 0.4788816	total: 1.18s	remaining: 1.02s
# 268:	learn: 0.4784982	total: 1.18s	remaining: 1.01s
# 269:	learn: 0.4781782	total: 1.19s	remaining: 1.01s
# 270:	learn: 0.4777516	total: 1.19s	remaining: 1.01s
# 271:	learn: 0.4774955	total: 1.2s	remaining: 1s
# 272:	learn: 0.4770848	total: 1.2s	remaining: 998ms
# 273:	learn: 0.4768034	total: 1.2s	remaining: 994ms
# 274:	learn: 0.4764707	total: 1.21s	remaining: 990ms
# 275:	learn: 0.4761671	total: 1.22s	remaining: 987ms
# 276:	learn: 0.4758735	total: 1.22s	remaining: 983ms
# 277:	learn: 0.4755581	total: 1.23s	remaining: 979ms
# 278:	learn: 0.4752330	total: 1.23s	remaining: 975ms
# 279:	learn: 0.4747877	total: 1.23s	remaining: 970ms
# 280:	learn: 0.4745723	total: 1.24s	remaining: 966ms
# 281:	learn: 0.4743406	total: 1.24s	remaining: 961ms
# 282:	learn: 0.4739673	total: 1.25s	remaining: 957ms
# 283:	learn: 0.4737362	total: 1.25s	remaining: 953ms
# 284:	learn: 0.4733508	total: 1.26s	remaining: 949ms
# 285:	learn: 0.4731224	total: 1.26s	remaining: 944ms
# 286:	learn: 0.4729503	total: 1.27s	remaining: 940ms
# 287:	learn: 0.4726213	total: 1.27s	remaining: 935ms
# 288:	learn: 0.4723121	total: 1.27s	remaining: 931ms
# 289:	learn: 0.4720322	total: 1.28s	remaining: 927ms
# 290:	learn: 0.4717744	total: 1.28s	remaining: 922ms
# 291:	learn: 0.4715657	total: 1.29s	remaining: 918ms
# 292:	learn: 0.4713353	total: 1.29s	remaining: 913ms
# 293:	learn: 0.4710445	total: 1.3s	remaining: 909ms
# 294:	learn: 0.4707639	total: 1.3s	remaining: 904ms
# 295:	learn: 0.4704602	total: 1.3s	remaining: 900ms
# 296:	learn: 0.4701731	total: 1.31s	remaining: 895ms
# 297:	learn: 0.4699682	total: 1.31s	remaining: 891ms
# 298:	learn: 0.4695877	total: 1.32s	remaining: 886ms
# 299:	learn: 0.4691938	total: 1.32s	remaining: 882ms
# 300:	learn: 0.4689508	total: 1.33s	remaining: 878ms
# 301:	learn: 0.4686879	total: 1.33s	remaining: 873ms
# 302:	learn: 0.4683918	total: 1.33s	remaining: 868ms
# 303:	learn: 0.4681053	total: 1.34s	remaining: 864ms
# 304:	learn: 0.4677985	total: 1.34s	remaining: 860ms
# 305:	learn: 0.4675255	total: 1.35s	remaining: 856ms
# 306:	learn: 0.4672283	total: 1.35s	remaining: 851ms
# 307:	learn: 0.4669317	total: 1.36s	remaining: 847ms
# 308:	learn: 0.4666312	total: 1.36s	remaining: 842ms
# 309:	learn: 0.4663467	total: 1.37s	remaining: 838ms
# 310:	learn: 0.4660818	total: 1.37s	remaining: 834ms
# 311:	learn: 0.4656457	total: 1.38s	remaining: 829ms
# 312:	learn: 0.4654079	total: 1.38s	remaining: 825ms
# 313:	learn: 0.4648746	total: 1.39s	remaining: 821ms
# 314:	learn: 0.4645704	total: 1.39s	remaining: 817ms
# 315:	learn: 0.4643368	total: 1.4s	remaining: 812ms
# 316:	learn: 0.4640698	total: 1.4s	remaining: 808ms
# 317:	learn: 0.4638855	total: 1.4s	remaining: 804ms
# 318:	learn: 0.4635892	total: 1.41s	remaining: 799ms
# 319:	learn: 0.4632803	total: 1.41s	remaining: 795ms
# 320:	learn: 0.4631429	total: 1.42s	remaining: 791ms
# 321:	learn: 0.4629377	total: 1.42s	remaining: 787ms
# 322:	learn: 0.4626277	total: 1.43s	remaining: 783ms
# 323:	learn: 0.4624112	total: 1.43s	remaining: 778ms
# 324:	learn: 0.4621860	total: 1.44s	remaining: 774ms
# 325:	learn: 0.4619046	total: 1.44s	remaining: 770ms
# 326:	learn: 0.4617571	total: 1.45s	remaining: 766ms
# 327:	learn: 0.4615305	total: 1.45s	remaining: 761ms
# 328:	learn: 0.4613731	total: 1.46s	remaining: 757ms
# 329:	learn: 0.4611439	total: 1.46s	remaining: 752ms
# 330:	learn: 0.4608728	total: 1.47s	remaining: 748ms
# 331:	learn: 0.4607212	total: 1.47s	remaining: 743ms
# 332:	learn: 0.4604641	total: 1.47s	remaining: 739ms
# 333:	learn: 0.4603140	total: 1.48s	remaining: 735ms
# 334:	learn: 0.4601226	total: 1.48s	remaining: 730ms
# 335:	learn: 0.4598561	total: 1.49s	remaining: 726ms
# 336:	learn: 0.4597123	total: 1.49s	remaining: 722ms
# 337:	learn: 0.4594932	total: 1.5s	remaining: 717ms
# 338:	learn: 0.4593036	total: 1.5s	remaining: 713ms
# 339:	learn: 0.4589181	total: 1.5s	remaining: 708ms
# 340:	learn: 0.4586220	total: 1.51s	remaining: 704ms
# 341:	learn: 0.4583431	total: 1.51s	remaining: 699ms
# 342:	learn: 0.4580659	total: 1.52s	remaining: 695ms
# 343:	learn: 0.4577613	total: 1.52s	remaining: 691ms
# 344:	learn: 0.4574415	total: 1.53s	remaining: 686ms
# 345:	learn: 0.4572548	total: 1.53s	remaining: 682ms
# 346:	learn: 0.4570044	total: 1.53s	remaining: 677ms
# 347:	learn: 0.4566983	total: 1.54s	remaining: 673ms
# 348:	learn: 0.4563959	total: 1.54s	remaining: 668ms
# 349:	learn: 0.4561274	total: 1.55s	remaining: 664ms
# 350:	learn: 0.4558323	total: 1.55s	remaining: 659ms
# 351:	learn: 0.4553811	total: 1.56s	remaining: 655ms
# 352:	learn: 0.4551543	total: 1.56s	remaining: 651ms
# 353:	learn: 0.4548794	total: 1.57s	remaining: 646ms
# 354:	learn: 0.4545952	total: 1.57s	remaining: 642ms
# 355:	learn: 0.4543401	total: 1.57s	remaining: 637ms
# 356:	learn: 0.4540736	total: 1.58s	remaining: 633ms
# 357:	learn: 0.4537775	total: 1.58s	remaining: 629ms
# 358:	learn: 0.4535109	total: 1.59s	remaining: 624ms
# 359:	learn: 0.4533247	total: 1.59s	remaining: 620ms
# 360:	learn: 0.4529968	total: 1.6s	remaining: 615ms
# 361:	learn: 0.4527424	total: 1.6s	remaining: 611ms
# 362:	learn: 0.4524372	total: 1.61s	remaining: 606ms
# 363:	learn: 0.4521458	total: 1.61s	remaining: 602ms
# 364:	learn: 0.4518065	total: 1.61s	remaining: 597ms
# 365:	learn: 0.4515595	total: 1.62s	remaining: 593ms
# 366:	learn: 0.4512463	total: 1.62s	remaining: 588ms
# 367:	learn: 0.4510954	total: 1.63s	remaining: 584ms
# 368:	learn: 0.4506947	total: 1.63s	remaining: 580ms
# 369:	learn: 0.4504099	total: 1.64s	remaining: 575ms
# 370:	learn: 0.4501953	total: 1.64s	remaining: 571ms
# 371:	learn: 0.4499650	total: 1.65s	remaining: 566ms
# 372:	learn: 0.4497355	total: 1.65s	remaining: 562ms
# 373:	learn: 0.4494169	total: 1.65s	remaining: 557ms
# 374:	learn: 0.4492465	total: 1.66s	remaining: 553ms
# 375:	learn: 0.4490495	total: 1.66s	remaining: 549ms
# 376:	learn: 0.4488926	total: 1.67s	remaining: 544ms
# 377:	learn: 0.4486522	total: 1.67s	remaining: 540ms
# 378:	learn: 0.4484181	total: 1.68s	remaining: 535ms
# 379:	learn: 0.4481846	total: 1.68s	remaining: 531ms
# 380:	learn: 0.4479108	total: 1.68s	remaining: 526ms
# 381:	learn: 0.4477142	total: 1.69s	remaining: 522ms
# 382:	learn: 0.4474322	total: 1.69s	remaining: 517ms
# 383:	learn: 0.4470729	total: 1.7s	remaining: 513ms
# 384:	learn: 0.4468355	total: 1.7s	remaining: 508ms
# 385:	learn: 0.4465817	total: 1.71s	remaining: 504ms
# 386:	learn: 0.4463993	total: 1.71s	remaining: 500ms
# 387:	learn: 0.4462338	total: 1.71s	remaining: 495ms
# 388:	learn: 0.4458574	total: 1.72s	remaining: 491ms
# 389:	learn: 0.4456324	total: 1.72s	remaining: 486ms
# 390:	learn: 0.4454389	total: 1.73s	remaining: 482ms
# 391:	learn: 0.4451270	total: 1.73s	remaining: 477ms
# 392:	learn: 0.4449414	total: 1.74s	remaining: 473ms
# 393:	learn: 0.4447345	total: 1.74s	remaining: 469ms
# 394:	learn: 0.4444583	total: 1.75s	remaining: 464ms
# 395:	learn: 0.4441019	total: 1.75s	remaining: 460ms
# 396:	learn: 0.4438656	total: 1.75s	remaining: 455ms
# 397:	learn: 0.4437141	total: 1.76s	remaining: 451ms
# 398:	learn: 0.4435183	total: 1.76s	remaining: 446ms
# 399:	learn: 0.4433140	total: 1.77s	remaining: 442ms
# 400:	learn: 0.4430376	total: 1.77s	remaining: 438ms
# 401:	learn: 0.4426996	total: 1.78s	remaining: 433ms
# 402:	learn: 0.4424928	total: 1.78s	remaining: 429ms
# 403:	learn: 0.4423317	total: 1.79s	remaining: 425ms
# 404:	learn: 0.4420704	total: 1.79s	remaining: 420ms
# 405:	learn: 0.4417738	total: 1.79s	remaining: 416ms
# 406:	learn: 0.4415361	total: 1.8s	remaining: 411ms
# 407:	learn: 0.4412831	total: 1.8s	remaining: 407ms
# 408:	learn: 0.4410257	total: 1.81s	remaining: 403ms
# 409:	learn: 0.4408499	total: 1.82s	remaining: 399ms
# 410:	learn: 0.4405819	total: 1.82s	remaining: 394ms
# 411:	learn: 0.4402985	total: 1.82s	remaining: 390ms
# 412:	learn: 0.4400199	total: 1.83s	remaining: 386ms
# 413:	learn: 0.4398585	total: 1.83s	remaining: 381ms
# 414:	learn: 0.4396327	total: 1.84s	remaining: 377ms
# 415:	learn: 0.4393518	total: 1.84s	remaining: 372ms
# 416:	learn: 0.4391270	total: 1.85s	remaining: 368ms
# 417:	learn: 0.4388435	total: 1.85s	remaining: 363ms
# 418:	learn: 0.4385417	total: 1.86s	remaining: 359ms
# 419:	learn: 0.4382143	total: 1.86s	remaining: 355ms
# 420:	learn: 0.4380449	total: 1.86s	remaining: 350ms
# 421:	learn: 0.4377227	total: 1.87s	remaining: 346ms
# 422:	learn: 0.4374709	total: 1.87s	remaining: 341ms
# 423:	learn: 0.4371741	total: 1.88s	remaining: 337ms
# 424:	learn: 0.4370489	total: 1.88s	remaining: 332ms
# 425:	learn: 0.4368740	total: 1.89s	remaining: 328ms
# 426:	learn: 0.4366921	total: 1.89s	remaining: 323ms
# 427:	learn: 0.4365547	total: 1.9s	remaining: 319ms
# ...
# 192:	learn: 0.5004311	total: 1.15s	remaining: 1.84s
# 193:	learn: 0.5001219	total: 1.16s	remaining: 1.83s
# 194:	learn: 0.4994622	total: 1.16s	remaining: 1.82s
# 195:	learn: 0.4991121	total: 1.17s	remaining: 1.81s
# 196:	learn: 0.4987919	total: 1.18s	remaining: 1.81s
# 197:	learn: 0.4984594	total: 1.18s	remaining: 1.8s
# 198:	learn: 0.4981471	total: 1.19s	remaining: 1.79s
# 199:	learn: 0.4977325	total: 1.19s	remaining: 1.79s
# 200:	learn: 0.4973015	total: 1.2s	remaining: 1.78s
# 201:	learn: 0.4969653	total: 1.2s	remaining: 1.77s
# 202:	learn: 0.4963737	total: 1.21s	remaining: 1.77s
# 203:	learn: 0.4959749	total: 1.21s	remaining: 1.76s
# 204:	learn: 0.4956812	total: 1.22s	remaining: 1.75s
# 205:	learn: 0.4953286	total: 1.22s	remaining: 1.75s
# 206:	learn: 0.4951377	total: 1.23s	remaining: 1.74s
# 207:	learn: 0.4948325	total: 1.23s	remaining: 1.73s
# 208:	learn: 0.4945161	total: 1.24s	remaining: 1.72s
# 209:	learn: 0.4943260	total: 1.24s	remaining: 1.72s
# 210:	learn: 0.4939908	total: 1.25s	remaining: 1.71s
# 211:	learn: 0.4936448	total: 1.25s	remaining: 1.7s
# 212:	learn: 0.4932305	total: 1.26s	remaining: 1.69s
# 213:	learn: 0.4927999	total: 1.26s	remaining: 1.69s
# 214:	learn: 0.4924667	total: 1.27s	remaining: 1.68s
# 215:	learn: 0.4921788	total: 1.27s	remaining: 1.67s
# 216:	learn: 0.4919004	total: 1.28s	remaining: 1.67s
# 217:	learn: 0.4914486	total: 1.28s	remaining: 1.66s
# 218:	learn: 0.4910892	total: 1.29s	remaining: 1.66s
# 219:	learn: 0.4907481	total: 1.3s	remaining: 1.65s
# 220:	learn: 0.4904590	total: 1.3s	remaining: 1.65s
# 221:	learn: 0.4901025	total: 1.31s	remaining: 1.64s
# 222:	learn: 0.4898042	total: 1.32s	remaining: 1.64s
# 223:	learn: 0.4894487	total: 1.32s	remaining: 1.63s
# 224:	learn: 0.4891474	total: 1.33s	remaining: 1.62s
# 225:	learn: 0.4888678	total: 1.33s	remaining: 1.62s
# 226:	learn: 0.4885389	total: 1.34s	remaining: 1.61s
# 227:	learn: 0.4882024	total: 1.35s	remaining: 1.61s
# 228:	learn: 0.4877760	total: 1.35s	remaining: 1.6s
# 229:	learn: 0.4874958	total: 1.36s	remaining: 1.6s
# 230:	learn: 0.4872599	total: 1.37s	remaining: 1.59s
# 231:	learn: 0.4870222	total: 1.37s	remaining: 1.59s
# 232:	learn: 0.4866946	total: 1.38s	remaining: 1.58s
# 233:	learn: 0.4864324	total: 1.39s	remaining: 1.57s
# 234:	learn: 0.4860680	total: 1.39s	remaining: 1.57s
# 235:	learn: 0.4858529	total: 1.4s	remaining: 1.56s
# 236:	learn: 0.4854412	total: 1.4s	remaining: 1.56s
# 237:	learn: 0.4850089	total: 1.41s	remaining: 1.55s
# 238:	learn: 0.4846949	total: 1.41s	remaining: 1.54s
# 239:	learn: 0.4843814	total: 1.42s	remaining: 1.54s
# 240:	learn: 0.4838676	total: 1.43s	remaining: 1.53s
# 241:	learn: 0.4836093	total: 1.43s	remaining: 1.53s
# 242:	learn: 0.4833563	total: 1.44s	remaining: 1.52s
# 243:	learn: 0.4828283	total: 1.44s	remaining: 1.51s
# 244:	learn: 0.4825667	total: 1.45s	remaining: 1.51s
# 245:	learn: 0.4823185	total: 1.45s	remaining: 1.5s
# 246:	learn: 0.4820579	total: 1.46s	remaining: 1.5s
# 247:	learn: 0.4816849	total: 1.47s	remaining: 1.49s
# 248:	learn: 0.4813825	total: 1.47s	remaining: 1.49s
# 249:	learn: 0.4811160	total: 1.48s	remaining: 1.48s
# 250:	learn: 0.4808704	total: 1.49s	remaining: 1.47s
# 251:	learn: 0.4806932	total: 1.49s	remaining: 1.47s
# 252:	learn: 0.4801955	total: 1.5s	remaining: 1.46s
# 253:	learn: 0.4799763	total: 1.5s	remaining: 1.46s
# 254:	learn: 0.4796229	total: 1.51s	remaining: 1.45s
# 255:	learn: 0.4793365	total: 1.52s	remaining: 1.45s
# 256:	learn: 0.4790390	total: 1.52s	remaining: 1.44s
# 257:	learn: 0.4788523	total: 1.53s	remaining: 1.43s
# 258:	learn: 0.4785642	total: 1.53s	remaining: 1.43s
# 259:	learn: 0.4783284	total: 1.54s	remaining: 1.42s
# 260:	learn: 0.4780862	total: 1.55s	remaining: 1.42s
# 261:	learn: 0.4777379	total: 1.55s	remaining: 1.41s
# 262:	learn: 0.4775294	total: 1.56s	remaining: 1.41s
# 263:	learn: 0.4772688	total: 1.56s	remaining: 1.4s
# 264:	learn: 0.4770442	total: 1.57s	remaining: 1.39s
# 265:	learn: 0.4767885	total: 1.58s	remaining: 1.39s
# 266:	learn: 0.4765132	total: 1.58s	remaining: 1.38s
# 267:	learn: 0.4763277	total: 1.59s	remaining: 1.38s
# 268:	learn: 0.4761021	total: 1.6s	remaining: 1.37s
# 269:	learn: 0.4758355	total: 1.6s	remaining: 1.36s
# 270:	learn: 0.4755198	total: 1.61s	remaining: 1.36s
# 271:	learn: 0.4751507	total: 1.61s	remaining: 1.35s
# 272:	learn: 0.4748855	total: 1.62s	remaining: 1.35s
# 273:	learn: 0.4747229	total: 1.63s	remaining: 1.34s
# 274:	learn: 0.4744692	total: 1.63s	remaining: 1.34s
# 275:	learn: 0.4741165	total: 1.64s	remaining: 1.33s
# 276:	learn: 0.4738718	total: 1.65s	remaining: 1.32s
# 277:	learn: 0.4735081	total: 1.65s	remaining: 1.32s
# 278:	learn: 0.4732429	total: 1.66s	remaining: 1.31s
# 279:	learn: 0.4728874	total: 1.66s	remaining: 1.31s
# 280:	learn: 0.4726005	total: 1.67s	remaining: 1.3s
# 281:	learn: 0.4723429	total: 1.67s	remaining: 1.29s
# 282:	learn: 0.4720150	total: 1.68s	remaining: 1.29s
# 283:	learn: 0.4715909	total: 1.69s	remaining: 1.28s
# 284:	learn: 0.4713887	total: 1.69s	remaining: 1.27s
# 285:	learn: 0.4710243	total: 1.7s	remaining: 1.27s
# 286:	learn: 0.4706234	total: 1.7s	remaining: 1.26s
# 287:	learn: 0.4704411	total: 1.71s	remaining: 1.26s
# 288:	learn: 0.4701703	total: 1.71s	remaining: 1.25s
# 289:	learn: 0.4699004	total: 1.72s	remaining: 1.25s
# 290:	learn: 0.4695077	total: 1.73s	remaining: 1.24s
# 291:	learn: 0.4691079	total: 1.73s	remaining: 1.23s
# 292:	learn: 0.4688330	total: 1.74s	remaining: 1.23s
# 293:	learn: 0.4685420	total: 1.74s	remaining: 1.22s
# 294:	learn: 0.4682003	total: 1.75s	remaining: 1.22s
# 295:	learn: 0.4680029	total: 1.75s	remaining: 1.21s
# 296:	learn: 0.4678502	total: 1.76s	remaining: 1.2s
# 297:	learn: 0.4675035	total: 1.76s	remaining: 1.2s
# 298:	learn: 0.4671051	total: 1.77s	remaining: 1.19s
# 299:	learn: 0.4668669	total: 1.78s	remaining: 1.18s
# 300:	learn: 0.4664667	total: 1.78s	remaining: 1.18s
# 301:	learn: 0.4661644	total: 1.79s	remaining: 1.17s
# 302:	learn: 0.4659222	total: 1.79s	remaining: 1.17s
# 303:	learn: 0.4656868	total: 1.8s	remaining: 1.16s
# 304:	learn: 0.4653593	total: 1.8s	remaining: 1.15s
# 305:	learn: 0.4650986	total: 1.81s	remaining: 1.15s
# 306:	learn: 0.4649513	total: 1.81s	remaining: 1.14s
# 307:	learn: 0.4646960	total: 1.82s	remaining: 1.13s
# 308:	learn: 0.4643720	total: 1.82s	remaining: 1.13s
# 309:	learn: 0.4639342	total: 1.83s	remaining: 1.12s
# 310:	learn: 0.4635495	total: 1.83s	remaining: 1.11s
# 311:	learn: 0.4631792	total: 1.84s	remaining: 1.11s
# 312:	learn: 0.4628215	total: 1.85s	remaining: 1.1s
# 313:	learn: 0.4625554	total: 1.85s	remaining: 1.1s
# 314:	learn: 0.4622283	total: 1.86s	remaining: 1.09s
# 315:	learn: 0.4620075	total: 1.86s	remaining: 1.08s
# 316:	learn: 0.4617089	total: 1.87s	remaining: 1.08s
# 317:	learn: 0.4614735	total: 1.87s	remaining: 1.07s
# 318:	learn: 0.4610532	total: 1.88s	remaining: 1.06s
# 319:	learn: 0.4606981	total: 1.88s	remaining: 1.06s
# 320:	learn: 0.4603743	total: 1.89s	remaining: 1.05s
# 321:	learn: 0.4600996	total: 1.9s	remaining: 1.05s
# 322:	learn: 0.4598806	total: 1.9s	remaining: 1.04s
# 323:	learn: 0.4596368	total: 1.91s	remaining: 1.04s
# 324:	learn: 0.4594023	total: 1.91s	remaining: 1.03s
# 325:	learn: 0.4592017	total: 1.92s	remaining: 1.02s
# 326:	learn: 0.4588976	total: 1.92s	remaining: 1.02s
# 327:	learn: 0.4586165	total: 1.93s	remaining: 1.01s
# 328:	learn: 0.4583370	total: 1.93s	remaining: 1s
# 329:	learn: 0.4580415	total: 1.94s	remaining: 1000ms
# 330:	learn: 0.4577685	total: 1.95s	remaining: 994ms
# 331:	learn: 0.4574467	total: 1.95s	remaining: 989ms
# 332:	learn: 0.4572627	total: 1.96s	remaining: 983ms
# 333:	learn: 0.4570004	total: 1.97s	remaining: 977ms
# 334:	learn: 0.4567853	total: 1.97s	remaining: 971ms
# 335:	learn: 0.4565945	total: 1.98s	remaining: 965ms
# 336:	learn: 0.4562129	total: 1.98s	remaining: 959ms
# 337:	learn: 0.4558954	total: 1.99s	remaining: 953ms
# 338:	learn: 0.4557184	total: 1.99s	remaining: 947ms
# 339:	learn: 0.4554509	total: 2s	remaining: 941ms
# 340:	learn: 0.4551062	total: 2.01s	remaining: 935ms
# 341:	learn: 0.4547953	total: 2.01s	remaining: 929ms
# 342:	learn: 0.4544985	total: 2.02s	remaining: 923ms
# 343:	learn: 0.4542243	total: 2.02s	remaining: 917ms
# 344:	learn: 0.4539075	total: 2.03s	remaining: 911ms
# 345:	learn: 0.4536714	total: 2.03s	remaining: 905ms
# 346:	learn: 0.4534882	total: 2.04s	remaining: 899ms
# 347:	learn: 0.4533523	total: 2.04s	remaining: 893ms
# 348:	learn: 0.4531548	total: 2.05s	remaining: 887ms
# 349:	learn: 0.4528493	total: 2.06s	remaining: 881ms
# 350:	learn: 0.4526107	total: 2.06s	remaining: 875ms
# 351:	learn: 0.4525264	total: 2.07s	remaining: 870ms
# 352:	learn: 0.4522465	total: 2.07s	remaining: 864ms
# 353:	learn: 0.4520692	total: 2.08s	remaining: 858ms
# 354:	learn: 0.4518803	total: 2.08s	remaining: 852ms
# 355:	learn: 0.4516118	total: 2.09s	remaining: 846ms
# 356:	learn: 0.4512795	total: 2.1s	remaining: 839ms
# 357:	learn: 0.4510286	total: 2.1s	remaining: 833ms
# 358:	learn: 0.4508778	total: 2.11s	remaining: 827ms
# 359:	learn: 0.4506578	total: 2.11s	remaining: 821ms
# 360:	learn: 0.4505092	total: 2.12s	remaining: 815ms
# 361:	learn: 0.4503343	total: 2.12s	remaining: 809ms
# 362:	learn: 0.4500684	total: 2.13s	remaining: 803ms
# 363:	learn: 0.4498799	total: 2.13s	remaining: 796ms
# 364:	learn: 0.4496540	total: 2.14s	remaining: 790ms
# 365:	learn: 0.4494487	total: 2.14s	remaining: 784ms
# 366:	learn: 0.4491555	total: 2.15s	remaining: 778ms
# 367:	learn: 0.4488977	total: 2.15s	remaining: 772ms
# 368:	learn: 0.4487046	total: 2.16s	remaining: 766ms
# 369:	learn: 0.4484270	total: 2.16s	remaining: 760ms
# 370:	learn: 0.4480910	total: 2.17s	remaining: 754ms
# 371:	learn: 0.4477302	total: 2.17s	remaining: 749ms
# 372:	learn: 0.4474167	total: 2.18s	remaining: 743ms
# 373:	learn: 0.4471860	total: 2.19s	remaining: 737ms
# 374:	learn: 0.4469612	total: 2.19s	remaining: 731ms
# 375:	learn: 0.4467199	total: 2.2s	remaining: 725ms
# 376:	learn: 0.4465364	total: 2.2s	remaining: 719ms
# 377:	learn: 0.4463854	total: 2.21s	remaining: 713ms
# 378:	learn: 0.4460906	total: 2.21s	remaining: 707ms
# 379:	learn: 0.4458847	total: 2.22s	remaining: 701ms
# 380:	learn: 0.4455942	total: 2.22s	remaining: 695ms
# 381:	learn: 0.4453253	total: 2.23s	remaining: 689ms
# 382:	learn: 0.4450644	total: 2.23s	remaining: 682ms
# 383:	learn: 0.4448500	total: 2.24s	remaining: 676ms
# 384:	learn: 0.4446083	total: 2.24s	remaining: 670ms
# 385:	learn: 0.4443093	total: 2.25s	remaining: 664ms
# 386:	learn: 0.4440848	total: 2.25s	remaining: 659ms
# 387:	learn: 0.4438248	total: 2.26s	remaining: 653ms
# 388:	learn: 0.4435376	total: 2.27s	remaining: 647ms
# 389:	learn: 0.4433577	total: 2.27s	remaining: 641ms
# 390:	learn: 0.4430640	total: 2.28s	remaining: 635ms
# 391:	learn: 0.4428435	total: 2.28s	remaining: 629ms
# 392:	learn: 0.4425859	total: 2.29s	remaining: 623ms
# 393:	learn: 0.4422964	total: 2.29s	remaining: 618ms
# 394:	learn: 0.4420688	total: 2.3s	remaining: 612ms
# 395:	learn: 0.4418434	total: 2.31s	remaining: 606ms
# 396:	learn: 0.4416274	total: 2.31s	remaining: 600ms
# 397:	learn: 0.4413013	total: 2.32s	remaining: 594ms
# 398:	learn: 0.4410727	total: 2.32s	remaining: 588ms
# 399:	learn: 0.4408606	total: 2.33s	remaining: 583ms
# 400:	learn: 0.4406078	total: 2.33s	remaining: 577ms
# 401:	learn: 0.4403812	total: 2.34s	remaining: 571ms
# 402:	learn: 0.4401792	total: 2.35s	remaining: 565ms
# 403:	learn: 0.4399441	total: 2.35s	remaining: 559ms
# 404:	learn: 0.4396808	total: 2.36s	remaining: 553ms
# 405:	learn: 0.4394271	total: 2.36s	remaining: 547ms
# 406:	learn: 0.4391712	total: 2.37s	remaining: 541ms
# 407:	learn: 0.4390978	total: 2.37s	remaining: 535ms
# 408:	learn: 0.4388952	total: 2.38s	remaining: 530ms
# 409:	learn: 0.4386095	total: 2.38s	remaining: 524ms
# 410:	learn: 0.4383788	total: 2.39s	remaining: 518ms
# 411:	learn: 0.4380884	total: 2.4s	remaining: 512ms
# 412:	learn: 0.4378442	total: 2.4s	remaining: 506ms
# 413:	learn: 0.4375725	total: 2.41s	remaining: 500ms
# 414:	learn: 0.4373202	total: 2.41s	remaining: 494ms
# 415:	learn: 0.4370946	total: 2.42s	remaining: 488ms
# 416:	learn: 0.4367873	total: 2.42s	remaining: 482ms
# 417:	learn: 0.4365746	total: 2.43s	remaining: 476ms
# 418:	learn: 0.4363938	total: 2.43s	remaining: 470ms
# 419:	learn: 0.4360934	total: 2.44s	remaining: 465ms
# 420:	learn: 0.4359229	total: 2.45s	remaining: 459ms
# 421:	learn: 0.4357000	total: 2.45s	remaining: 454ms
# 422:	learn: 0.4353305	total: 2.46s	remaining: 448ms
# 423:	learn: 0.4351885	total: 2.47s	remaining: 442ms
# 424:	learn: 0.4348795	total: 2.47s	remaining: 436ms
# 425:	learn: 0.4346389	total: 2.48s	remaining: 430ms
# 426:	learn: 0.4344692	total: 2.48s	remaining: 425ms
# 427:	learn: 0.4342175	total: 2.49s	remaining: 419ms
# 428:	learn: 0.4339210	total: 2.49s	remaining: 413ms
# 429:	learn: 0.4337164	total: 2.5s	remaining: 407ms
# 430:	learn: 0.4335073	total: 2.5s	remaining: 401ms
# 431:	learn: 0.4332390	total: 2.51s	remaining: 395ms
# 432:	learn: 0.4329800	total: 2.51s	remaining: 389ms
# 433:	learn: 0.4328137	total: 2.52s	remaining: 383ms
# 434:	learn: 0.4325108	total: 2.52s	remaining: 377ms
# 435:	learn: 0.4322896	total: 2.53s	remaining: 371ms
# 436:	learn: 0.4320825	total: 2.53s	remaining: 365ms
# 437:	learn: 0.4319628	total: 2.54s	remaining: 359ms
# 438:	learn: 0.4317295	total: 2.54s	remaining: 353ms
# 439:	learn: 0.4315804	total: 2.55s	remaining: 348ms
# 440:	learn: 0.4312887	total: 2.55s	remaining: 342ms
# 441:	learn: 0.4310834	total: 2.56s	remaining: 336ms
# 442:	learn: 0.4309436	total: 2.56s	remaining: 330ms
# 443:	learn: 0.4305900	total: 2.57s	remaining: 324ms
# 444:	learn: 0.4303081	total: 2.58s	remaining: 318ms
# 445:	learn: 0.4300758	total: 2.58s	remaining: 312ms
# 446:	learn: 0.4298559	total: 2.58s	remaining: 306ms
# 447:	learn: 0.4296144	total: 2.59s	remaining: 301ms
# 448:	learn: 0.4294412	total: 2.6s	remaining: 295ms
# 449:	learn: 0.4292932	total: 2.6s	remaining: 289ms
# 450:	learn: 0.4291489	total: 2.6s	remaining: 283ms
# 451:	learn: 0.4289455	total: 2.61s	remaining: 277ms
# 452:	learn: 0.4287716	total: 2.62s	remaining: 271ms
# 453:	learn: 0.4284572	total: 2.62s	remaining: 266ms
# 454:	learn: 0.4281840	total: 2.63s	remaining: 260ms
# 455:	learn: 0.4280858	total: 2.63s	remaining: 254ms
# 456:	learn: 0.4277938	total: 2.64s	remaining: 248ms
# 457:	learn: 0.4276384	total: 2.64s	remaining: 242ms
# 458:	learn: 0.4274555	total: 2.65s	remaining: 236ms
# 459:	learn: 0.4272544	total: 2.65s	remaining: 231ms
# 460:	learn: 0.4269347	total: 2.66s	remaining: 225ms
# 461:	learn: 0.4266442	total: 2.66s	remaining: 219ms
# 462:	learn: 0.4264026	total: 2.67s	remaining: 213ms
# 463:	learn: 0.4260135	total: 2.67s	remaining: 208ms
# 464:	learn: 0.4257785	total: 2.68s	remaining: 202ms
# 465:	learn: 0.4255803	total: 2.69s	remaining: 196ms
# 466:	learn: 0.4253156	total: 2.69s	remaining: 190ms
# 467:	learn: 0.4250570	total: 2.69s	remaining: 184ms
# 468:	learn: 0.4248015	total: 2.7s	remaining: 179ms
# 469:	learn: 0.4246379	total: 2.71s	remaining: 173ms
# 470:	learn: 0.4243933	total: 2.71s	remaining: 167ms
# 471:	learn: 0.4242156	total: 2.72s	remaining: 161ms
# 472:	learn: 0.4239922	total: 2.72s	remaining: 155ms
# 473:	learn: 0.4237973	total: 2.73s	remaining: 150ms
# 474:	learn: 0.4235996	total: 2.73s	remaining: 144ms
# 475:	learn: 0.4233464	total: 2.74s	remaining: 138ms
# 476:	learn: 0.4230818	total: 2.74s	remaining: 132ms
# 477:	learn: 0.4228670	total: 2.75s	remaining: 126ms
# 478:	learn: 0.4226602	total: 2.75s	remaining: 121ms
# 479:	learn: 0.4224770	total: 2.76s	remaining: 115ms
# 480:	learn: 0.4222607	total: 2.76s	remaining: 109ms
# 481:	learn: 0.4220319	total: 2.77s	remaining: 103ms
# 482:	learn: 0.4218449	total: 2.77s	remaining: 97.6ms
# 483:	learn: 0.4216353	total: 2.78s	remaining: 91.8ms
# 484:	learn: 0.4214360	total: 2.78s	remaining: 86.1ms
# 485:	learn: 0.4211587	total: 2.79s	remaining: 80.3ms
# 486:	learn: 0.4208563	total: 2.79s	remaining: 74.6ms
# 487:	learn: 0.4206352	total: 2.8s	remaining: 68.8ms
# 488:	learn: 0.4203808	total: 2.8s	remaining: 63.1ms
# 489:	learn: 0.4201679	total: 2.81s	remaining: 57.3ms
# 490:	learn: 0.4200138	total: 2.81s	remaining: 51.6ms
# 491:	learn: 0.4198379	total: 2.82s	remaining: 45.8ms
# 492:	learn: 0.4196741	total: 2.82s	remaining: 40.1ms
# 493:	learn: 0.4194669	total: 2.83s	remaining: 34.4ms
# 494:	learn: 0.4193013	total: 2.83s	remaining: 28.6ms
# 495:	learn: 0.4190664	total: 2.84s	remaining: 22.9ms
# 496:	learn: 0.4187908	total: 2.84s	remaining: 17.2ms
# 497:	learn: 0.4185791	total: 2.85s	remaining: 11.4ms
# 498:	learn: 0.4184010	total: 2.85s	remaining: 5.72ms
# 499:	learn: 0.4181990	total: 2.86s	remaining: 0us

# %%
pd.DataFrame(result_dict).T
# Out:
#                                                         fit_time  \
# Dummy_Classifer                                0.002 (+/- 0.000)
# DecitionTree_Classifier                        0.264 (+/- 0.003)
# GNB_Classifier                                 0.007 (+/- 0.000)
# LogisticR_Classifier                           0.049 (+/- 0.003)
# RandomForest_Classifier                        2.683 (+/- 0.034)
# GradBoost_Classifier                           1.889 (+/- 0.026)
# RandomForest_Classifier_predict_proba_scaled   2.633 (+/- 0.059)
# GradBoost_Classifier_predict_proba             1.790 (+/- 0.005)
# RandomForest_Classifier_predict_proba          2.569 (+/- 0.005)
# CATBoost_Classifier                            4.707 (+/- 0.125)
# DecitionTree_Classifier_tuned                  0.162 (+/- 0.002)
# RandomForest_Classifier_tuned                 15.249 (+/- 0.160)
# LogisticR_Classifier_tuned                     0.040 (+/- 0.003)
# GradBoost_Classifier_tuned                    81.706 (+/- 0.129)
# CATBoost_Classifier_tuned                      2.974 (+/- 0.577)
#
#                                                      score_time  \
# Dummy_Classifer                               0.000 (+/- 0.000)
# DecitionTree_Classifier                       0.002 (+/- 0.000)
# GNB_Classifier                                0.002 (+/- 0.001)
# LogisticR_Classifier                          0.002 (+/- 0.000)
# RandomForest_Classifier                       0.046 (+/- 0.000)
# GradBoost_Classifier                          0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba_scaled  0.045 (+/- 0.001)
# GradBoost_Classifier_predict_proba            0.004 (+/- 0.000)
# RandomForest_Classifier_predict_proba         0.044 (+/- 0.001)
# CATBoost_Classifier                           0.003 (+/- 0.001)
# DecitionTree_Classifier_tuned                 0.002 (+/- 0.000)
# RandomForest_Classifier_tuned                 0.067 (+/- 0.001)
# LogisticR_Classifier_tuned                    0.001 (+/- 0.000)
# GradBoost_Classifier_tuned                    0.097 (+/- 0.001)
# CATBoost_Classifier_tuned                     0.002 (+/- 0.001)
#
#                                                      test_score  \
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       0.613 (+/- 0.005)
# GNB_Classifier                                0.601 (+/- 0.008)
# LogisticR_Classifier                          0.547 (+/- 0.006)
# RandomForest_Classifier                       0.701 (+/- 0.006)
# GradBoost_Classifier                          0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba_scaled  0.701 (+/- 0.006)
# GradBoost_Classifier_predict_proba            0.685 (+/- 0.005)
# RandomForest_Classifier_predict_proba         0.701 (+/- 0.006)
# CATBoost_Classifier                           0.724 (+/- 0.007)
# DecitionTree_Classifier_tuned                 0.654 (+/- 0.005)
# RandomForest_Classifier_tuned                 0.699 (+/- 0.007)
# LogisticR_Classifier_tuned                    0.547 (+/- 0.006)
# GradBoost_Classifier_tuned                    0.719 (+/- 0.007)
# CATBoost_Classifier_tuned                     0.721 (+/- 0.007)
#
#                                                     train_score
# Dummy_Classifer                               0.501 (+/- 0.000)
# DecitionTree_Classifier                       1.000 (+/- 0.000)
# GNB_Classifier                                0.602 (+/- 0.009)
# LogisticR_Classifier                          0.548 (+/- 0.002)
# RandomForest_Classifier                       0.786 (+/- 0.002)
# GradBoost_Classifier                          0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba_scaled  0.786 (+/- 0.002)
# GradBoost_Classifier_predict_proba            0.692 (+/- 0.001)
# RandomForest_Classifier_predict_proba         0.786 (+/- 0.002)
# CATBoost_Classifier                           0.800 (+/- 0.002)
# DecitionTree_Classifier_tuned                 0.746 (+/- 0.007)
# RandomForest_Classifier_tuned                 0.803 (+/- 0.004)
# LogisticR_Classifier_tuned                    0.549 (+/- 0.002)
# GradBoost_Classifier_tuned                    0.779 (+/- 0.003)
# CATBoost_Classifier_tuned                     0.822 (+/- 0.002)

# %%
base_cvscore = [0.613,0.601,0.547,0.701,0.685,0.724]
base_train = [1,0.602,0.548,0.786,0.692,0.800]
est = ["DecisionTree","GaussianNB","LogisticR","RandomForest","GradBoost","CatBoost"]

# %%
plt.plot(est,base_cvscore,"X-",label="CV Score")
plt.plot(est,base_train,"rX-",label="Train Score")

plt.xticks(rotation = 45)
plt.yticks(np.arange(0.5, 1, 0.05))
plt.grid()
plt.legend()
plt.title("Plot of Cross validation scores (untuned)")
plt.show()

# %%
est = ["DecisionTree","LogisticR","RandomForest","GradBoost","CatBoost"]
tuned = [0.654,0.547,0.699,0.719,0.721]
tuned_train = [0.746,0.549,0.803,0.779,0.822]
plt.plot(est,tuned,"X-",label="CV Score")
plt.plot(est,tuned_train,"rX-",label="Train Score")
plt.ylim(0.5,1)
plt.yticks(np.arange(0.5, 1, 0.05))
plt.xticks(rotation = 45)
plt.grid()
plt.legend()
plt.title("Plot of Cross validation scores (tuned)")
plt.show()

# %% [markdown]
# ### Discussion about Results

# %% [markdown]
# If we look at the plot of untuned CV scores, we can see that Decision Tree classifier was overfitted. Logistic regression model showed very low cross validation accuracy, which was unexpected since these models are known to work well for classificatio problems. The ensemble techniques showed the best results out of all classifiers tested. In particular Random Forest and CatBoost models were the best with CV score above 0.7 and relatively low/no overfitting.
#
# Looking at the plot of tuned CV scores, we can see that after tuning the Decision Tree Classifier did not overfit the data. Moreover, the CV score also improved. We did not tune the hyperparameters for Gaussian Naive bayes classifier because the default parameters values were found to be the best. The perfomance of Random Forest classifier and CatBoost remained the same after tuning. However, the performance of Gradient Boosting Classifier increased after the tuning.

# %% [markdown]
# ### Kaggle Scores
#
# We found out that the Kaggle score is different than CV score we calculate after model training. Kaggle uses Area under curve to score the results. Hence, if instead 0 and 1 as classification, we submitted the submission with probabilities of state being active or 1, the results were much better. For this we used `predict_proba()` instead of `predict()`. However, the competition clearly asked for binary classification, we did not use this method.

# %% [markdown]
# ![kaggle_score.png](attachment:kaggle_score.png)

# %% [markdown]
# The first two submission that were obtained using `predict_proba()` recieved better scores than the other results that were obtained by using `predict()`.

# %% [markdown]
# ### Pratt method results

# %% [markdown]
# In the preprocessing section, we discussed about the `Pratt method` of preprocessing. Basically instead of 13 features, we created dataframes of 91 features and used these to make classification.

# %% [markdown]
# ![Pratt.png](attachment:Pratt.png)

# %% [markdown]
# As we can see the baseline scores without hyperparameter tuning were similar. However, the Platt preprocessed data was used in conjuction with `predict_proba()`, we got the best score of 0.849. Unfortunately, we could not explore further this pipeline before the deadline of the project. Additionally using a dataframe with 91 features and more than 1 million data points was computationally expensive as well.

# %% [markdown]
# ### Conclusion and Future Work

# %% [markdown]
# In conclusion, we implemeted different methods of data analysis and preprocessing learnt during the lecture periods. The ensemble techniques are a bit better than the normal/standard classifiers.

# %% [markdown]
# For future work, we would like to test different hyperparameter. Moreover, we would also like to try different libraries and models to see if the results are different or better in any way. Additionally, we simply used the mean to group the 60 second sensor data. We would like to explore other possibilities to group the sequence and see the affect on the state predition.
